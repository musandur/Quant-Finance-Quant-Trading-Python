# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch

from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'twits.json'), 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %%
# test
import shutil

shutil.copyfile('./../../data/project_6_stocktwits/twits.json',  'C:\Users\mndour\mn.jason')


#cp C:\Users\mndour /data/project_6_stocktwits/twits.json ./
# Out:
#   File "<ipython-input-20-fee94b8c8c0a>", line 4
#     shutil.copyfile('./../../data/project_6_stocktwits/twits.json' 'C:\Users\mndour\mn.jason')
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

# TODO Implement 

print(f"The number of twits: {len(twits['data'])}")
# Out:
# The number of twits: 1548010

# %%
twits['data'][0]
# Out:
# {'message_body': '$FITB great buy at 26.00...ill wait',
#  'sentiment': 2,
#  'timestamp': '2018-07-01T00:00:09Z'}

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %%
import matplotlib.pyplot as plt

# %%
sentiments[:21]
# Out:
# [4, 3, 4, 3, 2, 3, 0, 3, 4, 0, 4, 0, 4, 4, 4, 3, 4, 2, 4, 3, 3]

# %%
plt.hist(sentiments)
plt.show()

# %%
messages[:21]
# Out:
# ['$FITB great buy at 26.00...ill wait',
#  '@StockTwits $MSFT',
#  '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating',
#  '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.',
#  '$AMD reveal yourself!',
#  '$AAPL Why the drop? I warren Buffet taking out his position?',
#  '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA',
#  '$BAC ok good we&#39;re not dropping in price over the weekend, lol',
#  '$AMAT - Daily Chart, we need to get back to above 50.',
#  '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?',
#  '$SBUX STRONG BUY!',
#  '$SNPS short ratio is 2.17 at 2018-06-15 and short % to float is 1.42% http://sunshineavenue.com/stock/SNPS/ via @sunshineave',
#  '$NFLX price squeezing,perfect place for an option straddle near the supporting trend',
#  '@DEEPAKM2013 @Nytunes Start of new Q on Monday. Expect strong buy volume across key companies of various sectors. $AMZN $AAPL',
#  '[BREAKOUT Strategy] Current Portfolio : $ZBRA,$WEB,$TIF,$SRE,$SPPI,$OTEX,$OMF,$NVGS,$NRCIB,$MSG,$KIRK,$GHDX,$FBNK,$ESND,$DRI,$DKS,$CVTI,$CV',
#  '$PFE bulls have 3 reasons on 06-29 to pay more attention https://dividendbot.com?s=PFE',
#  '$AMZN 3 catalysts 4 Continuing this new uptrend; #1- Pill Pack buy out #2- Amazon Prime Day #3- Earnings. Test/break of 1763 soon $SPY $QQQ',
#  '$AAPL has moved -0.21% on 06-29. Check out the movement and peers at  https://dividendbot.com?s=AAPL',
#  '#STAAnalystAlert for $TGT : MKM Partners Set Price Target with a rating of Buy setting target price at USD 91.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating',
#  '$DNR I think it is too early to tell what’s going to happen Monday. Even with the current news about raisinf output, there is still so many',
#  '$NKE has a Current Ratio of 2.66, so it is financially healthy and has no problem in meeting its obligations. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=HEALTH&amp;utm_campaign=social_tracking#/NKE?r=fa&amp;key=8832fee1-d06b-46b5-827f-26246a5e29a8']

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %%
# test
test = messages[20]
test
# Out:
# '$NKE has a Current Ratio of 2.66, so it is financially healthy and has no problem in meeting its obligations. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=HEALTH&amp;utm_campaign=social_tracking#/NKE?r=fa&amp;key=8832fee1-d06b-46b5-827f-26246a5e29a8'

# %%
# test
tt = test
print(tt)
tt = re.sub(r'https?://\S+',' ', test)
print(tt)
tt = re.sub(r'\$\w+', '', tt) 
print(tt)

tt = re.sub(r'\@\w+', ' ', tt)
print(tt)

tt = re.sub(r'[^a-zA-Z]', ' ', tt)
print(tt)
            

tt = tt.split()
print(tt)
# Out:
# $NKE has a Current Ratio of 2.66, so it is financially healthy and has no problem in meeting its obligations. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=HEALTH&amp;utm_campaign=social_tracking#/NKE?r=fa&amp;key=8832fee1-d06b-46b5-827f-26246a5e29a8
# $NKE has a Current Ratio of 2.66, so it is financially healthy and has no problem in meeting its obligations.
#  has a Current Ratio of 2.66, so it is financially healthy and has no problem in meeting its obligations.
#  has a Current Ratio of 2.66, so it is financially healthy and has no problem in meeting its obligations.
#  has a Current Ratio of       so it is financially healthy and has no problem in meeting its obligations
# ['has', 'a', 'Current', 'Ratio', 'of', 'so', 'it', 'is', 'financially', 'healthy', 'and', 'has', 'no', 'problem', 'in', 'meeting', 'its', 'obligations']

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')


def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    #TODO: Implement 
    
    # Lowercase the twit message
    text = message.lower()
    
    # Replace URLs with a space in the message
    text = re.sub(r'http?://\S+', ' ', text)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'\$\w+', ' ', text)
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'\@\w+', ' ', text)

    # Replace everything not a letter with a space
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = text.split()

    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer()
    tokens = [wnl.lemmatize(word) for word in tokens]

    
    assert type(tokens) == list, 'Tokens should be list'
    return tokens
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# >Note: You must ensure that after preprocessing the text should NOT include:
# - Numbers
# - URLs
# - Single character tokens
# - Ticker symbols (these should be removed even if they don't appear at the beginning)

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
# TODO Implement

tokenized = [preprocess(message) for message in messages]

# %%
tokenized
# Out:
# [['great', 'buy', 'at', 'ill', 'wait'],
#  [],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['i',
#   'heard',
#   'there',
#   's',
#   'a',
#   'guy',
#   'who',
#   'know',
#   'someone',
#   'who',
#   'think',
#   'somebody',
#   'know',
#   'something',
#   'on',
#   'stocktwits'],
#  ['reveal', 'yourself'],
#  ['why',
#   'the',
#   'drop',
#   'i',
#   'warren',
#   'buffet',
#   'taking',
#   'out',
#   'his',
#   'position'],
#  ['bear',
#   'have',
#   'reason',
#   'on',
#   'to',
#   'pay',
#   'more',
#   'attention',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'ba'],
#  ['ok',
#   'good',
#   'we',
#   're',
#   'not',
#   'dropping',
#   'in',
#   'price',
#   'over',
#   'the',
#   'weekend',
#   'lol'],
#  ['daily', 'chart', 'we', 'need', 'to', 'get', 'back', 'to', 'above'],
#  ['drop',
#   'per',
#   'week',
#   'after',
#   'spike',
#   'if',
#   'no',
#   'news',
#   'in',
#   'month',
#   'back',
#   'to',
#   's',
#   'if',
#   'bo',
#   'then',
#   'bingo',
#   'what',
#   'is',
#   'the',
#   'odds'],
#  ['strong', 'buy'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['price',
#   'squeezing',
#   'perfect',
#   'place',
#   'for',
#   'an',
#   'option',
#   'straddle',
#   'near',
#   'the',
#   'supporting',
#   'trend'],
#  ['start',
#   'of',
#   'new',
#   'q',
#   'on',
#   'monday',
#   'expect',
#   'strong',
#   'buy',
#   'volume',
#   'across',
#   'key',
#   'company',
#   'of',
#   'various',
#   'sector'],
#  ['breakout', 'strategy', 'current', 'portfolio'],
#  ['bull',
#   'have',
#   'reason',
#   'on',
#   'to',
#   'pay',
#   'more',
#   'attention',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'pfe'],
#  ['catalyst',
#   'continuing',
#   'this',
#   'new',
#   'uptrend',
#   'pill',
#   'pack',
#   'buy',
#   'out',
#   'amazon',
#   'prime',
#   'day',
#   'earnings',
#   'test',
#   'break',
#   'of',
#   'soon'],
#  ['ha',
#   'moved',
#   'on',
#   'check',
#   'out',
#   'the',
#   'movement',
#   'and',
#   'peer',
#   'at',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'aapl'],
#  ['staanalystalert',
#   'for',
#   'mkm',
#   'partner',
#   'set',
#   'price',
#   'target',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['i',
#   'think',
#   'it',
#   'is',
#   'too',
#   'early',
#   'to',
#   'tell',
#   'what',
#   's',
#   'going',
#   'to',
#   'happen',
#   'monday',
#   'even',
#   'with',
#   'the',
#   'current',
#   'news',
#   'about',
#   'raisinf',
#   'output',
#   'there',
#   'is',
#   'still',
#   'so',
#   'many'],
#  ['ha',
#   'a',
#   'current',
#   'ratio',
#   'of',
#   'so',
#   'it',
#   'is',
#   'financially',
#   'healthy',
#   'and',
#   'ha',
#   'no',
#   'problem',
#   'in',
#   'meeting',
#   'it',
#   'obligation',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'health',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'nke',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'fee',
#   'd',
#   'b',
#   'b',
#   'f',
#   'a',
#   'e',
#   'a'],
#  ['bullish',
#   'stock',
#   'to',
#   'watch',
#   'setup',
#   'timeframes',
#   'http',
#   'www',
#   'seeitmarket',
#   'com',
#   'bullish',
#   'stock',
#   'twitter',
#   'twtr',
#   'and',
#   'michael',
#   'kor',
#   'blog',
#   'by'],
#  ['just', 'short', 'it'],
#  ['high', 'alert', 'for', 'next', 'week', 'gt', 'breakdown'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'health',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'fslr',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'b',
#   'cf',
#   'ec',
#   'e',
#   'b',
#   'b',
#   'b',
#   'be'],
#  ['i', 'miss', 'these', 'day'],
#  ['if',
#   'break',
#   'and',
#   'confirms',
#   'next',
#   'week',
#   'you',
#   'will',
#   'see',
#   'a',
#   'violent',
#   'move',
#   'downward',
#   'to',
#   'my',
#   'buy',
#   'price'],
#  ['bear',
#   'have',
#   'reason',
#   'on',
#   'to',
#   'pay',
#   'more',
#   'attention',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'cv'],
#  ['breakout',
#   'base',
#   'gap',
#   'and',
#   'day',
#   'ma',
#   'gap',
#   'gap',
#   'gap',
#   'and',
#   'day',
#   'ma'],
#  ['cabot',
#   'weekly',
#   'video',
#   'quot',
#   'resilient',
#   'growth',
#   'stock',
#   'to',
#   'watch',
#   'quot',
#   'http',
#   'bit',
#   'ly',
#   'kj',
#   'fnd'],
#  ['when',
#   'i',
#   'wa',
#   'a',
#   'kid',
#   'my',
#   'froend',
#   'told',
#   'me',
#   'the',
#   'moon',
#   'wa',
#   'made',
#   'out',
#   'of',
#   'cheese'],
#  ['short',
#   'volume',
#   'percent',
#   'for',
#   'wa',
#   'on',
#   'and',
#   'day',
#   'rank',
#   'wa',
#   'th',
#   'percentile',
#   'http',
#   'volumebot',
#   'com',
#   's',
#   'uri'],
#  ['thank',
#   'you',
#   'i',
#   'don',
#   't',
#   'feel',
#   'the',
#   'need',
#   'to',
#   'tell',
#   'or',
#   'to',
#   'do',
#   'well',
#   'for',
#   'me',
#   'they',
#   'already',
#   'have'],
#  ['during',
#   'the',
#   'youtube',
#   'interview',
#   'mitch',
#   'couldn',
#   't',
#   'remember',
#   'a',
#   'single',
#   'movie',
#   'he',
#   'watched',
#   'all',
#   'year',
#   'except',
#   'star',
#   'war',
#   'black',
#   'panther',
#   'clothes'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'hold'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['ha',
#   'a',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'profitability',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'k',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'e',
#   'a',
#   'e',
#   'f',
#   'f',
#   'd',
#   'b',
#   'c',
#   'c',
#   'e'],
#  ['although',
#   'the',
#   'market',
#   'is',
#   'up',
#   'is',
#   'doing',
#   'even',
#   'better',
#   'it',
#   'ha',
#   'advanced',
#   'a',
#   'of',
#   'more',
#   'info',
#   'peer',
#   'at',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'txn'],
#  ['july',
#   'will',
#   'be',
#   'the',
#   'most',
#   'bullish',
#   'day',
#   'of',
#   'the',
#   'year',
#   'for',
#   'stock'],
#  ['option',
#   'volume',
#   'wa',
#   'x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['third',
#   'design',
#   'win',
#   'the',
#   'timing',
#   'match',
#   'it',
#   's',
#   'probably',
#   'arm',
#   'http',
#   'www',
#   'forbes',
#   'com',
#   'site',
#   'ewanspence',
#   'surface',
#   'andromeda',
#   'windowsphone',
#   'window',
#   'tablet',
#   'leak',
#   'rumor',
#   'spec',
#   'release',
#   'date',
#   'd',
#   'bec',
#   'e'],
#  ['alcohol',
#   'stock',
#   'tobacco',
#   'stock',
#   'and',
#   'firearm',
#   'stock',
#   'to',
#   'buy',
#   'http',
#   'chc',
#   'li',
#   'kdqyur',
#   'b'],
#  ['president',
#   'trump',
#   'tweet',
#   'just',
#   'spoke',
#   'to',
#   'king',
#   'salman',
#   'of',
#   'saudi',
#   'arabia',
#   'and',
#   'explained',
#   'to',
#   'him',
#   'that',
#   'because',
#   'of',
#   'the',
#   'turmoil',
#   'amp'],
#  ['today',
#   's',
#   'insight',
#   'on',
#   'http',
#   'app',
#   'seasonaledge',
#   'com',
#   'tool',
#   'i',
#   'tap'],
#  ['intc',
#   'mama',
#   'said',
#   'i',
#   'get',
#   'ice',
#   'cream',
#   'if',
#   'i',
#   'finish',
#   'my',
#   'due',
#   'dil'],
#  ['just',
#   'noticed',
#   'they',
#   'have',
#   'the',
#   'last',
#   'jedi',
#   'on',
#   'stream',
#   'love',
#   'this',
#   'stock'],
#  ['here', 'you', 'go', 'i', 'will', 'just', 'leave', 'this', 'here'],
#  ['good',
#   'view',
#   'daily',
#   'still',
#   'look',
#   'good',
#   'ema',
#   'held',
#   'above',
#   'ema',
#   'and',
#   'stochastics',
#   'turning',
#   'healthy',
#   'a',
#   'spy',
#   'qqq',
#   'opposite'],
#  ['with',
#   'a',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'a',
#   'cheap',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'valuation',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'mu',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'fbab',
#   'a',
#   'b',
#   'cf',
#   'f',
#   'daf'],
#  ['saber',
#   'capital',
#   's',
#   'presentation',
#   'common',
#   'denominator',
#   'of',
#   'tencent',
#   'facebook',
#   'and',
#   'google',
#   'http',
#   'investoralmanac',
#   'com',
#   'saber',
#   'capital',
#   'common',
#   'denominator',
#   'of',
#   'tencent',
#   'facebook',
#   'google'],
#  ['how', 'u', 'expect', 'the', 'earnings'],
#  ['is',
#   'one',
#   'of',
#   'the',
#   'better',
#   'performing',
#   'stock',
#   'in',
#   'the',
#   'crude',
#   'petroleum',
#   'and',
#   'natural',
#   'gas',
#   'industry',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'ta',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'dnr',
#   'key',
#   'f',
#   'e',
#   'f',
#   'a',
#   'a',
#   'ff',
#   'aa'],
#  ['pu',
#   'it',
#   'simply',
#   'havent',
#   'lost',
#   'on',
#   'any',
#   'brown',
#   'guy',
#   'run',
#   'tech',
#   'company',
#   'mf',
#   'are',
#   'well',
#   'educated',
#   'n',
#   'know',
#   'their',
#   'shit',
#   'more',
#   'n',
#   'more',
#   'every',
#   'year'],
#  ['former',
#   'president',
#   'of',
#   'global',
#   'manufacturing',
#   'at',
#   'pfizer',
#   'is',
#   'an',
#   'independent',
#   'director',
#   'at',
#   'nat',
#   'ricciardi'],
#  ['may', 'be', 'the', 'safest', 'stock', 'i', 'own'],
#  ['special',
#   'limited',
#   'offer',
#   'june',
#   'th',
#   'june',
#   'th',
#   'tradenet',
#   'is',
#   'offering',
#   'a',
#   'discount',
#   'on',
#   'intro',
#   'program',
#   'http',
#   'www',
#   'tradenet',
#   'com',
#   'limitedtime',
#   'offer',
#   'campaign',
#   'id',
#   'o',
#   'pnwd',
#   'amp',
#   'affiliateorg',
#   'tradenet',
#   'amp',
#   'affiliateid',
#   'amp',
#   'affiliatedata'],
#  ['below', 'buy', 'put', 'on', 'financials'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   's',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock',
#   'http',
#   'investoralmanac',
#   'com',
#   'jeffrey',
#   'gundlach',
#   'long',
#   'energy',
#   'stock',
#   'short',
#   'facebook'],
#  ['s',
#   'low',
#   'peg',
#   'ratio',
#   'which',
#   'compensates',
#   'the',
#   'pe',
#   'for',
#   'growth',
#   'indicates',
#   'a',
#   'rather',
#   'cheap',
#   'valuation',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'valuation',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'hpq',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'd',
#   'a',
#   'd',
#   'a',
#   'ac',
#   'e',
#   'e',
#   'fe'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   's',
#   'sohn',
#   'pres',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'equity',
#   'http',
#   'investoralmanac',
#   'com',
#   'jeffrey',
#   'gundlach',
#   'long',
#   'energy',
#   'stock',
#   'short',
#   'facebook'],
#  ['coming'],
#  ['seems', 'is', 'the', 'support', 'next', 'if', 'under', 'is', 'likely'],
#  ['ha',
#   'moved',
#   'on',
#   'check',
#   'out',
#   'the',
#   'movement',
#   'and',
#   'peer',
#   'at',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'wba'],
#  ['bullshit',
#   'worthless',
#   'mean',
#   'fucking',
#   'nothing',
#   'this',
#   'is',
#   'macau',
#   'not',
#   'fucking',
#   'usa'],
#  ['take',
#   'this',
#   'let',
#   'me',
#   'know',
#   'where',
#   'are',
#   'we',
#   'right',
#   'now',
#   'lol'],
#  ['the',
#   'chart',
#   'look',
#   'so',
#   'ugly',
#   'without',
#   'a',
#   'clear',
#   'support',
#   'level',
#   'short',
#   'term',
#   'bearish',
#   'i',
#   'll',
#   'buy',
#   'when',
#   'this',
#   'is',
#   'at'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   's',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock',
#   'http',
#   'investoralmanac',
#   'com',
#   'jeffrey',
#   'gundlach',
#   'long',
#   'energy',
#   'stock',
#   'short',
#   'facebook'],
#  ['previously',
#   'there',
#   'wa',
#   'a',
#   'mo',
#   'run',
#   'up',
#   'followed',
#   'by',
#   'a',
#   'drop',
#   'we',
#   'are',
#   'at',
#   'the',
#   'end',
#   'of',
#   'month',
#   'of',
#   'another',
#   'runup',
#   'and',
#   'have',
#   'dropped',
#   'about'],
#  ['smart',
#   'money',
#   'betting',
#   'on',
#   'call',
#   'deal',
#   'update',
#   'http',
#   'uk',
#   'reuters',
#   'com',
#   'article',
#   'uk',
#   'indonesia',
#   'rio',
#   'tinto',
#   'grasberg',
#   'indonesia',
#   'inalum',
#   'close',
#   'to',
#   'acquiring',
#   'rio',
#   'interest',
#   'in',
#   'grasberg',
#   'copper',
#   'mine',
#   'official',
#   'idukkbn',
#   'jq',
#   'h'],
#  ['although',
#   'the',
#   'technical',
#   'rating',
#   'is',
#   'bad',
#   'doe',
#   'present',
#   'a',
#   'nice',
#   'setup',
#   'opportunity',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'setup',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'wynn',
#   'key',
#   'f',
#   'ceb',
#   'e',
#   'a',
#   'da',
#   'c',
#   'bc'],
#  ['i',
#   'will',
#   'completely',
#   'scale',
#   'out',
#   'in',
#   'time',
#   'to',
#   'gobble',
#   'up',
#   'my',
#   'next',
#   'long',
#   'play',
#   'aka',
#   'my',
#   'favorite',
#   'gt'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['them', 'are', 'iddy', 'bitty', 'kiddy', 'hand'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['then',
#   'u',
#   'r',
#   'awesome',
#   'it',
#   'is',
#   'now',
#   'i',
#   'd',
#   'be',
#   'concerned',
#   'if',
#   'not',
#   'over',
#   'by',
#   'eow',
#   'might',
#   'get',
#   'under',
#   'next',
#   'wk',
#   'or',
#   'soon'],
#  ['throwback'],
#  ['staanalystalert',
#   'for',
#   'u',
#   'capital',
#   'advisor',
#   'upgrade',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'hold',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['lol',
#   'all',
#   'these',
#   'shorties',
#   'are',
#   'dreaming',
#   'of',
#   'great',
#   'depression',
#   'or',
#   'somethin',
#   'loll'],
#  ['just',
#   'updated',
#   'hormel',
#   'food',
#   'dividend',
#   'king',
#   'stock',
#   'analysis',
#   'dividend',
#   'king',
#   'consumer',
#   'defensive'],
#  ['today',
#   's',
#   'insight',
#   'on',
#   'http',
#   'app',
#   'seasonaledge',
#   'com',
#   'tool',
#   'i',
#   'dal'],
#  ['just',
#   'updated',
#   'intel',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['today',
#   's',
#   'insight',
#   'on',
#   'http',
#   'app',
#   'seasonaledge',
#   'com',
#   'tool',
#   'i',
#   'mpc'],
#  ['the',
#   'long',
#   'and',
#   'short',
#   'term',
#   'trend',
#   'are',
#   'both',
#   'positive',
#   'this',
#   'is',
#   'looking',
#   'good',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'ta',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'chk',
#   'key',
#   'df',
#   'b',
#   'cb',
#   'c',
#   'b',
#   'a',
#   'ddbd',
#   'da'],
#  ['they', 'so', 'mad', 'at', 'me', 'still'],
#  ['back', 'to', 'by', 'july'],
#  ['x', 'report', 'and', 'block', 'this', 'person', 'spam'],
#  ['should', 'open', 'at', 'on', 'monday'],
#  ['my',
#   'projection',
#   'for',
#   'if',
#   'thats',
#   'true',
#   'under',
#   'is',
#   'next',
#   'week',
#   'thats',
#   'why',
#   'i',
#   'd',
#   'prefer',
#   'to',
#   'buy',
#   'from',
#   'support',
#   'level'],
#  ['what', 'a', 'turd'],
#  ['percent',
#   'short',
#   'volume',
#   'for',
#   'wa',
#   'on',
#   'http',
#   'volumebot',
#   'com',
#   's',
#   'tap'],
#  ['wal',
#   'mart',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'consumer',
#   'defensive',
#   'valueinvesting',
#   'dvb',
#   'aaamp'],
#  ['looking',
#   'for',
#   'marriage',
#   'i',
#   'have',
#   'm',
#   'in',
#   'my',
#   'bank',
#   'account',
#   'with',
#   'in',
#   'stock',
#   'dm'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['to',
#   'that',
#   'bear',
#   'that',
#   'won',
#   't',
#   'stop',
#   'posting',
#   'holding',
#   'a',
#   'big',
#   'short',
#   'position',
#   'over',
#   'weekend',
#   'calm',
#   'down',
#   'and',
#   'good',
#   'luck',
#   'lol'],
#  ['the',
#   'chase',
#   'continues',
#   'hopefully',
#   'they',
#   'catch',
#   'him',
#   'before',
#   'lisa',
#   'announces',
#   'the',
#   'rd',
#   'win'],
#  ['the',
#   'price',
#   'earnings',
#   'ratio',
#   'is',
#   'which',
#   'indicates',
#   'a',
#   'rather',
#   'cheap',
#   'valuation',
#   'of',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'valuation',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'bbby',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'f',
#   'bb',
#   'afa',
#   'b',
#   'e',
#   'ecc',
#   'ace',
#   'be',
#   'd',
#   'e'],
#  ['permamently',
#   'turned',
#   'me',
#   'off',
#   'of',
#   'option',
#   'trading',
#   'and',
#   'maybe',
#   'stock',
#   'altogether',
#   'manipulation',
#   'by',
#   'very',
#   'rich',
#   'to',
#   'make',
#   'me',
#   'very',
#   'poor',
#   'fuk',
#   'it'],
#  ['is',
#   'down',
#   'almost',
#   'pct',
#   'from',
#   'it',
#   'week',
#   'high',
#   'it',
#   's',
#   'about',
#   'time',
#   'for',
#   'buyback',
#   'i',
#   'got',
#   'more',
#   'share',
#   'in',
#   'my',
#   'account',
#   'though',
#   'from',
#   'drip'],
#  ['option',
#   'volume',
#   'wa',
#   'x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['http',
#   'www',
#   'hollywoodreporter',
#   'com',
#   'thr',
#   'esq',
#   'netflix',
#   'get',
#   'green',
#   'light',
#   'appeal',
#   'court',
#   'challenge',
#   'fox',
#   'employment',
#   'contract',
#   'utm',
#   'source',
#   'sailthru',
#   'amp',
#   'utm',
#   'medium',
#   'email',
#   'amp',
#   'utm',
#   'campaign',
#   'thr',
#   'breaking',
#   'news',
#   'now',
#   'a',
#   'a',
#   'ehayden',
#   'amp',
#   'utm',
#   'term',
#   'hollywoodreporter',
#   'breakingnews'],
#  ['dumped',
#   'call',
#   'friday',
#   'at',
#   'open',
#   'that',
#   'wa',
#   'obv',
#   'but',
#   'jeez',
#   'a',
#   'bit',
#   'over',
#   'done',
#   'here'],
#  ['bounce',
#   'off',
#   'support',
#   'heikin',
#   'ashi',
#   'weekly',
#   'candle',
#   'look',
#   'good',
#   'a',
#   'well',
#   'will',
#   'be',
#   'looking',
#   'for',
#   'confirmation'],
#  ['liking', 'this'],
#  ['look',
#   'for',
#   'a',
#   'wife',
#   'got',
#   'about',
#   'tree',
#   'fiddy',
#   'in',
#   'stock',
#   'and',
#   'it',
#   'sure',
#   'my',
#   'piggy',
#   'bank',
#   'ha',
#   'got',
#   'a',
#   'lot',
#   'of',
#   'coin',
#   'may',
#   'spend',
#   'on',
#   'candy',
#   'no',
#   'dm',
#   's',
#   'though'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['just',
#   'updated',
#   'microsoft',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['bearish',
#   'investor',
#   'aren',
#   't',
#   'happy',
#   'today',
#   'for',
#   'a',
#   'of',
#   'http',
#   'www',
#   'shortpainbot',
#   'com',
#   's',
#   'shld'],
#  ['staanalystalert',
#   'for',
#   'royal',
#   'bank',
#   'of',
#   'canada',
#   'reiterates',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'outperform',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'loop',
#   'capital',
#   'raise',
#   'target',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['kid', 'never', 'been', 'wrong', 'he', 's', 'a', 'miracle'],
#  ['what', 'is', 'o', 'period', 'bollinger', 'band', 'mean'],
#  ['x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'x',
#   'you',
#   'dare',
#   'say',
#   'i',
#   'didn',
#   't',
#   'know',
#   'you',
#   'are',
#   'a',
#   'guilty',
#   'a',
#   'fudge'],
#  ['today',
#   's',
#   'insight',
#   'on',
#   'http',
#   'app',
#   'seasonaledge',
#   'com',
#   'tool',
#   'i',
#   'cvx'],
#  ['hardly',
#   'ever',
#   'an',
#   'informative',
#   'comment',
#   'here',
#   'and',
#   'the',
#   'page',
#   'is',
#   'broken',
#   'giving',
#   'endless',
#   'buffering',
#   'icon',
#   'i',
#   'give',
#   'up',
#   'stocktwits'],
#  ['viral',
#   'walk',
#   'away',
#   'video',
#   'highlight',
#   'growing',
#   'movement',
#   'of',
#   'democrat',
#   'leaving',
#   'the',
#   'party',
#   'the',
#   'epoch',
#   'time',
#   'http',
#   'm',
#   'theepochtimes',
#   'com',
#   'viral',
#   'walk',
#   'away',
#   'video',
#   'highlight',
#   'growing',
#   'movement',
#   'of',
#   'democrat',
#   'leaving',
#   'the',
#   'party',
#   'html'],
#  ['staanalystalert',
#   'for',
#   'robert',
#   'w',
#   'baird',
#   'downgrade',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'neutral',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['too', 'much', 'weed', 'and', 'other', 'drug', 'i', 'guess'],
#  ['with',
#   'a',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'a',
#   'very',
#   'reasonable',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'valuation',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'wba',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'd',
#   'eb',
#   'd',
#   'ab',
#   'c',
#   'fd',
#   'a',
#   'a'],
#  ['the',
#   'reason',
#   'nike',
#   'is',
#   'winning',
#   'is',
#   'because',
#   'of',
#   'their',
#   'click',
#   'booking',
#   'app',
#   'it',
#   's',
#   'better',
#   'than',
#   'native',
#   'seamless',
#   'lovalized',
#   'transactable',
#   'ap'],
#  ['vitiello', 'tapped', 'a', 'acting', 'ice', 'director', 'via'],
#  ['will',
#   'reach',
#   'over',
#   'this',
#   'year',
#   'iconic',
#   'brand',
#   'global',
#   'technology',
#   'and',
#   'built',
#   'for',
#   'mobile',
#   'a',
#   'winning',
#   'strategy',
#   'amp',
#   'show',
#   'in',
#   'earnings'],
#  ['by', 'monday', 'morning'],
#  ['this', 'is', 'heading', 'to', 'a', 'ath', 'soon', 'maybe', 'next', 'week'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'baird',
#   'downgrade',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'neutral',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['there',
#   'have',
#   'been',
#   'acquisition',
#   'for',
#   'a',
#   'total',
#   'of',
#   'share',
#   'over',
#   'the',
#   'past',
#   'week',
#   'for'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['buy', 'zone'],
#  ['http',
#   'sputniknews',
#   'com',
#   'middleeast',
#   'saudi',
#   'arabia',
#   'wont',
#   'promise',
#   'trump',
#   'oil'],
#  ['fantastic',
#   'read',
#   'oil',
#   'market',
#   'continues',
#   'to',
#   'tighten',
#   'bbl',
#   'is',
#   'getting',
#   'closer',
#   'http',
#   'investoralmanac',
#   'com',
#   'oil',
#   'market',
#   'continues',
#   'to',
#   'tighten',
#   'is',
#   'getting',
#   'closer'],
#  ['one', 'of', 'the', 'greatest', 'buy'],
#  ['looking',
#   'at',
#   'the',
#   'yearly',
#   'performance',
#   'did',
#   'better',
#   'than',
#   'of',
#   'all',
#   'other',
#   'stock',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'ta',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'fosl',
#   'key',
#   'c',
#   'be',
#   'f',
#   'c',
#   'f',
#   'f',
#   'cdf'],
#  ['at',
#   'amp',
#   't',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'champion',
#   'cashflow',
#   'highyield',
#   'telecommunication',
#   'dividend'],
#  ['that',
#   's',
#   'a',
#   'pretty',
#   'risky',
#   'gamble',
#   'no',
#   'the',
#   'stock',
#   'can',
#   'either',
#   'plummet',
#   'or',
#   'rally'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['stronger'],
#  ['apple',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology',
#   'dividend'],
#  ['not', 'talking', 'about', 'i', 'wa', 'referring', 'to', 'intelsat'],
#  ['will',
#   'punish',
#   'seller',
#   'who',
#   'don',
#   't',
#   'move',
#   'stock',
#   'from',
#   'it',
#   'warehouse',
#   'common',
#   'sense',
#   'old',
#   'gather',
#   'dust',
#   'new',
#   'gather',
#   'money'],
#  ['pc',
#   'gamers',
#   'crypto',
#   'miner',
#   'and',
#   'other',
#   'gpu',
#   'enthusiast',
#   'have',
#   'been',
#   'waiting',
#   'over',
#   'two',
#   'year',
#   'for',
#   'the',
#   'company',
#   's',
#   'next',
#   'big',
#   'http',
#   'www',
#   'cnet',
#   'com',
#   'news',
#   'nvidia',
#   'geforce',
#   'gtx',
#   's',
#   'release',
#   'date',
#   'may',
#   'have',
#   'just',
#   'leaked'],
#  ['ha',
#   'only',
#   'a',
#   'medium',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'a',
#   'decent',
#   'setup',
#   'pattern',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'setup',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'mnk',
#   'key',
#   'd',
#   'a',
#   'd',
#   'c',
#   'adc',
#   'cbe',
#   'b',
#   'f',
#   'fb'],
#  ['today',
#   's',
#   'insight',
#   'on',
#   'http',
#   'app',
#   'seasonaledge',
#   'com',
#   'tool',
#   'i',
#   'dvn'],
#  ['what', 'will', 'be', 'more', 'in', 'five', 'year', 'baba', 'or', 'apple'],
#  ['next', 'week', 'ahhhhhhhhhhhhhhhhhhhhh'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['raytheon',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'industrials',
#   'military'],
#  ['why', 'we', 'trending'],
#  ['we',
#   'will',
#   'get',
#   'riiiiiiiiiich',
#   'sooooon',
#   'buuuuls',
#   'i',
#   'looooove',
#   'you',
#   'all',
#   'and',
#   'i',
#   'm',
#   'fucking',
#   'drunk'],
#  ['if',
#   'this',
#   'doesn',
#   't',
#   'get',
#   'through',
#   'it',
#   's',
#   'going',
#   'to',
#   'make',
#   'new',
#   'low',
#   'when',
#   'it',
#   'pay',
#   'the',
#   'dividend'],
#  ['gapping', 'up', 'monday'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['should',
#   'by',
#   'warbey',
#   'parker',
#   'for',
#   'b',
#   'in',
#   'prep',
#   'for',
#   'apple',
#   'glass',
#   'a',
#   'seen',
#   'with',
#   'watch',
#   'apple',
#   'focus',
#   'on',
#   'fashion',
#   'and',
#   'tech',
#   'wrt',
#   'wearable'],
#  ['look',
#   'like',
#   'sbux',
#   'is',
#   'paying',
#   'full',
#   'sex',
#   'change',
#   'for',
#   'employee',
#   'now',
#   'that',
#   'll',
#   'hit',
#   'the',
#   'bottom',
#   'line'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'run',
#   'up',
#   'to',
#   'other',
#   'trade',
#   'included',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam'],
#  ['b',
#   'enterprise',
#   'value',
#   'v',
#   'b',
#   'market',
#   'cap',
#   'a',
#   'difference',
#   'of',
#   'actual',
#   'asset',
#   'v',
#   'market',
#   'value',
#   'too',
#   'big',
#   'a',
#   'spread',
#   'way',
#   'undervalued'],
#  ['million', 'share', 'added', 'on', 'june', 'dont', 'wait'],
#  ['who',
#   'think',
#   'amazon',
#   'will',
#   'become',
#   'such',
#   'a',
#   'monopoly',
#   'dipping',
#   'into',
#   'everything',
#   'that',
#   'an',
#   'amazon',
#   'airline',
#   'is',
#   'a',
#   'possibility',
#   'i',
#   'do'],
#  ['don',
#   't',
#   'miss',
#   'the',
#   'breakout',
#   'on',
#   'buy',
#   'stop',
#   'stop',
#   'loss',
#   'is',
#   'suggested',
#   'by',
#   'the',
#   'chartmill',
#   'analyzer',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'tradingsetup',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'amd',
#   'key',
#   'eb',
#   'b',
#   'efcd',
#   'ba',
#   'de',
#   'f',
#   'd'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'resistance',
#   'other',
#   'trade',
#   'included',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'reversal',
#   'in',
#   'progress',
#   'other',
#   'trade',
#   'included',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy'],
#  ['i',
#   've',
#   'recently',
#   'closed',
#   'my',
#   'position',
#   'in',
#   'for',
#   'now',
#   'is',
#   'probably',
#   'next',
#   'on',
#   'the',
#   'list',
#   'i',
#   'bought',
#   'both',
#   'in',
#   'the',
#   'same',
#   'week'],
#  ['nat',
#   'ricciardi',
#   'is',
#   'director',
#   'used',
#   'to',
#   'be',
#   'president',
#   'of',
#   'global',
#   'manufacturing'],
#  ['according',
#   'to',
#   'data',
#   'reported',
#   'to',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'for',
#   'clocked',
#   'in',
#   'at',
#   'on',
#   'http',
#   'volumebot',
#   'com',
#   's',
#   'mpc'],
#  ['saudi',
#   'official',
#   'came',
#   'out',
#   'saying',
#   'they',
#   'didn',
#   't',
#   'agree',
#   'to',
#   'this'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'uptrend',
#   'to',
#   'resume',
#   'other',
#   'trade',
#   'included',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc'],
#  ['the',
#   'one',
#   'on',
#   'the',
#   'right',
#   'cover',
#   'the',
#   'penis',
#   'or',
#   'the',
#   'putang',
#   'the',
#   'front',
#   'leg',
#   'would',
#   'be',
#   'arm'],
#  ['http',
#   'pb',
#   'twimg',
#   'com',
#   'medium',
#   'dg',
#   'acn',
#   'xuaublcy',
#   'format',
#   'jpg',
#   'amp',
#   'name',
#   'medium'],
#  ['some', 'of', 'the', 'stock', 'i', 'am', 'watching', 'now'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'next',
#   'stop',
#   'other',
#   'trade',
#   'included',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri'],
#  ['i',
#   'wonder',
#   'how',
#   'much',
#   'this',
#   'will',
#   'be',
#   'valued',
#   'at',
#   'in',
#   'year',
#   'we',
#   'are',
#   'not',
#   'even',
#   'in',
#   'the',
#   'th',
#   'inning'],
#  ['ha',
#   'a',
#   'bad',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'a',
#   'decent',
#   'setup',
#   'pattern',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'setup',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'ge',
#   'key',
#   'b',
#   'dd',
#   'bca',
#   'd',
#   'e',
#   'c',
#   'f',
#   'fe',
#   'eb'],
#  ['is',
#   'going',
#   'to',
#   'make',
#   'a',
#   'big',
#   'move',
#   'higher',
#   'also',
#   'i',
#   'm',
#   'watching',
#   'apple',
#   'i',
#   'think',
#   'they',
#   'shorted',
#   'the',
#   'put',
#   'spread',
#   'for',
#   'july'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'consolidation',
#   'other',
#   'trade',
#   'included',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx'],
#  ['it',
#   's',
#   'good',
#   'that',
#   'even',
#   'bull',
#   'are',
#   'cautious',
#   'stunned',
#   'bearish',
#   'deeply',
#   'disappointed',
#   'too',
#   'bad',
#   'continues',
#   'it',
#   's',
#   'old',
#   'way',
#   'hopefully',
#   'we',
#   'are',
#   'close'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'other',
#   'trade',
#   'included',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn'],
#  ['ending', 'june', 'killed', 'it', 'best', 'month', 'since', 'february'],
#  ['funny',
#   'how',
#   'long',
#   'the',
#   'same',
#   'thing',
#   'ha',
#   'been',
#   'going',
#   'on',
#   'with',
#   'this',
#   'about',
#   'year',
#   'of',
#   'this',
#   'similar',
#   'story',
#   'different',
#   'day'],
#  ['bearish',
#   'crab',
#   'well',
#   'measured',
#   'bearish',
#   'crab',
#   'with',
#   'bearish',
#   'divergence',
#   'you',
#   'can',
#   'really',
#   'see',
#   'the',
#   'momentum',
#   'starting',
#   'to',
#   'shi'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'a',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['a',
#   'google',
#   'venture',
#   'company',
#   'http',
#   'www',
#   'outsideonline',
#   'com',
#   'outdoor',
#   'voice',
#   'ty',
#   'haney',
#   'queen',
#   'athleisure'],
#  ['tariff',
#   'increase',
#   'profit',
#   'how',
#   'can',
#   'it',
#   'be',
#   'bad',
#   'recession',
#   'if',
#   'it',
#   'come',
#   'is',
#   'year',
#   'down',
#   'the',
#   'line',
#   'keep',
#   'buying',
#   'short',
#   'r',
#   'pure',
#   'bull'],
#  ['beanscreen', 'for', 'q'],
#  ['the',
#   'min',
#   'chart',
#   'from',
#   'friday',
#   'indicating',
#   'some',
#   'nice',
#   'accumulation',
#   'at',
#   'eod',
#   'could',
#   'be',
#   'a',
#   'nice',
#   'pop',
#   'monday'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'at',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'heavy',
#   'resistance',
#   'at',
#   'other',
#   'trade',
#   'included',
#   'apog',
#   'acn',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo'],
#  ['can', 'we', 'squeeze', 'the', 'short'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'pullback',
#   'to',
#   'before',
#   'more',
#   'upside',
#   'other',
#   'trade',
#   'included',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog'],
#  ['still', 'holding', 'call', 'for', 'next', 'week'],
#  ['is', 'safe', 'but', 'their', 'buyback', 'yield', 'is', 'div', 'yield'],
#  ['adding',
#   'at',
#   'gladly',
#   'let',
#   'irrationality',
#   'reign',
#   'a',
#   'long',
#   'a',
#   'possible',
#   'excess',
#   'gain',
#   'are',
#   'welcome',
#   'gl'],
#  ['looking',
#   'at',
#   'friday',
#   's',
#   'data',
#   'i',
#   'm',
#   'seeing',
#   'different',
#   'story',
#   'on',
#   'the',
#   'chart',
#   'take',
#   'a',
#   'look',
#   'and',
#   'tell',
#   'me',
#   'what',
#   'you',
#   'think'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   't',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'given',
#   'the',
#   'price',
#   'action',
#   'http',
#   'www',
#   'shortpainbot',
#   'com',
#   's',
#   'nem'],
#  ['bouncing',
#   'off',
#   'support',
#   'need',
#   'continuation',
#   'next',
#   'week',
#   'make',
#   'me',
#   'feel',
#   'more',
#   'hopeful',
#   'for'],
#  ['data',
#   'science',
#   'officially',
#   'became',
#   'a',
#   'major',
#   'in',
#   'university',
#   'this',
#   'year',
#   'to',
#   'support',
#   'ai',
#   'industry',
#   'these',
#   'are',
#   'no',
#   'brainers',
#   'in',
#   'the',
#   'data',
#   'era'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  [],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'at',
#   'other',
#   'trade',
#   'included',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog',
#   'acn',
#   'camp'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  [],
#  ['ha',
#   'a',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'profitability',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   't',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'a',
#   'fe',
#   'e',
#   'ea',
#   'a',
#   'f',
#   'e',
#   'e',
#   'd'],
#  ['second', 'not', 'minute'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'rule',
#   'applies',
#   'here',
#   'other',
#   'trade',
#   'included',
#   'zbra',
#   'six',
#   'fc',
#   'gbx',
#   'fds',
#   'avav',
#   'baba'],
#  ['trump',
#   'is',
#   'killing',
#   'the',
#   'tax',
#   'cut',
#   'with',
#   'oil',
#   'price',
#   'and',
#   'tariff',
#   'no',
#   'idea',
#   'what',
#   'he',
#   's',
#   'doing',
#   'right',
#   'now'],
#  ['haven',
#   't',
#   'posted',
#   'on',
#   'stocktwits',
#   'in',
#   'a',
#   'while',
#   'these',
#   'weekly',
#   'chart',
#   'look',
#   'good',
#   'http',
#   'www',
#   'forexfactory',
#   'com',
#   'showthread',
#   'php',
#   'p',
#   'post'],
#  ['today',
#   's',
#   'insight',
#   'on',
#   'http',
#   'app',
#   'seasonaledge',
#   'com',
#   'tool',
#   'i',
#   'nem'],
#  ['omg', 'toy', 'story', 'land', 'look', 'amazing'],
#  ['stock',
#   'have',
#   'contributed',
#   'of',
#   'ytd',
#   'return',
#   'what',
#   'do',
#   'you',
#   'own'],
#  ['today',
#   's',
#   'insight',
#   'on',
#   'http',
#   'app',
#   'seasonaledge',
#   'com',
#   'tool',
#   'i',
#   'pfe'],
#  ['my', 'rd', 'most', 'popular', 'a', 'word'],
#  ['trump',
#   'tweet',
#   'and',
#   'then',
#   'he',
#   'may',
#   'be',
#   'buyin',
#   'those',
#   'dip',
#   'haha',
#   'still',
#   'makin',
#   'it',
#   'rain',
#   'up',
#   'in',
#   'the',
#   'white',
#   'house'],
#  ['ha',
#   'a',
#   'poor',
#   'technical',
#   'rating',
#   'and',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'setup',
#   'is',
#   'also',
#   'not',
#   'perfect',
#   'at',
#   'the',
#   'moment',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'ta',
#   'amp',
#   'utm',
#   'content',
#   'setup',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'gm',
#   'key',
#   'ae',
#   'fb',
#   'da',
#   'd',
#   'a',
#   'a',
#   'c',
#   'f',
#   'e'],
#  ['i',
#   'doubt',
#   'it',
#   'go',
#   'down',
#   'monday',
#   'and',
#   'i',
#   'doubt',
#   'saudi',
#   'arabia',
#   'increase',
#   'production'],
#  ['measured',
#   'over',
#   'the',
#   'past',
#   'year',
#   'show',
#   'a',
#   'very',
#   'strong',
#   'growth',
#   'in',
#   'eps',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'growth',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'amzn',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'e',
#   'e',
#   'a',
#   'd',
#   'a',
#   'b',
#   'c',
#   'd'],
#  ['b', 'constellation', 'brand'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   't',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'given',
#   'the',
#   'price',
#   'action',
#   'http',
#   'www',
#   'shortpainbot',
#   'com',
#   's',
#   'mpc'],
#  ['here'],
#  ['did',
#   'disney',
#   'just',
#   'clinch',
#   'the',
#   'deal',
#   'to',
#   'acquire',
#   'fox',
#   'http',
#   'themarketisopen',
#   'com',
#   'post',
#   'did',
#   'disney',
#   'just',
#   'clinch',
#   'the',
#   'deal',
#   'to',
#   'acquire',
#   'fox'],
#  ['new',
#   'way',
#   'match',
#   'group',
#   'can',
#   'counter',
#   'facebook',
#   'http',
#   'themarketisopen',
#   'com',
#   'post',
#   'new',
#   'way',
#   'match',
#   'group',
#   'can',
#   'counter',
#   'facebook'],
#  ['aggregate',
#   'short',
#   'volume',
#   'reported',
#   'to',
#   'finra',
#   'for',
#   'wa',
#   'on',
#   'http',
#   'volumebot',
#   'com',
#   's',
#   'nem'],
#  ['southwest',
#   'airline',
#   'is',
#   'adding',
#   'flight',
#   'in',
#   'dallas',
#   'a',
#   'delta',
#   'spat',
#   'continues',
#   'http',
#   'themarketisopen',
#   'com',
#   'post',
#   'southwest',
#   'airline',
#   'is',
#   'adding',
#   'flight',
#   'in',
#   'dallas',
#   'a',
#   'delta',
#   'spat',
#   'continues'],
#  ['what', 'california'],
#  ['better',
#   'buy',
#   'netflix',
#   'inc',
#   'nflx',
#   'versus',
#   'facebook',
#   'fb',
#   'http',
#   'themarketisopen',
#   'com',
#   'post',
#   'better',
#   'buy',
#   'netflix',
#   'inc',
#   'nflx',
#   'versus',
#   'facebook',
#   'fb'],
#  ['one',
#   'thing',
#   'that',
#   'starbucks',
#   'is',
#   'doing',
#   'wrong',
#   'http',
#   'themarketisopen',
#   'com',
#   'post',
#   'one',
#   'thing',
#   'that',
#   'starbucks',
#   'is',
#   'doing',
#   'wrong'],
#  [],
#  ['using',
#   'iex',
#   'data',
#   'we',
#   'calculate',
#   'that',
#   'shorters',
#   'have',
#   'lost',
#   'in',
#   'on',
#   'http',
#   'www',
#   'shortpainbot',
#   'com',
#   's',
#   'ftr'],
#  ['bull',
#   'list',
#   'after',
#   'their',
#   'emergence',
#   'from',
#   'bankruptcy',
#   'emergency'],
#  ['zwj',
#   'investment',
#   'counsel',
#   'inc',
#   'lower',
#   'stake',
#   'in',
#   'unitedhealth',
#   'group',
#   'inc',
#   'unh',
#   'http',
#   'stocknews',
#   'io',
#   'news',
#   'zwj',
#   'investment',
#   'counsel',
#   'inc',
#   'lower',
#   'stake',
#   'in',
#   'unitedhealth',
#   'group',
#   'inc',
#   'unh',
#   'weekherald',
#   'index',
#   'html'],
#  ['list',
#   'of',
#   'tyzen',
#   'and',
#   'vega',
#   'laptop',
#   'a',
#   'of',
#   'june',
#   'th',
#   'http',
#   'www',
#   'reddit',
#   'com',
#   'r',
#   'amd',
#   'comment',
#   'v',
#   'e',
#   'u',
#   'list',
#   'of',
#   'ryzen',
#   'and',
#   'vega',
#   'amd',
#   'laptop'],
#  ['i',
#   'm',
#   'investing',
#   'in',
#   'the',
#   'company',
#   'like',
#   'an',
#   'annuity',
#   'or',
#   'yr',
#   't',
#   'bond',
#   'i',
#   'continue',
#   'to',
#   'add',
#   'share',
#   'unsure',
#   'if',
#   'the',
#   'country',
#   'is',
#   'growing',
#   'amd',
#   'is'],
#  ['list',
#   'of',
#   'ryzen',
#   'and',
#   'vega',
#   'laptop',
#   'a',
#   'of',
#   'http',
#   'www',
#   'reddit',
#   'com',
#   'r',
#   'amd',
#   'comment',
#   'v',
#   'e',
#   'u',
#   'list',
#   'of',
#   'ryzen',
#   'and',
#   'vega',
#   'amd',
#   'laptop'],
#  ['gettin', 'a', 'blasted'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'strong',
#   'support',
#   'at',
#   'current',
#   'price',
#   'other',
#   'trade',
#   'included',
#   'cgnx',
#   'cx',
#   'aaoi',
#   'aa',
#   'amswa',
#   'yy',
#   'snx'],
#  ['bearish',
#   'shark',
#   'bearish',
#   'shark',
#   'with',
#   'bearish',
#   'divergence',
#   'i',
#   'am',
#   'definitely',
#   'jumping',
#   'into',
#   'the',
#   'august',
#   'put',
#   'on',
#   'monday'],
#  ['so',
#   'is',
#   'g',
#   'going',
#   'to',
#   'give',
#   'u',
#   'a',
#   'price',
#   'point',
#   'before',
#   'or',
#   'after',
#   'earnings'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['huge', 'volume', 'at', 'closing', 'on', 'friday'],
#  ['looking', 'for', 'scalp'],
#  ['this',
#   'is',
#   'one',
#   'giant',
#   'fermenting',
#   'turd',
#   'of',
#   'a',
#   'stock',
#   'when',
#   'will',
#   'it',
#   'go',
#   'back',
#   'up',
#   'to',
#   's'],
#  ['buffet', 'and', 'are', 'buying', 'at', 'per', 'share'],
#  ['in', 'put', 'from', 'last', 'week', 'target', 'zone', 'marked'],
#  ['option',
#   'volume',
#   'wa',
#   'x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'valuation',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'wfc',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'ccf',
#   'bb',
#   'a',
#   'f',
#   'b',
#   'cb',
#   'b',
#   'fe'],
#  ['the',
#   'eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'year',
#   'this',
#   'is',
#   'quite',
#   'good',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'growth',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'noc',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'c',
#   'eff',
#   'b',
#   'c',
#   'a',
#   'c',
#   'dc'],
#  ['mitch',
#   'did',
#   'a',
#   'great',
#   'job',
#   'of',
#   'getting',
#   'netflix',
#   'started',
#   'he',
#   'clearly',
#   'know',
#   'how',
#   'to',
#   'make',
#   'big',
#   'thing',
#   'happen',
#   'in',
#   'this',
#   'industry'],
#  ['cup',
#   'and',
#   'holder',
#   'inverse',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['with',
#   'a',
#   'debt',
#   'to',
#   'equity',
#   'ratio',
#   'of',
#   'is',
#   'doing',
#   'better',
#   'than',
#   'the',
#   'average',
#   'in',
#   'the',
#   'industry',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'health',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'dis',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'be',
#   'b',
#   'd',
#   'eea',
#   'a',
#   'cc',
#   'dc'],
#  ['sell',
#   'in',
#   'may',
#   'amp',
#   'go',
#   'away',
#   'ha',
#   'been',
#   'a',
#   'pattern',
#   'for',
#   'year',
#   'interesting',
#   'to',
#   'see',
#   'so',
#   'much',
#   'trading',
#   'in',
#   'this',
#   'time',
#   'frame',
#   'bank',
#   'love',
#   'you',
#   'trader'],
#  ['meanwhile', 'in', 'a', 'galaxy', 'far', 'far', 'away'],
#  ['broadening',
#   'wedge',
#   'descending',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['large', 'put', 'spread', 'in', 'open', 'interest', 'im', 'bearish'],
#  [],
#  ['pt'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy',
#   'fourth',
#   'everyone',
#   'have',
#   'a',
#   'coke',
#   'and',
#   'a',
#   'smile',
#   'thanks',
#   'for',
#   'the',
#   'dividend',
#   'and'],
#  [],
#  ['selling', 'will', 'prove', 'to', 'be', 'a', 'terrible', 'error'],
#  ['the',
#   'end',
#   'of',
#   'the',
#   'article',
#   'i',
#   'just',
#   'posted',
#   'hint',
#   'at',
#   'a',
#   'possible',
#   'acquisition',
#   'of',
#   'sogou',
#   'finger',
#   'crossed'],
#  ['triple',
#   'top',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['bro',
#   'that',
#   's',
#   'not',
#   'how',
#   'it',
#   'work',
#   'delete',
#   'the',
#   'blue',
#   'arrow',
#   'that',
#   's',
#   'your',
#   'delusion'],
#  ['let',
#   'me',
#   'guess',
#   'everyone',
#   'is',
#   'still',
#   'bullish',
#   'here',
#   'even',
#   'after',
#   'it',
#   'close',
#   'under',
#   'the',
#   'ma',
#   'on',
#   'the',
#   'daily',
#   'overbought',
#   'level',
#   'trend',
#   'is',
#   'changing'],
#  ['cup',
#   'and',
#   'holder',
#   'bullish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['mr', 'hold', 'yo'],
#  ['option',
#   'volume',
#   'wa',
#   'x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['hi',
#   'everyone',
#   'going',
#   'to',
#   'bed',
#   'good',
#   'night',
#   'everyone',
#   'happy',
#   'money',
#   'monday',
#   'soon',
#   'be',
#   'prepared'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['amazon',
#   's',
#   'new',
#   'warehouse',
#   'policy',
#   'will',
#   'start',
#   'penalizing',
#   'seller',
#   'that',
#   'store',
#   'product',
#   'for',
#   'too',
#   'long',
#   'http',
#   'cnb',
#   'cx',
#   'ibinab'],
#  ['just',
#   'fyi',
#   'trump',
#   'era',
#   'ramp',
#   'up',
#   'tech',
#   'worker',
#   'revolt',
#   'the',
#   'hill'],
#  ['this',
#   'company',
#   's',
#   'going',
#   'off',
#   'the',
#   'rail',
#   'the',
#   'people',
#   'that',
#   'work',
#   'there',
#   'and',
#   'the',
#   'store',
#   'manager',
#   'say',
#   'it',
#   'all',
#   'circuit',
#   'city',
#   'deux'],
#  ['why',
#   'did',
#   'bank',
#   'fail',
#   'to',
#   'rally',
#   'despite',
#   'huge',
#   'bb',
#   'and',
#   'div',
#   'incr',
#   'me',
#   'thinking',
#   'mm',
#   'driving',
#   'down',
#   'price',
#   'to',
#   'get',
#   'in',
#   'on',
#   'the',
#   'cheap',
#   'prior',
#   'the',
#   'rally'],
#  ['bear',
#   'using',
#   'all',
#   'argument',
#   'sound',
#   'like',
#   'short',
#   'position',
#   'are',
#   'becoming',
#   'loses',
#   'this',
#   'week'],
#  ['gameranx', 'popular', 'youtube', 'gaming', 'channel'],
#  ['facebook', 'the', 'cash', 'machine'],
#  ['and',
#   'it',
#   'will',
#   'take',
#   'all',
#   'semi',
#   's',
#   'up',
#   'more',
#   'week',
#   'and',
#   'then',
#   'uptrend',
#   'continues'],
#  ['cheap',
#   'dividend',
#   'champion',
#   'with',
#   'low',
#   'forward',
#   'p',
#   'e',
#   's',
#   'altria',
#   'aflac',
#   'eatonvance'],
#  ['look',
#   'at',
#   'the',
#   'graph',
#   'tripple',
#   'bottom',
#   'reached',
#   'for',
#   'heading',
#   'to',
#   'and',
#   'to',
#   'in',
#   'to',
#   'week'],
#  ['if',
#   'you',
#   'have',
#   'a',
#   'penis',
#   'and',
#   'want',
#   'a',
#   'vagina',
#   'like',
#   'alteration',
#   'go',
#   'get',
#   'a',
#   'job',
#   'at',
#   'sbux'],
#  ['oled',
#   'panel',
#   'post',
#   'steady',
#   'growth',
#   'amid',
#   'weak',
#   'demand',
#   'in',
#   'display',
#   'market',
#   'data'],
#  ['facebook',
#   'the',
#   'cash',
#   'machine',
#   'http',
#   'www',
#   'thestreet',
#   'com',
#   'investing',
#   'stock',
#   'facebook',
#   's',
#   'messenger',
#   'could',
#   'offer',
#   'a',
#   'cushy',
#   'boost',
#   'to',
#   'it',
#   'top',
#   'line',
#   'by'],
#  ['http',
#   'seekingalpha',
#   'com',
#   'article',
#   's',
#   'and',
#   'p',
#   'weekly',
#   'update',
#   'mid',
#   'year',
#   'review',
#   'different',
#   'market',
#   'setting',
#   'year',
#   'need',
#   'change',
#   'strategy',
#   'isdirectroadblock',
#   'true'],
#  ['option',
#   'volume',
#   'wa',
#   'x',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['microsoft',
#   'andromeda',
#   'leak',
#   'a',
#   'foldable',
#   'dual',
#   'screen',
#   'surface',
#   'device',
#   'that',
#   'fit',
#   'in',
#   'your',
#   'pocket',
#   'http',
#   'to',
#   'mac',
#   'com',
#   'foldable',
#   'microsoft',
# ...
#   'com',
#   'nyse',
#   'all',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['cxo',
#   'conchoresources',
#   'went',
#   'up',
#   'by',
#   'in',
#   'the',
#   'last',
#   'year',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'cxo',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'enterprise',
#   'value',
#   'to',
#   'ebitda',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply',
#   'http',
#   'www',
#   'chartmill',
#   'com',
#   'analyze',
#   'php',
#   'utm',
#   'source',
#   'stocktwits',
#   'amp',
#   'utm',
#   'medium',
#   'fa',
#   'amp',
#   'utm',
#   'content',
#   'valuation',
#   'amp',
#   'utm',
#   'campaign',
#   'social',
#   'tracking',
#   'wdc',
#   'r',
#   'fa',
#   'amp',
#   'key',
#   'ec',
#   'ac',
#   'a',
#   'f',
#   'fb',
#   'ac'],
#  ['bull',
#   'have',
#   'reason',
#   'on',
#   'to',
#   'pay',
#   'more',
#   'attention',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'hbi'],
#  ['qepresources',
#   'ha',
#   'a',
#   'very',
#   'high',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'qep',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'qep',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['ans',
#   'p',
#   'fcf',
#   'of',
#   'ansys',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'ans',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['coty',
#   'the',
#   'recommendation',
#   'mean',
#   'of',
#   'coty',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'coty',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['mtd',
#   'profit',
#   'margin',
#   'of',
#   'mettler',
#   'toledointernational',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'mtd',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['anyone', 'know', 'what', 'this', 'is', 'referring', 'to'],
#  ['gross',
#   'margin',
#   'of',
#   'motorolasolutions',
#   'is',
#   'msi',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'msi',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['operating',
#   'margin',
#   'of',
#   'michaelkors',
#   'is',
#   'kor',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'kor',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['allegionplc',
#   'is',
#   'overbought',
#   'according',
#   'to',
#   'it',
#   'stochastic',
#   'rsi',
#   'indicator',
#   'of',
#   'alle',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'alle',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['nlsn',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'nielsennv',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'nlsn',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['wpx',
#   'wpx',
#   'ha',
#   'a',
#   'rev',
#   'per',
#   'employee',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'wpx',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['whr',
#   'whirlpool',
#   'ha',
#   'a',
#   'dividend',
#   'yield',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'whr',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['chrw',
#   'chrobinsonworldwide',
#   'ha',
#   'a',
#   'short',
#   'of',
#   'float',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'chrw',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['the',
#   'recommendation',
#   'mean',
#   'of',
#   'wellsfargo',
#   'is',
#   'wfc',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'wfc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['ccl',
#   'carnival',
#   'ha',
#   'a',
#   'operating',
#   'margin',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'ccl',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['sma',
#   'of',
#   'pepsico',
#   'is',
#   'now',
#   'up',
#   'by',
#   'and',
#   'a',
#   'sma',
#   'is',
#   'now',
#   'down',
#   'by',
#   'pep',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'pep',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['pfe',
#   'pfizer',
#   'ha',
#   'a',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'pfe',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['so',
#   'funny',
#   'how',
#   'bear',
#   'disappear',
#   'from',
#   'to',
#   'but',
#   'it',
#   'pull',
#   'back',
#   'to',
#   'and',
#   'the',
#   'sky',
#   'is',
#   'falling',
#   'lollll',
#   'the',
#   'nature',
#   'of',
#   'stock',
#   'is',
#   'up',
#   'and',
#   'down'],
#  ['deltaairlines',
#   'ha',
#   'a',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'dal',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'dal',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['adtalemglobaleducation',
#   'ha',
#   'a',
#   'operating',
#   'margin',
#   'of',
#   'atge',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'atge',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['bsx',
#   'bostonscientific',
#   'ha',
#   'institutional',
#   'ownership',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'bsx',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['mck',
#   'mckesson',
#   'went',
#   'down',
#   'by',
#   'in',
#   'the',
#   'last',
#   'year',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'mck',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['pbct',
#   'peoplesunited',
#   'is',
#   'overbought',
#   'with',
#   'a',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'pbct',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['insider',
#   'ownership',
#   'of',
#   'vertexpharmaceuticalsorporated',
#   'is',
#   'vrtx',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'vrtx',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['bkng',
#   'volatility',
#   'of',
#   'booking',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'bkng',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['dis',
#   'waltdisney',
#   'ha',
#   'ppo',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'dis',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['abbottlaboratories',
#   'ha',
#   'insider',
#   'ownership',
#   'of',
#   'abt',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'abt',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['arthurjgallagherco',
#   'ha',
#   'a',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'ajg',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'ajg',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['disca',
#   'discoverycommunications',
#   'ha',
#   'a',
#   'gross',
#   'margin',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'disca',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['lyondellbasellindustriesnv',
#   'ha',
#   'a',
#   'weak',
#   'trend',
#   'according',
#   'to',
#   'it',
#   'adx',
#   'of',
#   'lyb',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'lyb',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['so',
#   'basically',
#   'the',
#   'vip',
#   's',
#   'and',
#   'premium',
#   'mass',
#   'aren',
#   't',
#   'spending',
#   'a',
#   'much',
#   'analyst',
#   'fooled',
#   'by',
#   'the',
#   'appearance',
#   'given',
#   'by',
#   'lower',
#   'quality',
#   'mass'],
#  ['skyworkssolutions',
#   'ha',
#   'institutional',
#   'ownership',
#   'of',
#   'swks',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'swks',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['edisoninternational',
#   'ha',
#   'a',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'eix',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'eix',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['wmb',
#   'williamscompanies',
#   'ha',
#   'a',
#   'volatility',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'wmb',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['is',
#   'the',
#   'competition',
#   'profitable',
#   'yes',
#   'are',
#   'they',
#   'collaboration',
#   'with',
#   'waymo',
#   'yes',
#   'do',
#   'they',
#   'have',
#   'cash',
#   'yes'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings',
#   'http',
#   't',
#   'co',
#   'hiag',
#   'kubxv'],
#  ['kroger',
#   'ha',
#   'a',
#   'very',
#   'high',
#   'roce',
#   'of',
#   'kr',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'kr',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['pcar',
#   'institutional',
#   'ownership',
#   'of',
#   'paccar',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'pcar',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['p',
#   'fcf',
#   'of',
#   'citrixsystems',
#   'is',
#   'ctxs',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'ctxs',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['profit',
#   'margin',
#   'of',
#   'verisign',
#   'is',
#   'vrsn',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'vrsn',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['honeywellinternational',
#   'ha',
#   'a',
#   'beta',
#   'of',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'hon',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'hon',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['the',
#   'dividend',
#   'yield',
#   'of',
#   'lincolnnational',
#   'is',
#   'lnc',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'lnc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['txn',
#   'texasinstrumentsorporated',
#   'ha',
#   'a',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'txn',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['tdc',
#   'short',
#   'percent',
#   'of',
#   'float',
#   'of',
#   'teradata',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'tdc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['sma',
#   'of',
#   'smithao',
#   'is',
#   'now',
#   'down',
#   'by',
#   'and',
#   'a',
#   'sma',
#   'is',
#   'now',
#   'down',
#   'by',
#   'aos',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'aos',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['idexxlaboratories',
#   'ha',
#   'a',
#   'operating',
#   'margin',
#   'of',
#   'idxx',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'idxx',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['bby',
#   'bestbuyco',
#   'ha',
#   'a',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'bby',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['masco',
#   'ha',
#   'a',
#   'gross',
#   'margin',
#   'of',
#   'ma',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'ma',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['the',
#   'payout',
#   'ratio',
#   'of',
#   'nike',
#   'is',
#   'nke',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'nke',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['len',
#   'lennar',
#   'rose',
#   'by',
#   'in',
#   'the',
#   'last',
#   'month',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'len',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['clf',
#   'the',
#   'roce',
#   'of',
#   'cliffsnaturalresources',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'clf',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['totalsystemservices',
#   'ha',
#   'a',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   'tss',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'tss',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['symantec',
#   'dipped',
#   'by',
#   'in',
#   'the',
#   'last',
#   'year',
#   'symc',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'symc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['rrc',
#   'rangeresources',
#   'went',
#   'down',
#   'by',
#   'in',
#   'the',
#   'last',
#   'month',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'rrc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['nsc',
#   'norfolksouther',
#   'ha',
#   'a',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'nsc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['the',
#   'return',
#   'on',
#   'capital',
#   'employed',
#   'of',
#   'accentureplc',
#   'is',
#   'acn',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'acn',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['willistowerswatsonpublic',
#   'is',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'a',
#   'beta',
#   'of',
#   'wltw',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'wltw',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['genworth',
#   'ha',
#   'institutional',
#   'ownership',
#   'of',
#   'gnw',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'gnw',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['martinmariettamaterials',
#   'ha',
#   'a',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'mlm',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'mlm',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['intc',
#   'operating',
#   'margin',
#   'of',
#   'intel',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'intc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['operating',
#   'margin',
#   'of',
#   'affiliatedmanagers',
#   'is',
#   'amg',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'amg',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['spgi',
#   'spglobal',
#   'ha',
#   'a',
#   'volatility',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'spgi',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['fbhs',
#   'beta',
#   'of',
#   'fortunebrandshomesecurity',
#   'is',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'fbhs',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['nwl',
#   'newellbrands',
#   'dipped',
#   'by',
#   'in',
#   'the',
#   'last',
#   'year',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'nwl',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['coopercompanies',
#   'ha',
#   'a',
#   'operating',
#   'margin',
#   'of',
#   'coo',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'coo',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['brighthouse',
#   'is',
#   'oversold',
#   'according',
#   'to',
#   'it',
#   'stoch',
#   'rsi',
#   'of',
#   'bhf',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'bhf',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['ebay',
#   'the',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'ebay',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'ebay',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['slg',
#   'operating',
#   'margin',
#   'of',
#   'slgreenrealty',
#   'is',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'slg',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['the',
#   'recommendation',
#   'mean',
#   'of',
#   'ppgindustries',
#   'is',
#   'ppg',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'ppg',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['tegna',
#   'dipped',
#   'by',
#   'in',
#   'the',
#   'last',
#   'month',
#   'tgna',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'tgna',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['dollargeneral',
#   'ha',
#   'a',
#   'gross',
#   'margin',
#   'of',
#   'dg',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'dg',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['beta',
#   'of',
#   'hess',
#   'make',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'he',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'he',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['insider',
#   'ownership',
#   'of',
#   'vulcanmaterials',
#   'is',
#   'vmc',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'vmc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['jpm',
#   'of',
#   'floating',
#   'share',
#   'of',
#   'jpmorganchaseco',
#   'are',
#   'being',
#   'shorted',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'jpm',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['beta',
#   'of',
#   'perrigo',
#   'is',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'prgo',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'prgo',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['mmc',
#   'marshmclennancompanies',
#   'ha',
#   'a',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'mmc',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['tsn',
#   'tysonfoods',
#   'ha',
#   'a',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'tsn',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['the',
#   'rpe',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'intercontinentalexchange',
#   'is',
#   'ice',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'ice',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['bectondickinsonand',
#   'ha',
#   'a',
#   'adx',
#   'of',
#   'hinting',
#   'it',
#   'weak',
#   'trend',
#   'bdx',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'bdx',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'fluor',
#   'is',
#   'flr',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'flr',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['pdco',
#   'pattersoncompanies',
#   'ha',
#   'a',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nasdaq',
#   'pdco',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['footlocker',
#   'rose',
#   'by',
#   'in',
#   'the',
#   'last',
#   'year',
#   'fl',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'fl',
#   'utm',
#   'source',
#   'stocktwits'],
#  ['we',
#   'have',
#   'detected',
#   'negative',
#   'indicator',
#   'a',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at',
#   'http',
#   'dividendbot',
#   'com',
#   's',
#   'aig'],
#  ['aph',
#   'amphenol',
#   'ha',
#   'a',
#   'p',
#   'fcf',
#   'of',
#   'http',
#   'wallmine',
#   'com',
#   'nyse',
#   'aph',
#   'utm',
#   'source',
#   'stocktwits'],
#  ...]

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
from collections import Counter


"""
Create a vocabulary by using Bag of words
"""

# TODO: Implement 

bow = Counter([word for word_list in tokenized for word in word_list])
for words in tokenized:
    bow.update(words)

# %%
# test
bow
# Out:
# Counter({'great': 35512,
#          'buy': 159444,
#          'at': 281306,
#          'ill': 1788,
#          'wait': 22822,
#          'staanalystalert': 8144,
#          'for': 563146,
#          'jefferies': 2398,
#          'maintains': 1848,
#          'with': 143270,
#          'a': 722154,
#          'rating': 32916,
#          'of': 436210,
#          'hold': 45308,
#          'setting': 7848,
#          'target': 36558,
#          'price': 80424,
#          'usd': 6006,
#          'our': 24660,
#          'own': 18268,
#          'verdict': 7494,
#          'is': 577432,
#          'i': 387264,
#          'heard': 2726,
#          'there': 52156,
#          's': 486210,
#          'guy': 26914,
#          'who': 36016,
#          'know': 40676,
#          'someone': 10390,
#          'think': 48796,
#          'somebody': 2200,
#          'something': 12100,
#          'on': 495172,
#          'stocktwits': 70694,
#          'reveal': 504,
#          'yourself': 2424,
#          'why': 46456,
#          'the': 813348,
#          'drop': 36434,
#          'warren': 2468,
#          'buffet': 2806,
#          'taking': 13078,
#          'out': 114854,
#          'his': 12720,
#          'position': 23842,
#          'bear': 67650,
#          'have': 106798,
#          'reason': 16110,
#          'to': 790424,
#          'pay': 15734,
#          'more': 113618,
#          'attention': 7126,
#          'http': 462942,
#          'dividendbot': 19104,
#          'com': 400038,
#          'ba': 5342,
#          'ok': 9230,
#          'good': 89160,
#          'we': 130172,
#          're': 27042,
#          'not': 138022,
#          'dropping': 4590,
#          'in': 424068,
#          'over': 66920,
#          'weekend': 7276,
#          'lol': 61896,
#          'daily': 32810,
#          'chart': 33956,
#          'need': 43868,
#          'get': 94618,
#          'back': 86942,
#          'above': 36486,
#          'per': 33392,
#          'week': 90108,
#          'after': 72226,
#          'spike': 4558,
#          'if': 118642,
#          'no': 81728,
#          'news': 97422,
#          'month': 34448,
#          'bo': 1306,
#          'then': 42030,
#          'bingo': 362,
#          'what': 160352,
#          'odds': 808,
#          'strong': 35388,
#          'short': 174320,
#          'ratio': 15628,
#          'and': 428386,
#          'float': 9314,
#          'via': 47032,
#          'squeezing': 460,
#          'perfect': 4058,
#          'place': 5812,
#          'an': 46616,
#          'option': 42020,
#          'straddle': 4468,
#          'near': 11990,
#          'supporting': 566,
#          'trend': 16634,
#          'start': 18232,
#          'new': 98498,
#          'q': 167696,
#          'monday': 15112,
#          'expect': 21186,
#          'volume': 87594,
#          'across': 1654,
#          'key': 56774,
#          'company': 47968,
#          'various': 172,
#          'sector': 10666,
#          'breakout': 13684,
#          'strategy': 3566,
#          'current': 12636,
#          'portfolio': 5318,
#          'bull': 54858,
#          'pfe': 1192,
#          'catalyst': 2646,
#          'continuing': 720,
#          'this': 409166,
#          'uptrend': 3410,
#          'pill': 402,
#          'pack': 408,
#          'amazon': 28352,
#          'prime': 4160,
#          'day': 136670,
#          'earnings': 114680,
#          'test': 8392,
#          'break': 34598,
#          'soon': 32584,
#          'ha': 90774,
#          'moved': 6754,
#          'check': 11026,
#          'movement': 6088,
#          'peer': 6538,
#          'aapl': 10848,
#          'mkm': 428,
#          'partner': 3330,
#          'set': 13416,
#          'it': 393382,
#          'too': 38404,
#          'early': 9816,
#          'tell': 9524,
#          'going': 96370,
#          'happen': 8588,
#          'even': 31992,
#          'about': 56732,
#          'raisinf': 2,
#          'output': 328,
#          'still': 71288,
#          'so': 92892,
#          'many': 19038,
#          'financially': 1162,
#          'healthy': 3662,
#          'problem': 5792,
#          'meeting': 2232,
#          'obligation': 1342,
#          'www': 193784,
#          'chartmill': 39044,
#          'analyze': 39122,
#          'php': 39880,
#          'utm': 208028,
#          'source': 88710,
#          'amp': 257672,
#          'medium': 56720,
#          'fa': 49224,
#          'content': 42758,
#          'health': 10064,
#          'campaign': 47588,
#          'social': 42608,
#          'tracking': 39062,
#          'nke': 2234,
#          'r': 46946,
#          'fee': 1634,
#          'd': 67580,
#          'b': 86866,
#          'f': 66084,
#          'e': 53652,
#          'bullish': 51672,
#          'stock': 197282,
#          'watch': 36014,
#          'setup': 23360,
#          'timeframes': 82,
#          'seeitmarket': 458,
#          'twitter': 6436,
#          'twtr': 1046,
#          'michael': 2684,
#          'kor': 784,
#          'blog': 5770,
#          'by': 112974,
#          'just': 147450,
#          'high': 58688,
#          'alert': 26950,
#          'next': 95472,
#          'gt': 19094,
#          'breakdown': 2278,
#          'much': 33654,
#          'better': 28228,
#          'than': 59434,
#          'industry': 16374,
#          'average': 18788,
#          'fslr': 640,
#          'cf': 4038,
#          'ec': 2568,
#          'be': 196912,
#          'miss': 14960,
#          'these': 28896,
#          'confirms': 1034,
#          'you': 190640,
#          'will': 258952,
#          'see': 90284,
#          'violent': 294,
#          'move': 46156,
#          'downward': 1680,
#          'my': 102982,
#          'cv': 1788,
#          'base': 3040,
#          'gap': 19646,
#          'ma': 11516,
#          'cabot': 244,
#          'weekly': 14650,
#          'video': 8690,
#          'quot': 80214,
#          'resilient': 288,
#          'growth': 82300,
#          'bit': 13348,
#          'ly': 5308,
#          'kj': 114,
#          'fnd': 8,
#          'when': 60342,
#          'wa': 110860,
#          'kid': 3448,
#          'froend': 2,
#          'told': 7714,
#          'me': 53752,
#          'moon': 4548,
#          'made': 15858,
#          'cheese': 248,
#          'percent': 13888,
#          'rank': 10746,
#          'th': 14132,
#          'percentile': 2798,
#          'volumebot': 13474,
#          'uri': 448,
#          'thank': 8256,
#          'don': 51044,
#          't': 169762,
#          'feel': 12034,
#          'or': 76246,
#          'do': 50080,
#          'well': 33902,
#          'they': 113054,
#          'already': 19428,
#          'during': 5264,
#          'youtube': 6444,
#          'interview': 1406,
#          'mitch': 134,
#          'couldn': 2514,
#          'remember': 9660,
#          'single': 4660,
#          'movie': 1896,
#          'he': 24008,
#          'watched': 800,
#          'all': 121480,
#          'year': 70712,
#          'except': 2286,
#          'star': 5112,
#          'war': 11384,
#          'black': 2684,
#          'panther': 52,
#          'clothes': 238,
#          'downgrade': 9162,
#          'sale': 56376,
#          'interest': 23922,
#          'return': 14502,
#          'equity': 18190,
#          'profitability': 10146,
#          'k': 48562,
#          'c': 62268,
#          'although': 3738,
#          'market': 116056,
#          'up': 245520,
#          'doing': 11140,
#          'advanced': 3408,
#          'info': 8412,
#          'txn': 1000,
#          'july': 7486,
#          'most': 17184,
#          'x': 31682,
#          'normal': 3274,
#          'friday': 22604,
#          'contract': 29252,
#          'call': 136826,
#          'put': 74280,
#          'third': 4192,
#          'design': 1356,
#          'win': 12488,
#          'timing': 1344,
#          'match': 904,
#          'probably': 10170,
#          'arm': 702,
#          'forbes': 1328,
#          'site': 3086,
#          'ewanspence': 8,
#          'surface': 546,
#          'andromeda': 14,
#          'windowsphone': 2,
#          'window': 1008,
#          'tablet': 254,
#          'leak': 1276,
#          'rumor': 2568,
#          'spec': 598,
#          'release': 12522,
#          'date': 8080,
#          'bec': 110,
#          'alcohol': 158,
#          'tobacco': 358,
#          'firearm': 6,
#          'chc': 120,
#          'li': 332,
#          'kdqyur': 2,
#          'president': 6132,
#          'trump': 26126,
#          'tweet': 3418,
#          'spoke': 346,
#          'king': 2724,
#          'salman': 16,
#          'saudi': 1956,
#          'arabia': 472,
#          'explained': 250,
#          'him': 4226,
#          'that': 180698,
#          'because': 16020,
#          'turmoil': 282,
#          'today': 153422,
#          'insight': 17334,
#          'app': 33188,
#          'seasonaledge': 18218,
#          'tool': 19422,
#          'tap': 1622,
#          'intc': 5738,
#          'mama': 308,
#          'said': 19304,
#          'ice': 1190,
#          'cream': 238,
#          'finish': 2354,
#          'due': 7814,
#          'dil': 16,
#          'noticed': 730,
#          'last': 84138,
#          'jedi': 384,
#          'stream': 1266,
#          'love': 21004,
#          'here': 151200,
#          'go': 106348,
#          'leave': 2784,
#          'view': 10788,
#          'look': 63632,
#          'ema': 2784,
#          'held': 5668,
#          'stochastics': 146,
#          'turning': 2392,
#          'spy': 4470,
#          'qqq': 1326,
#          'opposite': 1754,
#          'forward': 6908,
#          'pe': 9222,
#          'valuation': 13708,
#          'can': 89548,
#          'described': 692,
#          'cheap': 15956,
#          'mu': 21064,
#          'fbab': 758,
#          'daf': 854,
#          'saber': 34,
#          'capital': 7294,
#          'presentation': 1366,
#          'common': 3106,
#          'denominator': 26,
#          'tencent': 422,
#          'facebook': 23566,
#          'google': 11772,
#          'investoralmanac': 810,
#          'how': 50876,
#          'u': 81458,
#          'one': 56084,
#          'performing': 1980,
#          'crude': 1426,
#          'petroleum': 570,
#          'natural': 1586,
#          'gas': 3868,
#          'ta': 24210,
#          'dnr': 1264,
#          'ff': 2372,
#          'aa': 2578,
#          'pu': 128,
#          'simply': 1278,
#          'havent': 432,
#          'lost': 9190,
#          'any': 28918,
#          'brown': 530,
#          'run': 32024,
#          'tech': 22328,
#          'mf': 704,
#          'are': 205508,
#          'educated': 230,
#          'n': 14650,
#          'their': 48912,
#          'shit': 12828,
#          'every': 18040,
#          'former': 1052,
#          'global': 6142,
#          'manufacturing': 914,
#          'pfizer': 1210,
#          'independent': 408,
#          'director': 11086,
#          'nat': 282,
#          'ricciardi': 8,
#          'may': 23556,
#          'safest': 314,
#          'special': 1350,
#          'limited': 1214,
#          'offer': 3584,
#          'june': 2816,
#          'tradenet': 12,
#          'offering': 1632,
#          'discount': 3028,
#          'intro': 122,
#          'program': 2400,
#          'limitedtime': 2,
#          'id': 5796,
#          'o': 10996,
#          'pnwd': 2,
#          'affiliateorg': 2,
#          'affiliateid': 2,
#          'affiliatedata': 2,
#          'below': 22896,
#          'financials': 2324,
#          'summary': 2670,
#          'jeff': 1604,
#          'gundlach': 126,
#          'sohn': 50,
#          'long': 65864,
#          'thesis': 2046,
#          'energy': 7724,
#          'jeffrey': 610,
#          'low': 47730,
#          'peg': 1240,
#          'which': 16574,
#          'compensates': 592,
#          'indicates': 3996,
#          'rather': 4748,
#          'hpq': 374,
#          'ac': 3488,
#          'fe': 3590,
#          'pres': 708,
#          'coming': 38392,
#          'seems': 10832,
#          'support': 35206,
#          'under': 18584,
#          'likely': 7542,
#          'wba': 920,
#          'bullshit': 1750,
#          'worthless': 2058,
#          'mean': 12650,
#          'fucking': 4776,
#          'nothing': 14090,
#          'macau': 640,
#          'usa': 2452,
#          'take': 36616,
#          'let': 54082,
#          'where': 25050,
#          'right': 38620,
#          'now': 116624,
#          'ugly': 3734,
#          'without': 4814,
#          'clear': 5424,
#          'level': 19512,
#          'term': 42560,
#          'bearish': 23602,
#          'll': 26380,
#          'previously': 4084,
#          'mo': 2732,
#          'followed': 1974,
#          'end': 32206,
#          'another': 28504,
#          'runup': 382,
#          'dropped': 5948,
#          'smart': 6926,
#          'money': 50916,
#          'betting': 1862,
#          'deal': 15260,
#          'update': 42534,
#          'uk': 1768,
#          'reuters': 2302,
#          'article': 21576,
#          'indonesia': 212,
#          'rio': 132,
#          'tinto': 14,
#          'grasberg': 74,
#          'inalum': 20,
#          'close': 59370,
#          'acquiring': 256,
#          'copper': 710,
#          'mine': 1248,
#          'official': 1120,
#          'idukkbn': 22,
#          'jq': 46,
#          'h': 8606,
#          'technical': 30196,
#          'bad': 26858,
#          'doe': 22604,
#          'present': 5164,
#          'nice': 34710,
#          'opportunity': 12224,
#          'wynn': 2006,
#          'ceb': 316,
#          'da': 5824,
#          'bc': 4314,
#          'completely': 2086,
#          'scale': 796,
#          'time': 80464,
#          'gobble': 214,
#          'play': 19328,
#          'aka': 674,
#          'favorite': 1836,
#          'them': 22208,
#          'iddy': 2,
#          'bitty': 20,
#          'kiddy': 66,
#          'hand': 7594,
#          'awesome': 3706,
#          'concerned': 1118,
#          'eow': 4218,
#          'might': 18132,
#          'wk': 2644,
#          'throwback': 124,
#          'advisor': 586,
#          'upgrade': 14408,
#          'shorties': 1618,
#          'dreaming': 464,
#          'depression': 298,
#          'somethin': 54,
#          'loll': 96,
#          'updated': 1814,
#          'hormel': 294,
#          'food': 3510,
#          'dividend': 18552,
#          'analysis': 16274,
#          'consumer': 4496,
#          'defensive': 604,
#          'dal': 1028,
#          'intel': 20036,
#          'safety': 2374,
#          'score': 5516,
#          'technology': 9386,
#          'mpc': 508,
#          'both': 12554,
#          'positive': 18522,
#          'looking': 36086,
#          'chk': 3084,
#          'df': 2452,
#          'cb': 5166,
#          'ddbd': 354,
#          'mad': 2536,
#          'report': 125200,
#          'block': 20000,
#          'person': 1412,
#          'spam': 564,
#          'should': 49174,
#          'open': 42242,
#          'projection': 572,
#          'thats': 4554,
#          'true': 4526,
#          'prefer': 732,
#          'from': 131180,
#          'turd': 2160,
#          'wal': 270,
#          'mart': 320,
#          'aristocrat': 636,
#          'valueinvesting': 106,
#          'dvb': 46,
#          'aaamp': 56,
#          'marriage': 80,
#          'm': 108292,
#          'bank': 16828,
#          'account': 5898,
#          'dm': 218,
#          'won': 10974,
#          'stop': 25902,
#          'posting': 2602,
#          'holding': 30226,
#          'big': 57480,
#          'calm': 1864,
#          'down': 139740,
#          'luck': 6856,
#          'chase': 2896,
#          'continues': 5558,
#          'hopefully': 5236,
#          'catch': 3554,
#          'before': 52186,
#          'lisa': 6340,
#          'announces': 8256,
#          'rd': 2960,
#          'bbby': 544,
#          'bb': 9628,
#          'afa': 478,
#          'ecc': 154,
#          'ace': 412,
#          'permamently': 2,
#          'turned': 2760,
#          'off': 43508,
#          'trading': 43538,
#          'maybe': 15676,
#          'altogether': 52,
#          'manipulation': 5138,
#          'very': 40268,
#          'rich': 3294,
#          'make': 40814,
#          'poor': 3826,
#          'fuk': 452,
#          'almost': 11306,
#          'pct': 1534,
#          'buyback': 10482,
#          'got': 32592,
#          'share': 102984,
#          'though': 8260,
#          'drip': 648,
#          'hollywoodreporter': 28,
#          'thr': 114,
#          'esq': 8,
#          'netflix': 13216,
#          'green': 36898,
#          'light': 2834,
#          'appeal': 834,
#          'court': 1454,
#          'challenge': 1312,
#          'fox': 1920,
#          'employment': 182,
#          'sailthru': 2,
#          'email': 1516,
#          'breaking': 6344,
#          'ehayden': 2,
#          'breakingnews': 8,
#          'dumped': 2164,
#          'obv': 362,
#          'but': 108138,
#          'jeez': 678,
#          'done': 11042,
#          'bounce': 23392,
#          'heikin': 20,
#          'ashi': 24,
#          'candle': 6534,
#          'confirmation': 1486,
#          'liking': 838,
#          'wife': 1320,
#          'tree': 1116,
#          'fiddy': 64,
#          'sure': 16714,
#          'piggy': 540,
#          'lot': 20222,
#          'coin': 820,
#          'spend': 1700,
#          'candy': 226,
#          'microsoft': 5718,
#          'investor': 20100,
#          'aren': 3390,
#          'happy': 8764,
#          'shortpainbot': 7188,
#          'shld': 1310,
#          'royal': 906,
#          'canada': 3086,
#          'reiterates': 3802,
#          'outperform': 4146,
#          'loop': 690,
#          'raise': 15352,
#          'never': 18130,
#          'been': 39894,
#          'wrong': 11430,
#          'miracle': 632,
#          'period': 2410,
#          'bollinger': 3000,
#          'band': 3360,
#          'dare': 710,
#          'say': 36860,
#          'didn': 11866,
#          'guilty': 208,
#          'fudge': 130,
#          'cvx': 776,
#          'hardly': 510,
#          'ever': 11482,
#          'informative': 66,
#          'comment': 5120,
#          'page': 2672,
#          'broken': 3218,
#          'giving': 3634,
#          'endless': 468,
#          'buffering': 8,
#          'icon': 400,
#          'give': 15790,
#          'viral': 42,
#          'walk': 2258,
#          'away': 9800,
#          'highlight': 736,
#          'growing': 4714,
#          'democrat': 588,
#          'leaving': 1838,
#          'party': 3540,
#          'epoch': 4,
#          'theepochtimes': 10,
#          'html': 27364,
#          'robert': 2040,
#          'w': 25060,
#          'baird': 1604,
#          'neutral': 7628,
#          'weed': 1506,
#          'other': 17358,
#          'drug': 3126,
#          'guess': 11860,
#          'reasonable': 1242,
#          'eb': 2918,
#          'ab': 1846,
#          'fd': 3524,
#          'nike': 9068,
#          'winning': 4364,
#          'click': 2188,
#          'booking': 1740,
#          'native': 48,
#          'seamless': 24,
#          'lovalized': 2,
#          'transactable': 2,
#          'ap': 226,
#          'vitiello': 2,
#          'tapped': 256,
#          'acting': 1548,
#          'reach': 4206,
#          'iconic': 154,
#          'brand': 4774,
#          'built': 962,
#          'mobile': 2812,
#          'show': 20182,
#          'morning': 22802,
#          'heading': 5648,
#          'ath': 6292,
#          'acquisition': 4302,
#          'total': 12314,
#          'past': 16710,
#          'exit': 3054,
#          'zone': 3234,
#          'sputniknews': 22,
#          'middleeast': 16,
#          'wont': 3160,
#          'promise': 944,
#          'oil': 12042,
#          'fantastic': 1164,
#          'read': 7826,
#          'tighten': 742,
#          'bbl': 312,
#          'getting': 24984,
#          'closer': 2368,
#          'greatest': 862,
#          'yearly': 2484,
#          'performance': 4800,
#          'did': 25442,
#          'fosl': 418,
#          'cdf': 126,
#          'champion': 360,
#          'cashflow': 150,
#          'highyield': 46,
#          'telecommunication': 34,
#          'pretty': 9028,
#          'risky': 1478,
#          'gamble': 1780,
#          'either': 6478,
#          'plummet': 696,
#          'rally': 13112,
#          'stronger': 1776,
#          'apple': 32908,
#          'talking': 5558,
#          'referring': 216,
#          'intelsat': 14,
#          'punish': 256,
#          'seller': 6376,
#          'warehouse': 222,
#          'sense': 4460,
#          'old': 7814,
#          'gather': 314,
#          'dust': 896,
#          'pc': 1802,
#          'gamers': 466,
#          'crypto': 3728,
#          'miner': 386,
#          'gpu': 3096,
#          'enthusiast': 64,
#          'waiting': 14546,
#          'two': 11658,
#          'cnet': 218,
#          'nvidia': 8294,
#          'geforce': 450,
#          'gtx': 330,
#          'leaked': 884,
#          'only': 38298,
#          'decent': 5870,
#          'pattern': 13292,
#          'mnk': 664,
#          'adc': 208,
#          'cbe': 174,
#          'fb': 22190,
#          'dvn': 502,
#          'five': 1718,
#          'baba': 1178,
#          'ahhhhhhhhhhhhhhhhhhhhh': 2,
#          'raytheon': 500,
#          'industrials': 646,
#          'military': 780,
#          'trending': 3986,
#          'riiiiiiiiiich': 2,
#          'sooooon': 22,
#          'buuuuls': 2,
#          'looooove': 8,
#          'drunk': 420,
#          'doesn': 12624,
#          'through': 12520,
#          'gapping': 572,
#          'warbey': 2,
#          'parker': 434,
#          'prep': 230,
#          'glass': 664,
#          'seen': 7980,
#          'focus': 2556,
#          'fashion': 504,
#          'wrt': 32,
#          'wearable': 246,
#          'like': 104474,
#          'sbux': 1514,
#          'paying': 3134,
#          'full': 6260,
#          'sex': 404,
#          'change': 10782,
#          'employee': 2508,
#          'hit': 26096,
#          'bottom': 19640,
#          'line': 14928,
#          'recap': 3000,
#          'since': 45588,
#          'post': 27874,
#          'trade': 103054,
#          'included': 758,
#          'hsy': 316,
#          'sonc': 22,
#          'dri': 514,
#          'kmx': 266,
#          'akam': 356,
#          'enterprise': 2834,
#          'value': 12026,
#          'v': 24126,
#          'cap': 8582,
#          'difference': 1238,
#          'actual': 1302,
#          'asset': 4102,
#          'spread': 4970,
#          'way': 33650,
#          'undervalued': 5216,
#          'million': 14096,
#          'added': 11200,
#          'dont': 12784,
#          'become': 3444,
#          'such': 5840,
#          'monopoly': 678,
#          'dipping': 618,
#          'into': 35584,
#          'everything': 8660,
#          'airline': 2372,
#          'possibility': 958,
#          'loss': 15892,
#          'suggested': 648,
#          'analyzer': 1040,
#          'tradingsetup': 1400,
#          'amd': 57222,
#          'efcd': 676,
#          'de': 5004,
#          'resistance': 14474,
#          'len': 710,
#          'reversal': 9902,
#          'progress': 1216,
#          've': 13594,
#          'recently': 1694,
#          'closed': 6750,
#          'list': 7484,
#          'bought': 38386,
#          'same': 24256,
#          'used': 3642,
#          'according': 4194,
#          'data': 29634,
#          'reported': 28386,
#          'finra': 5534,
#          'clocked': 1416,
#          'came': 3268,
#          'saying': 8146,
#          'agree': 3174,
#          'resume': 1202,
#          'cover': 11834,
#          'penis': 100,
#          'putang': 2,
#          'front': 1182,
#          'leg': 4900,
#          'would': 45038,
#          'pb': 430,
#          'twimg': 26,
#          'dg': 724,
#          'acn': 380,
#          'xuaublcy': 2,
#          'format': 100,
#          'jpg': 104,
#          'name': 7170,
#          'some': 61396,
#          'am': 28910,
#          'watching': 11198,
#          'wonder': 6008,
#          'valued': 3346,
#          'inning': 152,
#          'ge': 10382,
#          'dd': 4800,
#          'bca': 626,
#          'higher': 52046,
#          'also': 15870,
#          'shorted': 5990,
#          'consolidation': 4076,
#          'cautious': 1118,
#          'stunned': 90,
#          'deeply': 206,
#          'disappointed': 922,
#          'ending': 2508,
#          'killed': 2484,
#          'best': 21760,
#          'february': 828,
#          'funny': 5056,
#          'thing': 25804,
#          'similar': 2300,
#          'story': 10492,
#          'different': 3242,
#          'crab': 78,
#          'measured': 978,
#          'divergence': 1558,
#          'really': 22744,
#          'momentum': 7186,
#          'starting': 6642,
#          'shi': 120,
#          'venture': 788,
#          'outsideonline': 2,
#          'outdoor': 42,
#          'voice': 810,
#          'ty': 588,
#          'haney': 2,
#          'queen': 194,
#          'athleisure': 36,
#          'tariff': 18032,
#          'increase': 8526,
#          'profit': 33444,
#          'recession': 2128,
#          'come': 37316,
#          'keep': 30500,
#          'buying': 48326,
#          'pure': 1884,
#          'beanscreen': 4,
#          'min': 11462,
#          'indicating': 866,
#          'accumulation': 1464,
#          'eod': 10352,
#          'could': 35024,
#          'pop': 15332,
#          'heavy': 3470,
#          'apog': 14,
#          'camp': 130,
#          'gi': 670,
#          'payx': 288,
#          'fdx': 956,
#          'goo': 9136,
#          'squeeze': 11434,
#          'pullback': 9362,
#          'upside': 10830,
#          'nvda': 8668,
#          'safe': 4082,
#          'yield': 5422,
#          'div': 4424,
#          'adding': 5986,
#          'gladly': 182,
#          'irrationality': 50,
#          'reign': 82,
#          'possible': 8474,
#          'excess': 132,
#          'gain': 24708,
#          'welcome': 2730,
#          'gl': 14918,
#          'seeing': 5214,
#          'jumping': 1424,
#          'joy': 572,
#          'least': 11094,
#          'given': 6068,
#          ...})

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the **number of messages** calculated in the code block above (i.e. `len(messages))`. Then remove words that only appear in some small fraction of the messages.
#
# >Note: There is not an exact number for low and high-frequency cut-offs, however there is a correct optimal range.
# You should ideally set up low-frequency cut-off from 0.0000002 to 0.000007 (inclusive) and high-frequency from 5 to 20 (inclusive). If the number is too big, we lose lots of important words that we can use in our data.

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""

# TODO Implement 

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
freqs = {word: bow[word]/len(messages) for word in bow}

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff =  0.00000002#pass

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 100000 #pass

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = set([k for k,v in bow.items() if v >= high_cutoff])



filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# {'utm', 'market', 'm', 'earnings', 'amp', 'down', 'wa', 'all', 'day', 'call', 'what', 'a', 'buy', 'stock', 'trade', 'by', 'here', 'this', 'have', 'not', 'that', 'at', 'in', 'if', 'q', 'of', 'we', 'estimize', 'now', 'share', 'more', 'to', 'on', 'the', 'it', 'be', 't', 'for', 'com', 'www', 'my', 'they', 'but', 'are', 'and', 'like', 'analyst', 'short', 'http', 'you', 'is', 's', 'with', 'go', 'report', 'from', 'today', 'i', 'just', 'out', 'up', 'will'}
# 130565

# %%
filtered_words
# Out:
# ['great',
#  'ill',
#  'wait',
#  'staanalystalert',
#  'jefferies',
#  'maintains',
#  'rating',
#  'hold',
#  'setting',
#  'target',
#  'price',
#  'usd',
#  'our',
#  'own',
#  'verdict',
#  'heard',
#  'there',
#  'guy',
#  'who',
#  'know',
#  'someone',
#  'think',
#  'somebody',
#  'something',
#  'stocktwits',
#  'reveal',
#  'yourself',
#  'why',
#  'drop',
#  'warren',
#  'buffet',
#  'taking',
#  'his',
#  'position',
#  'bear',
#  'reason',
#  'pay',
#  'attention',
#  'dividendbot',
#  'ba',
#  'ok',
#  'good',
#  're',
#  'dropping',
#  'over',
#  'weekend',
#  'lol',
#  'daily',
#  'chart',
#  'need',
#  'get',
#  'back',
#  'above',
#  'per',
#  'week',
#  'after',
#  'spike',
#  'no',
#  'news',
#  'month',
#  'bo',
#  'then',
#  'bingo',
#  'odds',
#  'strong',
#  'ratio',
#  'float',
#  'via',
#  'squeezing',
#  'perfect',
#  'place',
#  'an',
#  'option',
#  'straddle',
#  'near',
#  'supporting',
#  'trend',
#  'start',
#  'new',
#  'monday',
#  'expect',
#  'volume',
#  'across',
#  'key',
#  'company',
#  'various',
#  'sector',
#  'breakout',
#  'strategy',
#  'current',
#  'portfolio',
#  'bull',
#  'pfe',
#  'catalyst',
#  'continuing',
#  'uptrend',
#  'pill',
#  'pack',
#  'amazon',
#  'prime',
#  'test',
#  'break',
#  'soon',
#  'ha',
#  'moved',
#  'check',
#  'movement',
#  'peer',
#  'aapl',
#  'mkm',
#  'partner',
#  'set',
#  'too',
#  'early',
#  'tell',
#  'going',
#  'happen',
#  'even',
#  'about',
#  'raisinf',
#  'output',
#  'still',
#  'so',
#  'many',
#  'financially',
#  'healthy',
#  'problem',
#  'meeting',
#  'obligation',
#  'chartmill',
#  'analyze',
#  'php',
#  'source',
#  'medium',
#  'fa',
#  'content',
#  'health',
#  'campaign',
#  'social',
#  'tracking',
#  'nke',
#  'r',
#  'fee',
#  'd',
#  'b',
#  'f',
#  'e',
#  'bullish',
#  'watch',
#  'setup',
#  'timeframes',
#  'seeitmarket',
#  'twitter',
#  'twtr',
#  'michael',
#  'kor',
#  'blog',
#  'high',
#  'alert',
#  'next',
#  'gt',
#  'breakdown',
#  'much',
#  'better',
#  'than',
#  'industry',
#  'average',
#  'fslr',
#  'cf',
#  'ec',
#  'miss',
#  'these',
#  'confirms',
#  'see',
#  'violent',
#  'move',
#  'downward',
#  'cv',
#  'base',
#  'gap',
#  'ma',
#  'cabot',
#  'weekly',
#  'video',
#  'quot',
#  'resilient',
#  'growth',
#  'bit',
#  'ly',
#  'kj',
#  'fnd',
#  'when',
#  'kid',
#  'froend',
#  'told',
#  'me',
#  'moon',
#  'made',
#  'cheese',
#  'percent',
#  'rank',
#  'th',
#  'percentile',
#  'volumebot',
#  'uri',
#  'thank',
#  'don',
#  'feel',
#  'or',
#  'do',
#  'well',
#  'already',
#  'during',
#  'youtube',
#  'interview',
#  'mitch',
#  'couldn',
#  'remember',
#  'single',
#  'movie',
#  'he',
#  'watched',
#  'year',
#  'except',
#  'star',
#  'war',
#  'black',
#  'panther',
#  'clothes',
#  'downgrade',
#  'sale',
#  'interest',
#  'return',
#  'equity',
#  'profitability',
#  'k',
#  'c',
#  'although',
#  'doing',
#  'advanced',
#  'info',
#  'txn',
#  'july',
#  'most',
#  'x',
#  'normal',
#  'friday',
#  'contract',
#  'put',
#  'third',
#  'design',
#  'win',
#  'timing',
#  'match',
#  'probably',
#  'arm',
#  'forbes',
#  'site',
#  'ewanspence',
#  'surface',
#  'andromeda',
#  'windowsphone',
#  'window',
#  'tablet',
#  'leak',
#  'rumor',
#  'spec',
#  'release',
#  'date',
#  'bec',
#  'alcohol',
#  'tobacco',
#  'firearm',
#  'chc',
#  'li',
#  'kdqyur',
#  'president',
#  'trump',
#  'tweet',
#  'spoke',
#  'king',
#  'salman',
#  'saudi',
#  'arabia',
#  'explained',
#  'him',
#  'because',
#  'turmoil',
#  'insight',
#  'app',
#  'seasonaledge',
#  'tool',
#  'tap',
#  'intc',
#  'mama',
#  'said',
#  'ice',
#  'cream',
#  'finish',
#  'due',
#  'dil',
#  'noticed',
#  'last',
#  'jedi',
#  'stream',
#  'love',
#  'leave',
#  'view',
#  'look',
#  'ema',
#  'held',
#  'stochastics',
#  'turning',
#  'spy',
#  'qqq',
#  'opposite',
#  'forward',
#  'pe',
#  'valuation',
#  'can',
#  'described',
#  'cheap',
#  'mu',
#  'fbab',
#  'daf',
#  'saber',
#  'capital',
#  'presentation',
#  'common',
#  'denominator',
#  'tencent',
#  'facebook',
#  'google',
#  'investoralmanac',
#  'how',
#  'u',
#  'one',
#  'performing',
#  'crude',
#  'petroleum',
#  'natural',
#  'gas',
#  'ta',
#  'dnr',
#  'ff',
#  'aa',
#  'pu',
#  'simply',
#  'havent',
#  'lost',
#  'any',
#  'brown',
#  'run',
#  'tech',
#  'mf',
#  'educated',
#  'n',
#  'their',
#  'shit',
#  'every',
#  'former',
#  'global',
#  'manufacturing',
#  'pfizer',
#  'independent',
#  'director',
#  'nat',
#  'ricciardi',
#  'may',
#  'safest',
#  'special',
#  'limited',
#  'offer',
#  'june',
#  'tradenet',
#  'offering',
#  'discount',
#  'intro',
#  'program',
#  'limitedtime',
#  'id',
#  'o',
#  'pnwd',
#  'affiliateorg',
#  'affiliateid',
#  'affiliatedata',
#  'below',
#  'financials',
#  'summary',
#  'jeff',
#  'gundlach',
#  'sohn',
#  'long',
#  'thesis',
#  'energy',
#  'jeffrey',
#  'low',
#  'peg',
#  'which',
#  'compensates',
#  'indicates',
#  'rather',
#  'hpq',
#  'ac',
#  'fe',
#  'pres',
#  'coming',
#  'seems',
#  'support',
#  'under',
#  'likely',
#  'wba',
#  'bullshit',
#  'worthless',
#  'mean',
#  'fucking',
#  'nothing',
#  'macau',
#  'usa',
#  'take',
#  'let',
#  'where',
#  'right',
#  'ugly',
#  'without',
#  'clear',
#  'level',
#  'term',
#  'bearish',
#  'll',
#  'previously',
#  'mo',
#  'followed',
#  'end',
#  'another',
#  'runup',
#  'dropped',
#  'smart',
#  'money',
#  'betting',
#  'deal',
#  'update',
#  'uk',
#  'reuters',
#  'article',
#  'indonesia',
#  'rio',
#  'tinto',
#  'grasberg',
#  'inalum',
#  'close',
#  'acquiring',
#  'copper',
#  'mine',
#  'official',
#  'idukkbn',
#  'jq',
#  'h',
#  'technical',
#  'bad',
#  'doe',
#  'present',
#  'nice',
#  'opportunity',
#  'wynn',
#  'ceb',
#  'da',
#  'bc',
#  'completely',
#  'scale',
#  'time',
#  'gobble',
#  'play',
#  'aka',
#  'favorite',
#  'them',
#  'iddy',
#  'bitty',
#  'kiddy',
#  'hand',
#  'awesome',
#  'concerned',
#  'eow',
#  'might',
#  'wk',
#  'throwback',
#  'advisor',
#  'upgrade',
#  'shorties',
#  'dreaming',
#  'depression',
#  'somethin',
#  'loll',
#  'updated',
#  'hormel',
#  'food',
#  'dividend',
#  'analysis',
#  'consumer',
#  'defensive',
#  'dal',
#  'intel',
#  'safety',
#  'score',
#  'technology',
#  'mpc',
#  'both',
#  'positive',
#  'looking',
#  'chk',
#  'df',
#  'cb',
#  'ddbd',
#  'mad',
#  'block',
#  'person',
#  'spam',
#  'should',
#  'open',
#  'projection',
#  'thats',
#  'true',
#  'prefer',
#  'turd',
#  'wal',
#  'mart',
#  'aristocrat',
#  'valueinvesting',
#  'dvb',
#  'aaamp',
#  'marriage',
#  'bank',
#  'account',
#  'dm',
#  'won',
#  'stop',
#  'posting',
#  'holding',
#  'big',
#  'calm',
#  'luck',
#  'chase',
#  'continues',
#  'hopefully',
#  'catch',
#  'before',
#  'lisa',
#  'announces',
#  'rd',
#  'bbby',
#  'bb',
#  'afa',
#  'ecc',
#  'ace',
#  'permamently',
#  'turned',
#  'off',
#  'trading',
#  'maybe',
#  'altogether',
#  'manipulation',
#  'very',
#  'rich',
#  'make',
#  'poor',
#  'fuk',
#  'almost',
#  'pct',
#  'buyback',
#  'got',
#  'though',
#  'drip',
#  'hollywoodreporter',
#  'thr',
#  'esq',
#  'netflix',
#  'green',
#  'light',
#  'appeal',
#  'court',
#  'challenge',
#  'fox',
#  'employment',
#  'sailthru',
#  'email',
#  'breaking',
#  'ehayden',
#  'breakingnews',
#  'dumped',
#  'obv',
#  'jeez',
#  'done',
#  'bounce',
#  'heikin',
#  'ashi',
#  'candle',
#  'confirmation',
#  'liking',
#  'wife',
#  'tree',
#  'fiddy',
#  'sure',
#  'piggy',
#  'lot',
#  'coin',
#  'spend',
#  'candy',
#  'microsoft',
#  'investor',
#  'aren',
#  'happy',
#  'shortpainbot',
#  'shld',
#  'royal',
#  'canada',
#  'reiterates',
#  'outperform',
#  'loop',
#  'raise',
#  'never',
#  'been',
#  'wrong',
#  'miracle',
#  'period',
#  'bollinger',
#  'band',
#  'dare',
#  'say',
#  'didn',
#  'guilty',
#  'fudge',
#  'cvx',
#  'hardly',
#  'ever',
#  'informative',
#  'comment',
#  'page',
#  'broken',
#  'giving',
#  'endless',
#  'buffering',
#  'icon',
#  'give',
#  'viral',
#  'walk',
#  'away',
#  'highlight',
#  'growing',
#  'democrat',
#  'leaving',
#  'party',
#  'epoch',
#  'theepochtimes',
#  'html',
#  'robert',
#  'w',
#  'baird',
#  'neutral',
#  'weed',
#  'other',
#  'drug',
#  'guess',
#  'reasonable',
#  'eb',
#  'ab',
#  'fd',
#  'nike',
#  'winning',
#  'click',
#  'booking',
#  'native',
#  'seamless',
#  'lovalized',
#  'transactable',
#  'ap',
#  'vitiello',
#  'tapped',
#  'acting',
#  'reach',
#  'iconic',
#  'brand',
#  'built',
#  'mobile',
#  'show',
#  'morning',
#  'heading',
#  'ath',
#  'acquisition',
#  'total',
#  'past',
#  'exit',
#  'zone',
#  'sputniknews',
#  'middleeast',
#  'wont',
#  'promise',
#  'oil',
#  'fantastic',
#  'read',
#  'tighten',
#  'bbl',
#  'getting',
#  'closer',
#  'greatest',
#  'yearly',
#  'performance',
#  'did',
#  'fosl',
#  'cdf',
#  'champion',
#  'cashflow',
#  'highyield',
#  'telecommunication',
#  'pretty',
#  'risky',
#  'gamble',
#  'either',
#  'plummet',
#  'rally',
#  'stronger',
#  'apple',
#  'talking',
#  'referring',
#  'intelsat',
#  'punish',
#  'seller',
#  'warehouse',
#  'sense',
#  'old',
#  'gather',
#  'dust',
#  'pc',
#  'gamers',
#  'crypto',
#  'miner',
#  'gpu',
#  'enthusiast',
#  'waiting',
#  'two',
#  'cnet',
#  'nvidia',
#  'geforce',
#  'gtx',
#  'leaked',
#  'only',
#  'decent',
#  'pattern',
#  'mnk',
#  'adc',
#  'cbe',
#  'fb',
#  'dvn',
#  'five',
#  'baba',
#  'ahhhhhhhhhhhhhhhhhhhhh',
#  'raytheon',
#  'industrials',
#  'military',
#  'trending',
#  'riiiiiiiiiich',
#  'sooooon',
#  'buuuuls',
#  'looooove',
#  'drunk',
#  'doesn',
#  'through',
#  'gapping',
#  'warbey',
#  'parker',
#  'prep',
#  'glass',
#  'seen',
#  'focus',
#  'fashion',
#  'wrt',
#  'wearable',
#  'sbux',
#  'paying',
#  'full',
#  'sex',
#  'change',
#  'employee',
#  'hit',
#  'bottom',
#  'line',
#  'recap',
#  'since',
#  'post',
#  'included',
#  'hsy',
#  'sonc',
#  'dri',
#  'kmx',
#  'akam',
#  'enterprise',
#  'value',
#  'v',
#  'cap',
#  'difference',
#  'actual',
#  'asset',
#  'spread',
#  'way',
#  'undervalued',
#  'million',
#  'added',
#  'dont',
#  'become',
#  'such',
#  'monopoly',
#  'dipping',
#  'into',
#  'everything',
#  'airline',
#  'possibility',
#  'loss',
#  'suggested',
#  'analyzer',
#  'tradingsetup',
#  'amd',
#  'efcd',
#  'de',
#  'resistance',
#  'len',
#  'reversal',
#  'progress',
#  've',
#  'recently',
#  'closed',
#  'list',
#  'bought',
#  'same',
#  'used',
#  'according',
#  'data',
#  'reported',
#  'finra',
#  'clocked',
#  'came',
#  'saying',
#  'agree',
#  'resume',
#  'cover',
#  'penis',
#  'putang',
#  'front',
#  'leg',
#  'would',
#  'pb',
#  'twimg',
#  'dg',
#  'acn',
#  'xuaublcy',
#  'format',
#  'jpg',
#  'name',
#  'some',
#  'am',
#  'watching',
#  'wonder',
#  'valued',
#  'inning',
#  'ge',
#  'dd',
#  'bca',
#  'higher',
#  'also',
#  'shorted',
#  'consolidation',
#  'cautious',
#  'stunned',
#  'deeply',
#  'disappointed',
#  'ending',
#  'killed',
#  'best',
#  'february',
#  'funny',
#  'thing',
#  'similar',
#  'story',
#  'different',
#  'crab',
#  'measured',
#  'divergence',
#  'really',
#  'momentum',
#  'starting',
#  'shi',
#  'venture',
#  'outsideonline',
#  'outdoor',
#  'voice',
#  'ty',
#  'haney',
#  'queen',
#  'athleisure',
#  'tariff',
#  'increase',
#  'profit',
#  'recession',
#  'come',
#  'keep',
#  'buying',
#  'pure',
#  'beanscreen',
#  'min',
#  'indicating',
#  'accumulation',
#  'eod',
#  'could',
#  'pop',
#  'heavy',
#  'apog',
#  'camp',
#  'gi',
#  'payx',
#  'fdx',
#  'goo',
#  'squeeze',
#  'pullback',
#  'upside',
#  'nvda',
#  'safe',
#  'yield',
#  'div',
#  'adding',
#  'gladly',
#  'irrationality',
#  'reign',
#  'possible',
#  'excess',
#  'gain',
#  'welcome',
#  'gl',
#  'seeing',
#  'jumping',
#  'joy',
#  'least',
#  'given',
#  'action',
#  'nem',
#  'bouncing',
#  'continuation',
#  'hopeful',
#  'science',
#  'officially',
#  'became',
#  'major',
#  'university',
#  'ai',
#  'brainers',
#  'era',
#  'ea',
#  'second',
#  'minute',
#  'rule',
#  'applies',
#  'zbra',
#  'six',
#  'fc',
#  'gbx',
#  'fds',
#  'avav',
#  'killing',
#  'tax',
#  'cut',
#  'idea',
#  'haven',
#  'posted',
#  'while',
#  'forexfactory',
#  'showthread',
#  'p',
#  'omg',
#  'toy',
#  'land',
#  'amazing',
#  'contributed',
#  'ytd',
#  'popular',
#  'word',
#  'buyin',
#  'those',
#  'dip',
#  'haha',
#  'makin',
#  'rain',
#  'white',
#  'house',
#  'quality',
#  'moment',
#  'gm',
#  'ae',
#  'doubt',
#  'production',
#  'eps',
#  'amzn',
#  'constellation',
#  'disney',
#  ...]

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
"""

#TODO Implement

# A dictionary for the `filtered_words`. The key is the word and value is an id that represents the word. 
vocab = {word:id_ for id_, word in enumerate(filtered_words,1)}
# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = {pos:word for word, pos in vocab.items()}
# tokenized with the words not in `filtered_words` removed.
filtered =  [[word for word in tokenized_message if word in vocab] for tokenized_message in tokenized]

assert set(vocab.keys()) == set(id2vocab.values()), 'Check vocab and id2vocab dictionaries'

# %%
vocab
# Out:
# {'great': 1,
#  'ill': 2,
#  'wait': 3,
#  'staanalystalert': 4,
#  'jefferies': 5,
#  'maintains': 6,
#  'rating': 7,
#  'hold': 8,
#  'setting': 9,
#  'target': 10,
#  'price': 11,
#  'usd': 12,
#  'our': 13,
#  'own': 14,
#  'verdict': 15,
#  'heard': 16,
#  'there': 17,
#  'guy': 18,
#  'who': 19,
#  'know': 20,
#  'someone': 21,
#  'think': 22,
#  'somebody': 23,
#  'something': 24,
#  'stocktwits': 25,
#  'reveal': 26,
#  'yourself': 27,
#  'why': 28,
#  'drop': 29,
#  'warren': 30,
#  'buffet': 31,
#  'taking': 32,
#  'his': 33,
#  'position': 34,
#  'bear': 35,
#  'reason': 36,
#  'pay': 37,
#  'attention': 38,
#  'dividendbot': 39,
#  'ba': 40,
#  'ok': 41,
#  'good': 42,
#  're': 43,
#  'dropping': 44,
#  'over': 45,
#  'weekend': 46,
#  'lol': 47,
#  'daily': 48,
#  'chart': 49,
#  'need': 50,
#  'get': 51,
#  'back': 52,
#  'above': 53,
#  'per': 54,
#  'week': 55,
#  'after': 56,
#  'spike': 57,
#  'no': 58,
#  'news': 59,
#  'month': 60,
#  'bo': 61,
#  'then': 62,
#  'bingo': 63,
#  'odds': 64,
#  'strong': 65,
#  'ratio': 66,
#  'float': 67,
#  'via': 68,
#  'squeezing': 69,
#  'perfect': 70,
#  'place': 71,
#  'an': 72,
#  'option': 73,
#  'straddle': 74,
#  'near': 75,
#  'supporting': 76,
#  'trend': 77,
#  'start': 78,
#  'new': 79,
#  'monday': 80,
#  'expect': 81,
#  'volume': 82,
#  'across': 83,
#  'key': 84,
#  'company': 85,
#  'various': 86,
#  'sector': 87,
#  'breakout': 88,
#  'strategy': 89,
#  'current': 90,
#  'portfolio': 91,
#  'bull': 92,
#  'pfe': 93,
#  'catalyst': 94,
#  'continuing': 95,
#  'uptrend': 96,
#  'pill': 97,
#  'pack': 98,
#  'amazon': 99,
#  'prime': 100,
#  'test': 101,
#  'break': 102,
#  'soon': 103,
#  'ha': 104,
#  'moved': 105,
#  'check': 106,
#  'movement': 107,
#  'peer': 108,
#  'aapl': 109,
#  'mkm': 110,
#  'partner': 111,
#  'set': 112,
#  'too': 113,
#  'early': 114,
#  'tell': 115,
#  'going': 116,
#  'happen': 117,
#  'even': 118,
#  'about': 119,
#  'raisinf': 120,
#  'output': 121,
#  'still': 122,
#  'so': 123,
#  'many': 124,
#  'financially': 125,
#  'healthy': 126,
#  'problem': 127,
#  'meeting': 128,
#  'obligation': 129,
#  'chartmill': 130,
#  'analyze': 131,
#  'php': 132,
#  'source': 133,
#  'medium': 134,
#  'fa': 135,
#  'content': 136,
#  'health': 137,
#  'campaign': 138,
#  'social': 139,
#  'tracking': 140,
#  'nke': 141,
#  'r': 142,
#  'fee': 143,
#  'd': 144,
#  'b': 145,
#  'f': 146,
#  'e': 147,
#  'bullish': 148,
#  'watch': 149,
#  'setup': 150,
#  'timeframes': 151,
#  'seeitmarket': 152,
#  'twitter': 153,
#  'twtr': 154,
#  'michael': 155,
#  'kor': 156,
#  'blog': 157,
#  'high': 158,
#  'alert': 159,
#  'next': 160,
#  'gt': 161,
#  'breakdown': 162,
#  'much': 163,
#  'better': 164,
#  'than': 165,
#  'industry': 166,
#  'average': 167,
#  'fslr': 168,
#  'cf': 169,
#  'ec': 170,
#  'miss': 171,
#  'these': 172,
#  'confirms': 173,
#  'see': 174,
#  'violent': 175,
#  'move': 176,
#  'downward': 177,
#  'cv': 178,
#  'base': 179,
#  'gap': 180,
#  'ma': 181,
#  'cabot': 182,
#  'weekly': 183,
#  'video': 184,
#  'quot': 185,
#  'resilient': 186,
#  'growth': 187,
#  'bit': 188,
#  'ly': 189,
#  'kj': 190,
#  'fnd': 191,
#  'when': 192,
#  'kid': 193,
#  'froend': 194,
#  'told': 195,
#  'me': 196,
#  'moon': 197,
#  'made': 198,
#  'cheese': 199,
#  'percent': 200,
#  'rank': 201,
#  'th': 202,
#  'percentile': 203,
#  'volumebot': 204,
#  'uri': 205,
#  'thank': 206,
#  'don': 207,
#  'feel': 208,
#  'or': 209,
#  'do': 210,
#  'well': 211,
#  'already': 212,
#  'during': 213,
#  'youtube': 214,
#  'interview': 215,
#  'mitch': 216,
#  'couldn': 217,
#  'remember': 218,
#  'single': 219,
#  'movie': 220,
#  'he': 221,
#  'watched': 222,
#  'year': 223,
#  'except': 224,
#  'star': 225,
#  'war': 226,
#  'black': 227,
#  'panther': 228,
#  'clothes': 229,
#  'downgrade': 230,
#  'sale': 231,
#  'interest': 232,
#  'return': 233,
#  'equity': 234,
#  'profitability': 235,
#  'k': 236,
#  'c': 237,
#  'although': 238,
#  'doing': 239,
#  'advanced': 240,
#  'info': 241,
#  'txn': 242,
#  'july': 243,
#  'most': 244,
#  'x': 245,
#  'normal': 246,
#  'friday': 247,
#  'contract': 248,
#  'put': 249,
#  'third': 250,
#  'design': 251,
#  'win': 252,
#  'timing': 253,
#  'match': 254,
#  'probably': 255,
#  'arm': 256,
#  'forbes': 257,
#  'site': 258,
#  'ewanspence': 259,
#  'surface': 260,
#  'andromeda': 261,
#  'windowsphone': 262,
#  'window': 263,
#  'tablet': 264,
#  'leak': 265,
#  'rumor': 266,
#  'spec': 267,
#  'release': 268,
#  'date': 269,
#  'bec': 270,
#  'alcohol': 271,
#  'tobacco': 272,
#  'firearm': 273,
#  'chc': 274,
#  'li': 275,
#  'kdqyur': 276,
#  'president': 277,
#  'trump': 278,
#  'tweet': 279,
#  'spoke': 280,
#  'king': 281,
#  'salman': 282,
#  'saudi': 283,
#  'arabia': 284,
#  'explained': 285,
#  'him': 286,
#  'because': 287,
#  'turmoil': 288,
#  'insight': 289,
#  'app': 290,
#  'seasonaledge': 291,
#  'tool': 292,
#  'tap': 293,
#  'intc': 294,
#  'mama': 295,
#  'said': 296,
#  'ice': 297,
#  'cream': 298,
#  'finish': 299,
#  'due': 300,
#  'dil': 301,
#  'noticed': 302,
#  'last': 303,
#  'jedi': 304,
#  'stream': 305,
#  'love': 306,
#  'leave': 307,
#  'view': 308,
#  'look': 309,
#  'ema': 310,
#  'held': 311,
#  'stochastics': 312,
#  'turning': 313,
#  'spy': 314,
#  'qqq': 315,
#  'opposite': 316,
#  'forward': 317,
#  'pe': 318,
#  'valuation': 319,
#  'can': 320,
#  'described': 321,
#  'cheap': 322,
#  'mu': 323,
#  'fbab': 324,
#  'daf': 325,
#  'saber': 326,
#  'capital': 327,
#  'presentation': 328,
#  'common': 329,
#  'denominator': 330,
#  'tencent': 331,
#  'facebook': 332,
#  'google': 333,
#  'investoralmanac': 334,
#  'how': 335,
#  'u': 336,
#  'one': 337,
#  'performing': 338,
#  'crude': 339,
#  'petroleum': 340,
#  'natural': 341,
#  'gas': 342,
#  'ta': 343,
#  'dnr': 344,
#  'ff': 345,
#  'aa': 346,
#  'pu': 347,
#  'simply': 348,
#  'havent': 349,
#  'lost': 350,
#  'any': 351,
#  'brown': 352,
#  'run': 353,
#  'tech': 354,
#  'mf': 355,
#  'educated': 356,
#  'n': 357,
#  'their': 358,
#  'shit': 359,
#  'every': 360,
#  'former': 361,
#  'global': 362,
#  'manufacturing': 363,
#  'pfizer': 364,
#  'independent': 365,
#  'director': 366,
#  'nat': 367,
#  'ricciardi': 368,
#  'may': 369,
#  'safest': 370,
#  'special': 371,
#  'limited': 372,
#  'offer': 373,
#  'june': 374,
#  'tradenet': 375,
#  'offering': 376,
#  'discount': 377,
#  'intro': 378,
#  'program': 379,
#  'limitedtime': 380,
#  'id': 381,
#  'o': 382,
#  'pnwd': 383,
#  'affiliateorg': 384,
#  'affiliateid': 385,
#  'affiliatedata': 386,
#  'below': 387,
#  'financials': 388,
#  'summary': 389,
#  'jeff': 390,
#  'gundlach': 391,
#  'sohn': 392,
#  'long': 393,
#  'thesis': 394,
#  'energy': 395,
#  'jeffrey': 396,
#  'low': 397,
#  'peg': 398,
#  'which': 399,
#  'compensates': 400,
#  'indicates': 401,
#  'rather': 402,
#  'hpq': 403,
#  'ac': 404,
#  'fe': 405,
#  'pres': 406,
#  'coming': 407,
#  'seems': 408,
#  'support': 409,
#  'under': 410,
#  'likely': 411,
#  'wba': 412,
#  'bullshit': 413,
#  'worthless': 414,
#  'mean': 415,
#  'fucking': 416,
#  'nothing': 417,
#  'macau': 418,
#  'usa': 419,
#  'take': 420,
#  'let': 421,
#  'where': 422,
#  'right': 423,
#  'ugly': 424,
#  'without': 425,
#  'clear': 426,
#  'level': 427,
#  'term': 428,
#  'bearish': 429,
#  'll': 430,
#  'previously': 431,
#  'mo': 432,
#  'followed': 433,
#  'end': 434,
#  'another': 435,
#  'runup': 436,
#  'dropped': 437,
#  'smart': 438,
#  'money': 439,
#  'betting': 440,
#  'deal': 441,
#  'update': 442,
#  'uk': 443,
#  'reuters': 444,
#  'article': 445,
#  'indonesia': 446,
#  'rio': 447,
#  'tinto': 448,
#  'grasberg': 449,
#  'inalum': 450,
#  'close': 451,
#  'acquiring': 452,
#  'copper': 453,
#  'mine': 454,
#  'official': 455,
#  'idukkbn': 456,
#  'jq': 457,
#  'h': 458,
#  'technical': 459,
#  'bad': 460,
#  'doe': 461,
#  'present': 462,
#  'nice': 463,
#  'opportunity': 464,
#  'wynn': 465,
#  'ceb': 466,
#  'da': 467,
#  'bc': 468,
#  'completely': 469,
#  'scale': 470,
#  'time': 471,
#  'gobble': 472,
#  'play': 473,
#  'aka': 474,
#  'favorite': 475,
#  'them': 476,
#  'iddy': 477,
#  'bitty': 478,
#  'kiddy': 479,
#  'hand': 480,
#  'awesome': 481,
#  'concerned': 482,
#  'eow': 483,
#  'might': 484,
#  'wk': 485,
#  'throwback': 486,
#  'advisor': 487,
#  'upgrade': 488,
#  'shorties': 489,
#  'dreaming': 490,
#  'depression': 491,
#  'somethin': 492,
#  'loll': 493,
#  'updated': 494,
#  'hormel': 495,
#  'food': 496,
#  'dividend': 497,
#  'analysis': 498,
#  'consumer': 499,
#  'defensive': 500,
#  'dal': 501,
#  'intel': 502,
#  'safety': 503,
#  'score': 504,
#  'technology': 505,
#  'mpc': 506,
#  'both': 507,
#  'positive': 508,
#  'looking': 509,
#  'chk': 510,
#  'df': 511,
#  'cb': 512,
#  'ddbd': 513,
#  'mad': 514,
#  'block': 515,
#  'person': 516,
#  'spam': 517,
#  'should': 518,
#  'open': 519,
#  'projection': 520,
#  'thats': 521,
#  'true': 522,
#  'prefer': 523,
#  'turd': 524,
#  'wal': 525,
#  'mart': 526,
#  'aristocrat': 527,
#  'valueinvesting': 528,
#  'dvb': 529,
#  'aaamp': 530,
#  'marriage': 531,
#  'bank': 532,
#  'account': 533,
#  'dm': 534,
#  'won': 535,
#  'stop': 536,
#  'posting': 537,
#  'holding': 538,
#  'big': 539,
#  'calm': 540,
#  'luck': 541,
#  'chase': 542,
#  'continues': 543,
#  'hopefully': 544,
#  'catch': 545,
#  'before': 546,
#  'lisa': 547,
#  'announces': 548,
#  'rd': 549,
#  'bbby': 550,
#  'bb': 551,
#  'afa': 552,
#  'ecc': 553,
#  'ace': 554,
#  'permamently': 555,
#  'turned': 556,
#  'off': 557,
#  'trading': 558,
#  'maybe': 559,
#  'altogether': 560,
#  'manipulation': 561,
#  'very': 562,
#  'rich': 563,
#  'make': 564,
#  'poor': 565,
#  'fuk': 566,
#  'almost': 567,
#  'pct': 568,
#  'buyback': 569,
#  'got': 570,
#  'though': 571,
#  'drip': 572,
#  'hollywoodreporter': 573,
#  'thr': 574,
#  'esq': 575,
#  'netflix': 576,
#  'green': 577,
#  'light': 578,
#  'appeal': 579,
#  'court': 580,
#  'challenge': 581,
#  'fox': 582,
#  'employment': 583,
#  'sailthru': 584,
#  'email': 585,
#  'breaking': 586,
#  'ehayden': 587,
#  'breakingnews': 588,
#  'dumped': 589,
#  'obv': 590,
#  'jeez': 591,
#  'done': 592,
#  'bounce': 593,
#  'heikin': 594,
#  'ashi': 595,
#  'candle': 596,
#  'confirmation': 597,
#  'liking': 598,
#  'wife': 599,
#  'tree': 600,
#  'fiddy': 601,
#  'sure': 602,
#  'piggy': 603,
#  'lot': 604,
#  'coin': 605,
#  'spend': 606,
#  'candy': 607,
#  'microsoft': 608,
#  'investor': 609,
#  'aren': 610,
#  'happy': 611,
#  'shortpainbot': 612,
#  'shld': 613,
#  'royal': 614,
#  'canada': 615,
#  'reiterates': 616,
#  'outperform': 617,
#  'loop': 618,
#  'raise': 619,
#  'never': 620,
#  'been': 621,
#  'wrong': 622,
#  'miracle': 623,
#  'period': 624,
#  'bollinger': 625,
#  'band': 626,
#  'dare': 627,
#  'say': 628,
#  'didn': 629,
#  'guilty': 630,
#  'fudge': 631,
#  'cvx': 632,
#  'hardly': 633,
#  'ever': 634,
#  'informative': 635,
#  'comment': 636,
#  'page': 637,
#  'broken': 638,
#  'giving': 639,
#  'endless': 640,
#  'buffering': 641,
#  'icon': 642,
#  'give': 643,
#  'viral': 644,
#  'walk': 645,
#  'away': 646,
#  'highlight': 647,
#  'growing': 648,
#  'democrat': 649,
#  'leaving': 650,
#  'party': 651,
#  'epoch': 652,
#  'theepochtimes': 653,
#  'html': 654,
#  'robert': 655,
#  'w': 656,
#  'baird': 657,
#  'neutral': 658,
#  'weed': 659,
#  'other': 660,
#  'drug': 661,
#  'guess': 662,
#  'reasonable': 663,
#  'eb': 664,
#  'ab': 665,
#  'fd': 666,
#  'nike': 667,
#  'winning': 668,
#  'click': 669,
#  'booking': 670,
#  'native': 671,
#  'seamless': 672,
#  'lovalized': 673,
#  'transactable': 674,
#  'ap': 675,
#  'vitiello': 676,
#  'tapped': 677,
#  'acting': 678,
#  'reach': 679,
#  'iconic': 680,
#  'brand': 681,
#  'built': 682,
#  'mobile': 683,
#  'show': 684,
#  'morning': 685,
#  'heading': 686,
#  'ath': 687,
#  'acquisition': 688,
#  'total': 689,
#  'past': 690,
#  'exit': 691,
#  'zone': 692,
#  'sputniknews': 693,
#  'middleeast': 694,
#  'wont': 695,
#  'promise': 696,
#  'oil': 697,
#  'fantastic': 698,
#  'read': 699,
#  'tighten': 700,
#  'bbl': 701,
#  'getting': 702,
#  'closer': 703,
#  'greatest': 704,
#  'yearly': 705,
#  'performance': 706,
#  'did': 707,
#  'fosl': 708,
#  'cdf': 709,
#  'champion': 710,
#  'cashflow': 711,
#  'highyield': 712,
#  'telecommunication': 713,
#  'pretty': 714,
#  'risky': 715,
#  'gamble': 716,
#  'either': 717,
#  'plummet': 718,
#  'rally': 719,
#  'stronger': 720,
#  'apple': 721,
#  'talking': 722,
#  'referring': 723,
#  'intelsat': 724,
#  'punish': 725,
#  'seller': 726,
#  'warehouse': 727,
#  'sense': 728,
#  'old': 729,
#  'gather': 730,
#  'dust': 731,
#  'pc': 732,
#  'gamers': 733,
#  'crypto': 734,
#  'miner': 735,
#  'gpu': 736,
#  'enthusiast': 737,
#  'waiting': 738,
#  'two': 739,
#  'cnet': 740,
#  'nvidia': 741,
#  'geforce': 742,
#  'gtx': 743,
#  'leaked': 744,
#  'only': 745,
#  'decent': 746,
#  'pattern': 747,
#  'mnk': 748,
#  'adc': 749,
#  'cbe': 750,
#  'fb': 751,
#  'dvn': 752,
#  'five': 753,
#  'baba': 754,
#  'ahhhhhhhhhhhhhhhhhhhhh': 755,
#  'raytheon': 756,
#  'industrials': 757,
#  'military': 758,
#  'trending': 759,
#  'riiiiiiiiiich': 760,
#  'sooooon': 761,
#  'buuuuls': 762,
#  'looooove': 763,
#  'drunk': 764,
#  'doesn': 765,
#  'through': 766,
#  'gapping': 767,
#  'warbey': 768,
#  'parker': 769,
#  'prep': 770,
#  'glass': 771,
#  'seen': 772,
#  'focus': 773,
#  'fashion': 774,
#  'wrt': 775,
#  'wearable': 776,
#  'sbux': 777,
#  'paying': 778,
#  'full': 779,
#  'sex': 780,
#  'change': 781,
#  'employee': 782,
#  'hit': 783,
#  'bottom': 784,
#  'line': 785,
#  'recap': 786,
#  'since': 787,
#  'post': 788,
#  'included': 789,
#  'hsy': 790,
#  'sonc': 791,
#  'dri': 792,
#  'kmx': 793,
#  'akam': 794,
#  'enterprise': 795,
#  'value': 796,
#  'v': 797,
#  'cap': 798,
#  'difference': 799,
#  'actual': 800,
#  'asset': 801,
#  'spread': 802,
#  'way': 803,
#  'undervalued': 804,
#  'million': 805,
#  'added': 806,
#  'dont': 807,
#  'become': 808,
#  'such': 809,
#  'monopoly': 810,
#  'dipping': 811,
#  'into': 812,
#  'everything': 813,
#  'airline': 814,
#  'possibility': 815,
#  'loss': 816,
#  'suggested': 817,
#  'analyzer': 818,
#  'tradingsetup': 819,
#  'amd': 820,
#  'efcd': 821,
#  'de': 822,
#  'resistance': 823,
#  'len': 824,
#  'reversal': 825,
#  'progress': 826,
#  've': 827,
#  'recently': 828,
#  'closed': 829,
#  'list': 830,
#  'bought': 831,
#  'same': 832,
#  'used': 833,
#  'according': 834,
#  'data': 835,
#  'reported': 836,
#  'finra': 837,
#  'clocked': 838,
#  'came': 839,
#  'saying': 840,
#  'agree': 841,
#  'resume': 842,
#  'cover': 843,
#  'penis': 844,
#  'putang': 845,
#  'front': 846,
#  'leg': 847,
#  'would': 848,
#  'pb': 849,
#  'twimg': 850,
#  'dg': 851,
#  'acn': 852,
#  'xuaublcy': 853,
#  'format': 854,
#  'jpg': 855,
#  'name': 856,
#  'some': 857,
#  'am': 858,
#  'watching': 859,
#  'wonder': 860,
#  'valued': 861,
#  'inning': 862,
#  'ge': 863,
#  'dd': 864,
#  'bca': 865,
#  'higher': 866,
#  'also': 867,
#  'shorted': 868,
#  'consolidation': 869,
#  'cautious': 870,
#  'stunned': 871,
#  'deeply': 872,
#  'disappointed': 873,
#  'ending': 874,
#  'killed': 875,
#  'best': 876,
#  'february': 877,
#  'funny': 878,
#  'thing': 879,
#  'similar': 880,
#  'story': 881,
#  'different': 882,
#  'crab': 883,
#  'measured': 884,
#  'divergence': 885,
#  'really': 886,
#  'momentum': 887,
#  'starting': 888,
#  'shi': 889,
#  'venture': 890,
#  'outsideonline': 891,
#  'outdoor': 892,
#  'voice': 893,
#  'ty': 894,
#  'haney': 895,
#  'queen': 896,
#  'athleisure': 897,
#  'tariff': 898,
#  'increase': 899,
#  'profit': 900,
#  'recession': 901,
#  'come': 902,
#  'keep': 903,
#  'buying': 904,
#  'pure': 905,
#  'beanscreen': 906,
#  'min': 907,
#  'indicating': 908,
#  'accumulation': 909,
#  'eod': 910,
#  'could': 911,
#  'pop': 912,
#  'heavy': 913,
#  'apog': 914,
#  'camp': 915,
#  'gi': 916,
#  'payx': 917,
#  'fdx': 918,
#  'goo': 919,
#  'squeeze': 920,
#  'pullback': 921,
#  'upside': 922,
#  'nvda': 923,
#  'safe': 924,
#  'yield': 925,
#  'div': 926,
#  'adding': 927,
#  'gladly': 928,
#  'irrationality': 929,
#  'reign': 930,
#  'possible': 931,
#  'excess': 932,
#  'gain': 933,
#  'welcome': 934,
#  'gl': 935,
#  'seeing': 936,
#  'jumping': 937,
#  'joy': 938,
#  'least': 939,
#  'given': 940,
#  'action': 941,
#  'nem': 942,
#  'bouncing': 943,
#  'continuation': 944,
#  'hopeful': 945,
#  'science': 946,
#  'officially': 947,
#  'became': 948,
#  'major': 949,
#  'university': 950,
#  'ai': 951,
#  'brainers': 952,
#  'era': 953,
#  'ea': 954,
#  'second': 955,
#  'minute': 956,
#  'rule': 957,
#  'applies': 958,
#  'zbra': 959,
#  'six': 960,
#  'fc': 961,
#  'gbx': 962,
#  'fds': 963,
#  'avav': 964,
#  'killing': 965,
#  'tax': 966,
#  'cut': 967,
#  'idea': 968,
#  'haven': 969,
#  'posted': 970,
#  'while': 971,
#  'forexfactory': 972,
#  'showthread': 973,
#  'p': 974,
#  'omg': 975,
#  'toy': 976,
#  'land': 977,
#  'amazing': 978,
#  'contributed': 979,
#  'ytd': 980,
#  'popular': 981,
#  'word': 982,
#  'buyin': 983,
#  'those': 984,
#  'dip': 985,
#  'haha': 986,
#  'makin': 987,
#  'rain': 988,
#  'white': 989,
#  'house': 990,
#  'quality': 991,
#  'moment': 992,
#  'gm': 993,
#  'ae': 994,
#  'doubt': 995,
#  'production': 996,
#  'eps': 997,
#  'amzn': 998,
#  'constellation': 999,
#  'disney': 1000,
#  ...}

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %%
balanced
# Out:
# {'messages': [['great', 'ill', 'wait'],
#   ['staanalystalert',
#    'jefferies',
#    'maintains',
#    'rating',
#    'hold',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict'],
#   ['heard',
#    'there',
#    'guy',
#    'who',
#    'know',
#    'someone',
#    'who',
#    'think',
#    'somebody',
#    'know',
#    'something',
#    'stocktwits'],
#   ['why', 'drop', 'warren', 'buffet', 'taking', 'his', 'position'],
#   ['bear', 'reason', 'pay', 'attention', 'dividendbot', 'ba'],
#   ['ok', 'good', 're', 'dropping', 'price', 'over', 'weekend', 'lol'],
#   ['daily', 'chart', 'need', 'get', 'back', 'above'],
#   ['drop',
#    'per',
#    'week',
#    'after',
#    'spike',
#    'no',
#    'news',
#    'month',
#    'back',
#    'bo',
#    'then',
#    'bingo',
#    'odds'],
#   ['strong'],
#   ['ratio', 'float', 'via'],
#   ['price',
#    'squeezing',
#    'perfect',
#    'place',
#    'an',
#    'option',
#    'straddle',
#    'near',
#    'supporting',
#    'trend'],
#   ['start',
#    'new',
#    'monday',
#    'expect',
#    'strong',
#    'volume',
#    'across',
#    'key',
#    'company',
#    'various',
#    'sector'],
#   ['breakout', 'strategy', 'current', 'portfolio'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'pfe'],
#   ['catalyst',
#    'continuing',
#    'new',
#    'uptrend',
#    'pill',
#    'pack',
#    'amazon',
#    'prime',
#    'test',
#    'break',
#    'soon'],
#   ['ha', 'moved', 'check', 'movement', 'peer', 'dividendbot', 'aapl'],
#   ['staanalystalert',
#    'mkm',
#    'partner',
#    'set',
#    'price',
#    'target',
#    'rating',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict'],
#   ['think',
#    'too',
#    'early',
#    'tell',
#    'going',
#    'happen',
#    'monday',
#    'even',
#    'current',
#    'news',
#    'about',
#    'raisinf',
#    'output',
#    'there',
#    'still',
#    'so',
#    'many'],
#   ['ha',
#    'current',
#    'ratio',
#    'so',
#    'financially',
#    'healthy',
#    'ha',
#    'no',
#    'problem',
#    'meeting',
#    'obligation',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'health',
#    'campaign',
#    'social',
#    'tracking',
#    'nke',
#    'r',
#    'fa',
#    'key',
#    'fee',
#    'd',
#    'b',
#    'b',
#    'f',
#    'e'],
#   ['bullish',
#    'watch',
#    'setup',
#    'timeframes',
#    'seeitmarket',
#    'bullish',
#    'twitter',
#    'twtr',
#    'michael',
#    'kor',
#    'blog'],
#   ['high', 'alert', 'next', 'week', 'gt', 'breakdown'],
#   ['current',
#    'ratio',
#    'much',
#    'better',
#    'than',
#    'industry',
#    'average',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'health',
#    'campaign',
#    'social',
#    'tracking',
#    'fslr',
#    'r',
#    'fa',
#    'key',
#    'b',
#    'cf',
#    'ec',
#    'e',
#    'b',
#    'b',
#    'b'],
#   ['miss', 'these'],
#   ['break',
#    'confirms',
#    'next',
#    'week',
#    'see',
#    'violent',
#    'move',
#    'downward',
#    'price'],
#   ['bear', 'reason', 'pay', 'attention', 'dividendbot', 'cv'],
#   ['breakout', 'base', 'gap', 'ma', 'gap', 'gap', 'gap', 'ma'],
#   ['when', 'kid', 'froend', 'told', 'me', 'moon', 'made', 'cheese'],
#   ['volume', 'percent', 'rank', 'th', 'percentile', 'volumebot', 'uri'],
#   ['thank',
#    'don',
#    'feel',
#    'need',
#    'tell',
#    'or',
#    'do',
#    'well',
#    'me',
#    'already'],
#   ['staanalystalert',
#    'jefferies',
#    'downgrade',
#    'rating',
#    'hold',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict',
#    'hold'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['although',
#    'doing',
#    'even',
#    'better',
#    'ha',
#    'advanced',
#    'info',
#    'peer',
#    'dividendbot',
#    'txn'],
#   ['july', 'most', 'bullish', 'year'],
#   ['option',
#    'volume',
#    'x',
#    'normal',
#    'friday',
#    'contract',
#    'volume',
#    'put',
#    'volume'],
#   ['third',
#    'design',
#    'win',
#    'timing',
#    'match',
#    'probably',
#    'arm',
#    'forbes',
#    'site',
#    'ewanspence',
#    'surface',
#    'andromeda',
#    'windowsphone',
#    'window',
#    'tablet',
#    'leak',
#    'rumor',
#    'spec',
#    'release',
#    'date',
#    'd',
#    'bec',
#    'e'],
#   ['alcohol', 'tobacco', 'firearm', 'chc', 'li', 'kdqyur', 'b'],
#   ['president',
#    'trump',
#    'tweet',
#    'spoke',
#    'king',
#    'salman',
#    'saudi',
#    'arabia',
#    'explained',
#    'him',
#    'because',
#    'turmoil'],
#   ['good',
#    'view',
#    'daily',
#    'still',
#    'look',
#    'good',
#    'ema',
#    'held',
#    'above',
#    'ema',
#    'stochastics',
#    'turning',
#    'healthy',
#    'spy',
#    'qqq',
#    'opposite'],
#   ['forward',
#    'pe',
#    'valuation',
#    'can',
#    'described',
#    'cheap',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'valuation',
#    'campaign',
#    'social',
#    'tracking',
#    'mu',
#    'r',
#    'fa',
#    'key',
#    'fbab',
#    'b',
#    'cf',
#    'f',
#    'daf'],
#   ['saber',
#    'capital',
#    'presentation',
#    'common',
#    'denominator',
#    'tencent',
#    'facebook',
#    'google',
#    'investoralmanac',
#    'saber',
#    'capital',
#    'common',
#    'denominator',
#    'tencent',
#    'facebook',
#    'google'],
#   ['how', 'u', 'expect'],
#   ['pu',
#    'simply',
#    'havent',
#    'lost',
#    'any',
#    'brown',
#    'guy',
#    'run',
#    'tech',
#    'company',
#    'mf',
#    'well',
#    'educated',
#    'n',
#    'know',
#    'their',
#    'shit',
#    'n',
#    'every',
#    'year'],
#   ['former',
#    'president',
#    'global',
#    'manufacturing',
#    'pfizer',
#    'an',
#    'independent',
#    'director',
#    'nat',
#    'ricciardi'],
#   ['may', 'safest', 'own'],
#   ['special',
#    'limited',
#    'offer',
#    'june',
#    'th',
#    'june',
#    'th',
#    'tradenet',
#    'offering',
#    'discount',
#    'intro',
#    'program',
#    'tradenet',
#    'limitedtime',
#    'offer',
#    'campaign',
#    'id',
#    'o',
#    'pnwd',
#    'affiliateorg',
#    'tradenet',
#    'affiliateid',
#    'affiliatedata'],
#   ['below', 'put', 'financials'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'presentation',
#    'long',
#    'thesis',
#    'energy',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['low',
#    'peg',
#    'ratio',
#    'which',
#    'compensates',
#    'pe',
#    'growth',
#    'indicates',
#    'rather',
#    'cheap',
#    'valuation',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'valuation',
#    'campaign',
#    'social',
#    'tracking',
#    'hpq',
#    'r',
#    'fa',
#    'key',
#    'd',
#    'd',
#    'ac',
#    'e',
#    'e',
#    'fe'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'pres',
#    'long',
#    'thesis',
#    'energy',
#    'equity',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['coming'],
#   ['seems', 'support', 'next', 'under', 'likely'],
#   ['bullshit',
#    'worthless',
#    'mean',
#    'fucking',
#    'nothing',
#    'macau',
#    'fucking',
#    'usa'],
#   ['take', 'let', 'me', 'know', 'where', 'right', 'lol'],
#   ['chart',
#    'look',
#    'so',
#    'ugly',
#    'without',
#    'clear',
#    'support',
#    'level',
#    'term',
#    'bearish',
#    'll',
#    'when'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'presentation',
#    'long',
#    'thesis',
#    'energy',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['previously',
#    'there',
#    'mo',
#    'run',
#    'followed',
#    'drop',
#    'end',
#    'month',
#    'another',
#    'runup',
#    'dropped',
#    'about'],
#   ['smart',
#    'money',
#    'betting',
#    'deal',
#    'update',
#    'uk',
#    'reuters',
#    'article',
#    'uk',
#    'indonesia',
#    'rio',
#    'tinto',
#    'grasberg',
#    'indonesia',
#    'inalum',
#    'close',
#    'acquiring',
#    'rio',
#    'interest',
#    'grasberg',
#    'copper',
#    'mine',
#    'official',
#    'idukkbn',
#    'jq',
#    'h'],
#   ['completely',
#    'scale',
#    'time',
#    'gobble',
#    'next',
#    'long',
#    'play',
#    'aka',
#    'favorite',
#    'gt'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['throwback'],
#   ['staanalystalert',
#    'u',
#    'capital',
#    'advisor',
#    'upgrade',
#    'rating',
#    'hold',
#    'our',
#    'own',
#    'verdict'],
#   ['updated',
#    'hormel',
#    'food',
#    'dividend',
#    'king',
#    'analysis',
#    'dividend',
#    'king',
#    'consumer',
#    'defensive'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'dal'],
#   ['long',
#    'term',
#    'trend',
#    'both',
#    'positive',
#    'looking',
#    'good',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'ta',
#    'campaign',
#    'social',
#    'tracking',
#    'chk',
#    'key',
#    'df',
#    'b',
#    'cb',
#    'c',
#    'b',
#    'ddbd',
#    'da'],
#   ['back', 'july'],
#   ['should', 'open', 'monday'],
#   ['projection',
#    'thats',
#    'true',
#    'under',
#    'next',
#    'week',
#    'thats',
#    'why',
#    'd',
#    'prefer',
#    'support',
#    'level'],
#   ['turd'],
#   ['percent', 'volume', 'volumebot', 'tap'],
#   ['ratio', 'float', 'via'],
#   ['bear',
#    'won',
#    'stop',
#    'posting',
#    'holding',
#    'big',
#    'position',
#    'over',
#    'weekend',
#    'calm',
#    'good',
#    'luck',
#    'lol'],
#   ['chase',
#    'continues',
#    'hopefully',
#    'catch',
#    'him',
#    'before',
#    'lisa',
#    'announces',
#    'rd',
#    'win'],
#   ['price',
#    'ratio',
#    'which',
#    'indicates',
#    'rather',
#    'cheap',
#    'valuation',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'valuation',
#    'campaign',
#    'social',
#    'tracking',
#    'bbby',
#    'r',
#    'fa',
#    'key',
#    'f',
#    'bb',
#    'afa',
#    'b',
#    'e',
#    'ecc',
#    'ace',
#    'd',
#    'e'],
#   ['permamently',
#    'turned',
#    'me',
#    'off',
#    'option',
#    'trading',
#    'maybe',
#    'altogether',
#    'manipulation',
#    'very',
#    'rich',
#    'make',
#    'me',
#    'very',
#    'poor',
#    'fuk'],
#   ['almost',
#    'pct',
#    'week',
#    'high',
#    'about',
#    'time',
#    'buyback',
#    'got',
#    'account',
#    'though',
#    'drip'],
#   ['hollywoodreporter',
#    'thr',
#    'esq',
#    'netflix',
#    'get',
#    'green',
#    'light',
#    'appeal',
#    'court',
#    'challenge',
#    'fox',
#    'employment',
#    'contract',
#    'source',
#    'sailthru',
#    'medium',
#    'email',
#    'campaign',
#    'thr',
#    'breaking',
#    'news',
#    'ehayden',
#    'term',
#    'hollywoodreporter',
#    'breakingnews'],
#   ['liking'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['bearish', 'investor', 'aren', 'happy', 'shortpainbot', 'shld'],
#   ['staanalystalert',
#    'royal',
#    'bank',
#    'canada',
#    'reiterates',
#    'rating',
#    'outperform',
#    'our',
#    'own',
#    'verdict'],
#   ['staanalystalert',
#    'loop',
#    'capital',
#    'raise',
#    'target',
#    'rating',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict'],
#   ['hardly',
#    'ever',
#    'an',
#    'informative',
#    'comment',
#    'page',
#    'broken',
#    'giving',
#    'endless',
#    'buffering',
#    'icon',
#    'give',
#    'stocktwits'],
#   ['staanalystalert',
#    'robert',
#    'w',
#    'baird',
#    'downgrade',
#    'rating',
#    'neutral',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict'],
#   ['reason',
#    'nike',
#    'winning',
#    'because',
#    'their',
#    'click',
#    'booking',
#    'app',
#    'better',
#    'than',
#    'native',
#    'seamless',
#    'lovalized',
#    'transactable',
#    'ap'],
#   ['vitiello', 'tapped', 'acting', 'ice', 'director', 'via'],
#   ['reach',
#    'over',
#    'year',
#    'iconic',
#    'brand',
#    'global',
#    'technology',
#    'built',
#    'mobile',
#    'winning',
#    'strategy',
#    'show'],
#   ['monday', 'morning'],
#   ['heading', 'ath', 'soon', 'maybe', 'next', 'week'],
#   ['staanalystalert',
#    'jefferies',
#    'downgrade',
#    'rating',
#    'hold',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict'],
#   ['staanalystalert',
#    'baird',
#    'downgrade',
#    'rating',
#    'neutral',
#    'our',
#    'own',
#    'verdict'],
#   ['zone'],
#   ['sputniknews',
#    'middleeast',
#    'saudi',
#    'arabia',
#    'wont',
#    'promise',
#    'trump',
#    'oil'],
#   ['fantastic',
#    'read',
#    'oil',
#    'continues',
#    'tighten',
#    'bbl',
#    'getting',
#    'closer',
#    'investoralmanac',
#    'oil',
#    'continues',
#    'tighten',
#    'getting',
#    'closer'],
#   ['one', 'greatest'],
#   ['pretty',
#    'risky',
#    'gamble',
#    'no',
#    'can',
#    'either',
#    'plummet',
#    'or',
#    'rally'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['stronger'],
#   ['apple',
#    'valuation',
#    'profitability',
#    'dividend',
#    'safety',
#    'score',
#    'analysis',
#    'dividend',
#    'technology',
#    'dividend'],
#   ['talking', 'about', 'referring', 'intelsat'],
#   ['punish',
#    'seller',
#    'who',
#    'don',
#    'move',
#    'warehouse',
#    'common',
#    'sense',
#    'old',
#    'gather',
#    'dust',
#    'new',
#    'gather',
#    'money'],
#   ['pc',
#    'gamers',
#    'crypto',
#    'miner',
#    'other',
#    'gpu',
#    'enthusiast',
#    'been',
#    'waiting',
#    'over',
#    'two',
#    'year',
#    'company',
#    'next',
#    'big',
#    'cnet',
#    'news',
#    'nvidia',
#    'geforce',
#    'gtx',
#    'release',
#    'date',
#    'may',
#    'leaked'],
#   ['five', 'year', 'baba', 'or', 'apple'],
#   ['next', 'week', 'ahhhhhhhhhhhhhhhhhhhhh'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['get',
#    'riiiiiiiiiich',
#    'sooooon',
#    'buuuuls',
#    'looooove',
#    'fucking',
#    'drunk'],
#   ['doesn',
#    'get',
#    'through',
#    'going',
#    'make',
#    'new',
#    'low',
#    'when',
#    'pay',
#    'dividend'],
#   ['gapping', 'monday'],
#   ['ratio', 'float', 'via'],
#   ['staanalystalert',
#    'jefferies',
#    'maintains',
#    'rating',
#    'hold',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict'],
#   ['should',
#    'warbey',
#    'parker',
#    'b',
#    'prep',
#    'apple',
#    'glass',
#    'seen',
#    'watch',
#    'apple',
#    'focus',
#    'fashion',
#    'tech',
#    'wrt',
#    'wearable'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'expect',
#    'run',
#    'other',
#    'included',
#    'hsy',
#    'uri',
#    'sonc',
#    'dri',
#    'kmx',
#    'wynn',
#    'akam'],
#   ['b',
#    'enterprise',
#    'value',
#    'v',
#    'b',
#    'cap',
#    'difference',
#    'actual',
#    'asset',
#    'v',
#    'value',
#    'too',
#    'big',
#    'spread',
#    'way',
#    'undervalued'],
#   ['don',
#    'miss',
#    'breakout',
#    'stop',
#    'stop',
#    'loss',
#    'suggested',
#    'chartmill',
#    'analyzer',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'tradingsetup',
#    'campaign',
#    'social',
#    'tracking',
#    'amd',
#    'key',
#    'eb',
#    'b',
#    'efcd',
#    'ba',
#    'de',
#    'f',
#    'd'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['weekly',
#    'recap',
#    'price',
#    'ha',
#    'moved',
#    'since',
#    'post',
#    'support',
#    'resistance',
#    'other',
#    'included',
#    'uri',
#    'sonc',
#    'dri',
#    'kmx',
#    'wynn',
#    'akam',
#    'len'],
#   ['ve',
#    'recently',
#    'closed',
#    'position',
#    'probably',
#    'next',
#    'list',
#    'bought',
#    'both',
#    'same',
#    'week'],
#   ['according',
#    'data',
#    'reported',
#    'finra',
#    'volume',
#    'percent',
#    'clocked',
#    'volumebot',
#    'mpc'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'uptrend',
#    'resume',
#    'other',
#    'included',
#    'kmx',
#    'wynn',
#    'akam',
#    'len',
#    'hsy',
#    'uri',
#    'sonc'],
#   ['one',
#    'right',
#    'cover',
#    'penis',
#    'or',
#    'putang',
#    'front',
#    'leg',
#    'would',
#    'arm'],
#   ['ratio', 'float', 'via'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'next',
#    'stop',
#    'other',
#    'included',
#    'wynn',
#    'akam',
#    'len',
#    'hsy',
#    'uri',
#    'sonc',
#    'dri'],
#   ['wonder', 'how', 'much', 'valued', 'year', 'even', 'th', 'inning'],
#   ['going',
#    'make',
#    'big',
#    'move',
#    'higher',
#    'also',
#    'watching',
#    'apple',
#    'think',
#    'shorted',
#    'put',
#    'spread',
#    'july'],
#   ['good',
#    'even',
#    'bull',
#    'cautious',
#    'stunned',
#    'bearish',
#    'deeply',
#    'disappointed',
#    'too',
#    'bad',
#    'continues',
#    'old',
#    'way',
#    'hopefully',
#    'close'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'support',
#    'other',
#    'included',
#    'len',
#    'hsy',
#    'uri',
#    'sonc',
#    'dri',
#    'kmx',
#    'wynn'],
#   ['ending', 'june', 'killed', 'best', 'month', 'since', 'february'],
#   ['funny',
#    'how',
#    'long',
#    'same',
#    'thing',
#    'ha',
#    'been',
#    'going',
#    'about',
#    'year',
#    'similar',
#    'story',
#    'different'],
#   ['bearish',
#    'crab',
#    'well',
#    'measured',
#    'bearish',
#    'crab',
#    'bearish',
#    'divergence',
#    'can',
#    'really',
#    'see',
#    'momentum',
#    'starting',
#    'shi'],
#   ['staanalystalert',
#    'jefferies',
#    'maintains',
#    'rating',
#    'setting',
#    'target',
#    'price',
#    'usd',
#    'our',
#    'own',
#    'verdict'],
#   ['tariff',
#    'increase',
#    'profit',
#    'how',
#    'can',
#    'bad',
#    'recession',
#    'come',
#    'year',
#    'line',
#    'keep',
#    'buying',
#    'r',
#    'pure',
#    'bull'],
#   ['min',
#    'chart',
#    'friday',
#    'indicating',
#    'some',
#    'nice',
#    'accumulation',
#    'eod',
#    'could',
#    'nice',
#    'pop',
#    'monday'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'heavy',
#    'resistance',
#    'other',
#    'included',
#    'apog',
#    'acn',
#    'camp',
#    'gi',
#    'payx',
#    'fdx',
#    'goo'],
#   ['can', 'squeeze'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'pullback',
#    'before',
#    'upside',
#    'other',
#    'included',
#    'camp',
#    'gi',
#    'payx',
#    'fdx',
#    'goo',
#    'nvda',
#    'apog'],
#   ['still', 'holding', 'next', 'week'],
#   ['adding',
#    'gladly',
#    'let',
#    'irrationality',
#    'reign',
#    'long',
#    'possible',
#    'excess',
#    'gain',
#    'welcome',
#    'gl'],
#   ['looking',
#    'friday',
#    'data',
#    'seeing',
#    'different',
#    'story',
#    'chart',
#    'take',
#    'look',
#    'tell',
#    'me',
#    'think'],
#   ['probably',
#    'aren',
#    'jumping',
#    'joy',
#    'least',
#    'given',
#    'price',
#    'action',
#    'shortpainbot',
#    'nem'],
#   ['bouncing',
#    'off',
#    'support',
#    'need',
#    'continuation',
#    'next',
#    'week',
#    'make',
#    'me',
#    'feel',
#    'hopeful'],
#   ['data',
#    'science',
#    'officially',
#    'became',
#    'major',
#    'university',
#    'year',
#    'support',
#    'ai',
#    'industry',
#    'these',
#    'no',
#    'brainers',
#    'data',
#    'era'],
#   ['ratio', 'float', 'via'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'support',
#    'other',
#    'included',
#    'payx',
#    'fdx',
#    'goo',
#    'nvda',
#    'apog',
#    'acn',
#    'camp'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['second', 'minute'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'nem'],
#   ['omg', 'toy', 'story', 'land', 'look', 'amazing'],
#   ['contributed', 'ytd', 'return', 'do', 'own'],
#   ['trump',
#    'tweet',
#    'then',
#    'he',
#    'may',
#    'buyin',
#    'those',
#    'dip',
#    'haha',
#    'still',
#    'makin',
#    'rain',
#    'white',
#    'house'],
#   ['measured',
#    'over',
#    'past',
#    'year',
#    'show',
#    'very',
#    'strong',
#    'growth',
#    'eps',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'growth',
#    'campaign',
#    'social',
#    'tracking',
#    'amzn',
#    'r',
#    'fa',
#    'key',
#    'e',
#    'e',
#    'd',
#    'b',
#    'c',
#    'd'],
#   ['b', 'constellation', 'brand'],
#   ['probably',
#    'aren',
#    'jumping',
#    'joy',
#    'least',
#    'given',
#    'price',
#    'action',
#    'shortpainbot',
#    'mpc'],
#   ['aggregate', 'volume', 'reported', 'finra', 'volumebot', 'nem'],
#   ['southwest',
#    'airline',
#    'adding',
#    'flight',
#    'dallas',
#    'delta',
#    'spat',
#    'continues',
#    'themarketisopen',
#    'post',
#    'southwest',
#    'airline',
#    'adding',
#    'flight',
#    'dallas',
#    'delta',
#    'spat',
#    'continues'],
#   ['better',
#    'netflix',
#    'inc',
#    'nflx',
#    'versus',
#    'facebook',
#    'fb',
#    'themarketisopen',
#    'post',
#    'better',
#    'netflix',
#    'inc',
#    'nflx',
#    'versus',
#    'facebook',
#    'fb'],
#   ['bull', 'list', 'after', 'their', 'emergence', 'bankruptcy', 'emergency'],
#   ['zwj',
#    'investment',
#    'counsel',
#    'inc',
#    'lower',
#    'stake',
#    'unitedhealth',
#    'group',
#    'inc',
#    'unh',
#    'stocknews',
#    'io',
#    'news',
#    'zwj',
#    'investment',
#    'counsel',
#    'inc',
#    'lower',
#    'stake',
#    'unitedhealth',
#    'group',
#    'inc',
#    'unh',
#    'weekherald',
#    'index',
#    'html'],
#   ['investing',
#    'company',
#    'an',
#    'annuity',
#    'or',
#    'yr',
#    'bond',
#    'continue',
#    'add',
#    'unsure',
#    'country',
#    'growing',
#    'amd'],
#   ['weekly',
#    'recap',
#    'price',
#    'moved',
#    'since',
#    'post',
#    'strong',
#    'support',
#    'current',
#    'price',
#    'other',
#    'included',
#    'cgnx',
#    'cx',
#    'aaoi',
#    'aa',
#    'amswa',
#    'yy',
#    'snx'],
#   ['bearish',
#    'shark',
#    'bearish',
#    'shark',
#    'bearish',
#    'divergence',
#    'am',
#    'definitely',
#    'jumping',
#    'into',
#    'august',
#    'put',
#    'monday'],
#   ['so', 'g', 'going', 'give', 'u', 'price', 'point', 'before', 'or', 'after'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['huge', 'volume', 'closing', 'friday'],
#   ['looking', 'scalp'],
#   ['one', 'giant', 'fermenting', 'turd', 'when', 'back'],
#   ['buffet', 'buying', 'per'],
#   ['option',
#    'volume',
#    'x',
#    'normal',
#    'friday',
#    'contract',
#    'volume',
#    'put',
#    'volume'],
#   ['eps',
#    'ha',
#    'been',
#    'growing',
#    'average',
#    'over',
#    'past',
#    'year',
#    'quite',
#    'good',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'growth',
#    'campaign',
#    'social',
#    'tracking',
#    'noc',
#    'r',
#    'fa',
#    'key',
#    'c',
#    'eff',
#    'b',
#    'c',
#    'c',
#    'dc'],
#   ['mitch',
#    'did',
#    'great',
#    'job',
#    'getting',
#    'netflix',
#    'started',
#    'he',
#    'clearly',
#    'know',
#    'how',
#    'make',
#    'big',
#    'thing',
#    'happen',
#    'industry'],
#   ['cup',
#    'holder',
#    'inverse',
#    'bearish',
#    'confidence',
#    'reach',
#    'target',
#    'price',
#    'usd'],
#   ['sell',
#    'may',
#    'away',
#    'ha',
#    'been',
#    'pattern',
#    'year',
#    'interesting',
#    'see',
#    'so',
#    'much',
#    'trading',
#    'time',
#    'frame',
#    'bank',
#    'love',
#    'trader'],
#   ['broadening',
#    'wedge',
#    'descending',
#    'bearish',
#    'confidence',
#    'reach',
#    'target',
#    'price',
#    'usd'],
#   ['happy', 'trading', 'guy', 'looking', 'exit'],
#   ['large', 'put', 'spread', 'open', 'interest', 'im', 'bearish'],
#   ['pt'],
#   ['three',
#    'falling',
#    'peak',
#    'bearish',
#    'confidence',
#    'reach',
#    'target',
#    'price',
#    'usd'],
#   ['happy', 'fourth', 'everyone', 'coke', 'smile', 'thanks', 'dividend'],
#   ['selling', 'prove', 'terrible', 'error'],
#   ['triple',
#    'top',
#    'bearish',
#    'confidence',
#    'reach',
#    'target',
#    'price',
#    'usd'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['bro', 'how', 'work', 'delete', 'blue', 'arrow', 'your', 'delusion'],
#   ['cup',
#    'holder',
#    'bullish',
#    'confidence',
#    'reach',
#    'target',
#    'price',
#    'usd'],
#   ['mr', 'hold', 'yo'],
#   ['hi',
#    'everyone',
#    'going',
#    'bed',
#    'good',
#    'night',
#    'everyone',
#    'happy',
#    'money',
#    'monday',
#    'soon',
#    'prepared'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['amazon',
#    'new',
#    'warehouse',
#    'policy',
#    'start',
#    'penalizing',
#    'seller',
#    'store',
#    'product',
#    'too',
#    'long',
#    'cnb',
#    'cx',
#    'ibinab'],
#   ['why',
#    'did',
#    'bank',
#    'fail',
#    'rally',
#    'despite',
#    'huge',
#    'bb',
#    'div',
#    'incr',
#    'me',
#    'thinking',
#    'mm',
#    'driving',
#    'price',
#    'get',
#    'cheap',
#    'prior',
#    'rally'],
#   ['bear',
#    'using',
#    'argument',
#    'sound',
#    'position',
#    'becoming',
#    'loses',
#    'week'],
#   ['gameranx', 'popular', 'youtube', 'gaming', 'channel'],
#   ['facebook', 'cash', 'machine'],
#   ['cheap',
#    'dividend',
#    'champion',
#    'low',
#    'forward',
#    'p',
#    'e',
#    'altria',
#    'aflac',
#    'eatonvance'],
#   ['look', 'graph', 'tripple', 'bottom', 'reached', 'heading', 'week'],
#   ['penis', 'want', 'vagina', 'alteration', 'get', 'job', 'sbux'],
#   ['oled',
#    'panel',
#    'post',
#    'steady',
#    'growth',
#    'amid',
#    'weak',
#    'demand',
#    'display',
#    'data'],
#   ['option',
#    'volume',
#    'x',
#    'normal',
#    'friday',
#    'contract',
#    'volume',
#    'put',
#    'volume'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['original',
#    'thesis',
#    'predicated',
#    'amd',
#    'having',
#    'competitive',
#    'server',
#    'product',
#    'around',
#    'time',
#    'didn',
#    'think',
#    'intel',
#    'would',
#    'shit',
#    'bed'],
#   ['bullish', 'bat', 'bullish', 'bat', 'bullish', 'divergence'],
#   ['original',
#    'thesis',
#    'predicated',
#    'amd',
#    'having',
#    'competitive',
#    'server',
#    'product',
#    'around',
#    'time',
#    'didn',
#    'think',
#    'intel',
#    'would',
#    'sh',
#    'bed'],
#   ['think', 'many', 'can', 'under'],
#   ['new',
#    'way',
#    'match',
#    'group',
#    'can',
#    'counter',
#    'facebook',
#    'nasdaq',
#    'article',
#    'new',
#    'way',
#    'match',
#    'group',
#    'can',
#    'counter',
#    'facebook',
#    'cm'],
#   ['wowza',
#    'started',
#    'one',
#    'month',
#    'ago',
#    'return',
#    'would',
#    'around',
#    'iex',
#    'data',
#    'shortpainbot',
#    'mnk'],
#   ['real',
#    'boom',
#    'social',
#    'medium',
#    'get',
#    'much',
#    'bigger',
#    'before',
#    'christmas'],
#   ['current',
#    'ratio',
#    'much',
#    'better',
#    'than',
#    'industry',
#    'average',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'health',
#    'campaign',
#    'social',
#    'tracking',
#    'eog',
#    'r',
#    'fa',
#    'key',
#    'd',
#    'e',
#    'bcc',
#    'd'],
#   ['bear',
#    'shorties',
#    'made',
#    'huge',
#    'mistake',
#    'don',
#    'money',
#    'back',
#    'when',
#    'shorted',
#    'so',
#    'cry',
#    'everyday'],
#   ['industry',
#    'average',
#    'roa',
#    'outperforms',
#    'industry',
#    'peer',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'profitability',
#    'campaign',
#    'social',
#    'tracking',
#    'cmcsa',
#    'r',
#    'fa',
#    'key',
#    'd',
#    'f',
#    'beb',
#    'ced',
#    'f'],
#   ['encourage',
#    'no',
#    'longer',
#    'sheep',
#    'end',
#    'your',
#    'racist',
#    'hateful',
#    'way',
#    'amd',
#    'walk',
#    'away',
#    'democratic',
#    'party',
#    'walkaway'],
#   ['happening',
#    'looking',
#    'ease',
#    'flattening',
#    'yc',
#    'starting',
#    'week',
#    'lot',
#    'trader',
#    'def',
#    'offside'],
#   ['daily', 'or', 'weekly', 'chart', 'look', 'horrible'],
#   ['spotify', 'add', 'video', 'content', 'look'],
#   ['positioning',
#    'very',
#    'underweight',
#    'crowdthnk',
#    'algo',
#    'forecast',
#    'chance',
#    'moving',
#    'lower',
#    'crowdthnk',
#    'uri'],
#   ['added',
#    'no',
#    'brainer',
#    're',
#    'long',
#    'there',
#    'no',
#    'peer',
#    'top',
#    'dog',
#    'amd',
#    'mu',
#    'notwithstanding'],
#   ['bearish',
#    'bat',
#    'bearish',
#    'bat',
#    'some',
#    'serious',
#    'bearish',
#    'divergence',
#    'something',
#    'about',
#    'give'],
#   ['ha', 'been', 'proposition', 'july', 'since', 'net', 'return'],
#   ['term', 'negative', 'there', 'bearish', 'indicator', 'dividendbot', 'xec'],
#   ['brexit', 'banker', 'risk', 'life', 'edge', 'luxembourg', 'fill', 'via'],
#   ['history',
#    'marketwatch',
#    'story',
#    'guid',
#    'ae',
#    'beb',
#    'adc',
#    'e',
#    'f',
#    'd'],
#   ['pertains',
#    'started',
#    'ago',
#    'bearish',
#    'investor',
#    'would',
#    'lost',
#    'around',
#    'according',
#    'iex',
#    'shortpainbot',
#    'he'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['waiting', 'pull', 'back', 'slow', 'n', 'steady'],
#   ['thought',
#    'friday',
#    'flush',
#    'cheap',
#    'did',
#    'oil',
#    'before',
#    'opec',
#    'meeting'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['rated', 'sell', 'since', 'june', 'below', 'median', 'level'],
#   ['dont', 'trust', 'company'],
#   ['anticipation', 'rising', 'which', 'right', 'june'],
#   ['sorry',
#    'itsallaboutheoptions',
#    'price',
#    'so',
#    'higher',
#    'than',
#    'predicted',
#    'lower'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['nasdaq',
#    'article',
#    'caterpillar',
#    'could',
#    'rebound',
#    'construction',
#    'spending',
#    'cm'],
#   ['because',
#    'concern',
#    'still',
#    'worth',
#    'weight',
#    'faucet',
#    'little',
#    'bit',
#    'lighting'],
#   ['three',
#    'falling',
#    'peak',
#    'bearish',
#    'confidence',
#    'reach',
#    'target',
#    'price',
#    'usd'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['rectangle',
#    'top',
#    'bullish',
#    'confidence',
#    'reach',
#    'target',
#    'price',
#    'usd'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'hum'],
#   ['really',
#    'baked',
#    'right',
#    'having',
#    'deep',
#    'thought',
#    'coming',
#    'back',
#    'look',
#    'tweet',
#    'year'],
#   ['one',
#    'test',
#    'fails',
#    'target',
#    'start',
#    'buying',
#    'again',
#    'houseofpain'],
#   ['finance',
#    'yahoo',
#    'video',
#    'amazon',
#    'constantly',
#    'under',
#    'regulator',
#    'magnifying',
#    'html'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot'],
#   ['over', 'before'],
#   ['extremely',
#    'undervalued',
#    'within',
#    'year',
#    'great',
#    'midterm',
#    'investment'],
#   ['may', 'slightly', 'news', 'june', 'ggr'],
#   ['stupid', 'spammer', 'wasting', 'time'],
#   ['already', 'oversold', 'so', 'much', 'consolidation', 'then'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['purchasing',
#    'pill',
#    'pack',
#    'last',
#    'thursday',
#    'breaking',
#    'into',
#    'pharmaceutical',
#    'field',
#    'increase',
#    'amazon',
#    'bottom',
#    'line',
#    'retest',
#    'quickly'],
#   ['june', 'ggr', 'still', 'after', 'soccer', 'world', 'cup', 'holiday'],
#   ['purchasing',
#    'pill',
#    'pack',
#    'last',
#    'thurs',
#    'breaking',
#    'into',
#    'pharmaceutical',
#    'field',
#    'increase',
#    'amazon',
#    'bottom',
#    'line',
#    'retest',
#    'quickly'],
#   ['back', 'want', 'cheap'],
#   ['too',
#    'expensive',
#    'growing',
#    'strongly',
#    'check',
#    'part',
#    'our',
#    'affordable',
#    'growth',
#    'selection',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'fa',
#    'campaign',
#    'social',
#    'tracking',
#    'mu',
#    'tab',
#    'ag',
#    'r',
#    'fa',
#    'key',
#    'fbab',
#    'b',
#    'cf',
#    'f',
#    'daf'],
#   ['option',
#    'volume',
#    'x',
#    'normal',
#    'friday',
#    'contract',
#    'volume',
#    'put',
#    'volume'],
#   ['long',
#    'term',
#    'trend',
#    'positive',
#    'term',
#    'trend',
#    'neutral',
#    'so',
#    'benefit',
#    'doubt',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'ta',
#    'campaign',
#    'social',
#    'tracking',
#    'goog',
#    'key',
#    'c',
#    'f',
#    'bd',
#    'd',
#    'c',
#    'bc',
#    'cc'],
#   ['lot',
#    'buyer',
#    'fri',
#    'when',
#    'mm',
#    'pinned',
#    'quot',
#    'trader',
#    'amazon',
#    'amzn',
#    'weakness',
#    'quot',
#    'themarketsdaily',
#    'trader',
#    'amazon',
#    'amzn',
#    'weakness',
#    'html'],
#   ['term', 'positive', 'there', 'bullish', 'indicator', 'dividendbot', 'fdx'],
#   ['know', 'hold'],
#   ['wanna',
#    'hear',
#    'er',
#    'ok',
#    'yeah',
#    'y',
#    'got',
#    'great',
#    'product',
#    'so',
#    'want',
#    'news'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['august',
#    'either',
#    'gonna',
#    'make',
#    'fortune',
#    'or',
#    'declare',
#    'bankruptcy'],
#   ['jul',
#    'casino',
#    'gross',
#    'gaming',
#    'revenue',
#    'ggr',
#    'macau',
#    'rose',
#    'percent',
#    'year',
#    'year',
#    'june'],
#   ['gonna', 'cheaper', 'than', 'also'],
#   ['monster',
#    'core',
#    'amd',
#    'ryzen',
#    'threadripper',
#    'x',
#    'cpu',
#    'c',
#    'rumored',
#    'usd',
#    'ultragamerz',
#    'monster',
#    'core',
#    'amd',
#    'ryzen',
#    'threadripper',
#    'x',
#    'cpu',
#    'c',
#    'rumored',
#    'usd'],
#   ['someone', 'give', 'me'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['forbes',
#    'site',
#    'muhammadcohen',
#    'amid',
#    'stunning',
#    'recovery',
#    'macau',
#    'casino',
#    'still',
#    'room',
#    'grow',
#    'd',
#    'cea',
#    'f'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['trump', 'cause', 'oil', 'price'],
#   ['were', 'need', 'buyback', 'bln', 'wouldn', 'try', 'dip'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['gigabyte',
#    'epyc',
#    'cpu',
#    'large',
#    'density',
#    'server',
#    'ultragamerz',
#    'gigabyte',
#    'amd',
#    'epyc',
#    'cpu',
#    'large',
#    'density',
#    'server'],
#   ['intel',
#    'can',
#    'produce',
#    'full',
#    'silicon',
#    'wafer',
#    'quantum',
#    'computing',
#    'chip',
#    'ultragamerz',
#    'intel',
#    'can',
#    'produce',
#    'full',
#    'silicon',
#    'wafer',
#    'quantum',
#    'computing',
#    'chip'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['good',
#    'technical',
#    'also',
#    'nice',
#    'setup',
#    'pattern',
#    'forming',
#    'part',
#    'our',
#    'top',
#    'breakout',
#    'selection',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'setup',
#    'campaign',
#    'social',
#    'tracking',
#    'uaa',
#    'key',
#    'b',
#    'fa',
#    'd',
#    'f',
#    'f',
#    'd',
#    'c',
#    'c',
#    'b'],
#   ['bear', 'reason', 'pay', 'attention', 'dividendbot', 'dhr'],
#   ['amazon',
#    'j',
#    'hook',
#    'pattern',
#    'set',
#    'monthly',
#    'looking',
#    'strong',
#    'move',
#    'monday',
#    'expected'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'mgm'],
#   ['seekingalpha', 'article', 'wynn', 'dip', 'soft', 'may', 'number', 'macau'],
#   ['bear', 'reason', 'pay', 'attention', 'dividendbot', 'qep'],
#   ['dip', 'buying', 'opp'],
#   ['an',
#    'example',
#    'j',
#    'hook',
#    'pattern',
#    'virtually',
#    'identical',
#    'amazon',
#    'monthly',
#    'chart',
#    'look'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['showing',
#    'our',
#    'top',
#    'breakout',
#    'selection',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'dailychart',
#    'campaign',
#    'social',
#    'tracking',
#    'cop',
#    'key',
#    'ee',
#    'f',
#    'd',
#    'f',
#    'fe',
#    'd',
#    'c',
#    'd'],
#   ['overbought', 'sell', 'signal'],
#   ['ratio', 'float', 'via'],
#   ['rsi', 'deathcross'],
#   ['pertains',
#    'started',
#    'ago',
#    'bearish',
#    'investor',
#    'would',
#    'lost',
#    'around',
#    'according',
#    'iex',
#    'shortpainbot',
#    'esv'],
#   ['volume',
#    'th',
#    'percentile',
#    'term',
#    'last',
#    'trading',
#    'volumebot',
#    'hbi'],
#   ['bring',
#    'gloom',
#    'doom',
#    'pull',
#    'back',
#    'ahead',
#    'er',
#    'happens',
#    'ever',
#    'time',
#    'after',
#    'don',
#    'fight',
#    'plan',
#    'no',
#    'way',
#    'fall'],
#   ['overbought', 'death', 'cross', 'sell', 'signal'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['bad',
#    'news',
#    'baked',
#    'sector',
#    'second',
#    'major',
#    'miss',
#    'row',
#    'going',
#    'spook',
#    'lot',
#    'investor'],
#   ['volume', 'percent', 'versus', 'volumebot', 'irm'],
#   ['artcile',
#    'expectation',
#    'june',
#    'great',
#    'buying',
#    'opp',
#    'dip',
#    'july',
#    'august',
#    'seekingalpha',
#    'article',
#    'watch',
#    'tariff',
#    'take',
#    'holiday'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['ratio', 'float', 'via'],
#   ['well',
#    'can',
#    'sell',
#    'premarket',
#    'then',
#    'back',
#    'summer',
#    'july',
#    'tariff',
#    'coming',
#    'lower',
#    'price',
#    'why',
#    'ggr'],
#   ['term', 'positive', 'there', 'bullish', 'indicator', 'dividendbot', 'unp'],
#   ['currently',
#    'trading',
#    'upper',
#    'part',
#    'week',
#    'range',
#    'outperforming',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'ta',
#    'campaign',
#    'social',
#    'tracking',
#    'aapl',
#    'key',
#    'bb',
#    'ac',
#    'c',
#    'b',
#    'd',
#    'd',
#    'f',
#    'b'],
#   ['huge',
#    'miss',
#    'june',
#    'ggr',
#    'right',
#    'before',
#    'july',
#    'tariff',
#    'oh',
#    'shit',
#    'selling',
#    'premarket',
#    'buying',
#    'back'],
#   ['according',
#    'data',
#    'reported',
#    'finra',
#    'volume',
#    'percent',
#    'clocked',
#    'volumebot',
#    'wynn'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'csco'],
#   ['ratio', 'float', 'via'],
#   ['based',
#    'iex',
#    'data',
#    'bearish',
#    'investor',
#    'taken',
#    'some',
#    'punishment',
#    'started',
#    'month',
#    'ago',
#    'their',
#    'return',
#    'around',
#    'shortpainbot',
#    'ni'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['think',
#    'opinion',
#    'most',
#    'consolidated',
#    'greatest',
#    'business',
#    'support',
#    'different',
#    'area',
#    'strategy'],
#   ['happened',
#    'last',
#    'june',
#    'too',
#    'miss',
#    'june',
#    'ggr',
#    'seekingalpha',
#    'news',
#    'macau',
#    'sector',
#    'slip',
#    'june',
#    'revenue',
#    'miss',
#    'high',
#    'flying',
#    'expectation'],
#   ['based',
#    'iex',
#    'data',
#    'bearish',
#    'investor',
#    'taken',
#    'some',
#    'punishment',
#    'started',
#    'month',
#    'ago',
#    'their',
#    'return',
#    'around',
#    'shortpainbot',
#    'rmd'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'do'],
#   ['wow',
#    'started',
#    'one',
#    'month',
#    'ago',
#    'bear',
#    'return',
#    'would',
#    'around',
#    'iex',
#    'data',
#    'shortpainbot',
#    'leg'],
#   ['according',
#    'data',
#    'reported',
#    'finra',
#    'volume',
#    'percent',
#    'clocked',
#    'volumebot',
#    'scg'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'esv'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['newspscan', 'w', 'vol', 'accum'],
#   ['your', 'thought', 'bank'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['long',
#    'term',
#    'trend',
#    'both',
#    'positive',
#    'looking',
#    'good',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'ta',
#    'campaign',
#    'social',
#    'tracking',
#    'chk',
#    'key',
#    'df',
#    'b',
#    'cb',
#    'c',
#    'b',
#    'ddbd',
#    'da'],
#   ['weekly',
#    'bullflag',
#    'great',
#    'condition',
#    'major',
#    'support',
#    'breakout',
#    'pt',
#    'indicator',
#    'look',
#    'good'],
#   ['per',
#    'data',
#    'reported',
#    'finra',
#    'volume',
#    'divided',
#    'total',
#    'volume',
#    'volumebot',
#    'esv'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['chart', 'swingstocktraders', 'chart'],
#   ['ha',
#    'bad',
#    'technical',
#    'rating',
#    'doe',
#    'show',
#    'decent',
#    'setup',
#    'pattern',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'ta',
#    'content',
#    'setup',
#    'campaign',
#    'social',
#    'tracking',
#    'celg',
#    'key',
#    'b',
#    'cb',
#    'd',
#    'd',
#    'c',
#    'cea'],
#   ['percent', 'volume', 'volumebot', 'qep'],
#   ['term', 'positive', 'there', 'bullish', 'indicator', 'dividendbot', 'oxy'],
#   ['confidently',
#    'can',
#    'invest',
#    'forget',
#    'generation',
#    'e',
#    'yr',
#    'enjoy',
#    'fruit',
#    'labor',
#    'extending',
#    'future'],
#   ['rated', 'since', 'may', 'above', 'median', 'level'],
#   ['financials',
#    'broke',
#    'wedge',
#    'weekly',
#    'chart',
#    'indicator',
#    'bearish',
#    'price',
#    'target',
#    'dma'],
#   ['ha',
#    'profit',
#    'margin',
#    'amongst',
#    'best',
#    'return',
#    'industry',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'profitability',
#    'campaign',
#    'social',
#    'tracking',
#    'xom',
#    'r',
#    'fa',
#    'key',
#    'e',
#    'f',
#    'd',
#    'd',
#    'bc',
#    'b',
#    'aab'],
#   ['volume', 'reported', 'finra', 'volumebot', 'ba'],
#   ['weekly',
#    'bf',
#    'look',
#    'great',
#    'dma',
#    'crossing',
#    'dma',
#    'bullish',
#    'sign',
#    'buying',
#    'volume',
#    'gt',
#    'selling',
#    'volume',
#    'make',
#    'very',
#    'attractive'],
#   ['ratio', 'float', 'via'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'gpn'],
#   ['maybe', 'or', 'moviepass', 'superb', 'income', 'generator'],
#   ['detected', 'positive', 'indicator', 'info', 'dividendbot', 'x'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['conservative',
#    'believe',
#    'social',
#    'network',
#    'censor',
#    'political',
#    'speech',
#    'according',
#    'pew',
#    'study'],
#   ['volume', 'percent', 'an', 'increase', 'volumebot', 'kr'],
#   ['ha',
#    'profit',
#    'margin',
#    'better',
#    'than',
#    'industry',
#    'average',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'profitability',
#    'campaign',
#    'social',
#    'tracking',
#    'dri',
#    'r',
#    'fa',
#    'key',
#    'cba',
#    'bacd',
#    'ec',
#    'b',
#    'b',
#    'ac'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'dva'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['bigger',
#    'news',
#    'when',
#    'doj',
#    'give',
#    'clearance',
#    'condition',
#    'then',
#    'see',
#    'very',
#    'huge',
#    'counter',
#    'offer'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['per',
#    'data',
#    'reported',
#    'finra',
#    'volume',
#    'divided',
#    'total',
#    'volume',
#    'volumebot',
#    'nrg'],
#   ['volume', 'reported', 'finra', 'volumebot', 'rok'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'ci'],
#   ['fund',
#    'follow',
#    'added',
#    'micron',
#    'another',
#    'fund',
#    'manager',
#    'ha',
#    'had',
#    'since',
#    'still',
#    'holding',
#    'both',
#    'targeting',
#    'higher',
#    'high'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'nke'],
#   ['aggregate', 'volume', 'reported', 'finra', 'volumebot', 'pld'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'tsn'],
#   ['eps',
#    'ha',
#    'been',
#    'growing',
#    'average',
#    'over',
#    'past',
#    'year',
#    'very',
#    'strong',
#    'growth',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'growth',
#    'campaign',
#    'social',
#    'tracking',
#    'amd',
#    'r',
#    'fa',
#    'key',
#    'eb',
#    'b',
#    'efcd',
#    'ba',
#    'de',
#    'f',
#    'd'],
#   ['sure',
#    'felt',
#    'some',
#    'pain',
#    'shorted',
#    'first',
#    'their',
#    'ytd',
#    'return',
#    'around',
#    'shortpainbot',
#    'mro'],
#   ['volume', 'reported', 'finra', 'volumebot', 'schw'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['rt',
#    'show',
#    'quite',
#    'strong',
#    'growth',
#    'eps',
#    'over',
#    'last',
#    'year',
#    'eps',
#    'ha',
#    'been',
#    'growing',
#    'yearly',
#    'cha'],
#   ['bear', 'reason', 'pay', 'attention', 'dividendbot', 'cog'],
#   ['sorry', 'bull', 'after', 'trump', 'attack', 'great', 'american', 'brand'],
#   ['volume',
#    'th',
#    'percentile',
#    'term',
#    'last',
#    'trading',
#    'volumebot',
#    'clf'],
#   ['absolutely',
#    'true',
#    'throwing',
#    'body',
#    'issue',
#    'often',
#    'creates',
#    'new',
#    'one',
#    'stay',
#    'course'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['term', 'positive', 'there', 'bullish', 'indicator', 'dividendbot', 'exc'],
#   ['ran',
#    'looked',
#    'folding',
#    'device',
#    'westworld',
#    'even',
#    'apple',
#    'fan',
#    'would',
#    'one'],
#   ['fed', 'waterboarding', 'deutschebank', 'also', 'goo', 'gl', 'j', 'rj'],
#   ['soon',
#    'did',
#    'd',
#    'tip',
#    'their',
#    'hand',
#    'competition',
#    'd',
#    'approve',
#    'purchase',
#    'same'],
#   ['volume', 'percent', 'decrease', 'volumebot', 'fe'],
#   ['space',
#    'grey',
#    'macbook',
#    'pro',
#    'touch',
#    'bar',
#    'running',
#    'mojave',
#    'dark',
#    'mode'],
#   ['ratio', 'float', 'via'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'schw'],
#   ['aggregate', 'volume', 'reported', 'finra', 'volumebot', 'cvx'],
#   ['ha',
#    'an',
#    'altman',
#    'z',
#    'score',
#    'meaning',
#    'financially',
#    'healthy',
#    'little',
#    'risk',
#    'bankruptcy',
#    'chartmill',
#    'analyze',
#    'php',
#    'source',
#    'stocktwits',
#    'medium',
#    'fa',
#    'content',
#    'health',
#    'campaign',
#    'social',
#    'tracking',
#    'sbux',
#    'r',
#    'fa',
#    'key',
#    'b',
#    'd',
#    'ea',
#    'ebc',
#    'fe'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['bear', 'reason', 'pay', 'attention', 'dividendbot', 'klac'],
#   ['aggregate', 'volume', 'reported', 'finra', 'volumebot', 'v'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['move',
#    'monday',
#    'signaled',
#    'major',
#    'reversal',
#    'could',
#    'rally',
#    'anticipation',
#    'end'],
#   ['smart',
#    'money',
#    'getting',
#    'faangs',
#    'especially',
#    'amzn',
#    'fb',
#    'nflx',
#    'bubble',
#    'deflating',
#    'cash',
#    'becomes',
#    'attractive',
#    'higher',
#    'rate'],
#   ['volume', 'percent', 'volumebot', 'dhr'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'v'],
#   ['term', 'negative', 'there', 'bearish', 'indicator', 'dividendbot'],
#   ['huffingtonpost',
#    'entry',
#    'white',
#    'house',
#    'back',
#    'off',
#    'trump',
#    'tweet',
#    'oil',
#    'agreement',
#    'u',
#    'b',
#    'e',
#    'b',
#    'f',
#    'c',
#    'e',
#    'd'],
#   ['opportunity',
#    'intel',
#    'intc',
#    'monthly',
#    'demand',
#    'level',
#    'intel',
#    'intc',
#    'ha',
#    'clear',
#    'long',
#    'term',
#    'long',
#    'bias',
#    'opportunt'],
#   ['lot',
#    'people',
#    'chuckling',
#    'been',
#    'saying',
#    'year',
#    'selling',
#    'into',
#    'strength',
#    'since',
#    'monday',
#    'spanking',
#    'show',
#    'issue'],
#   ['break',
#    'level',
#    'resistance',
#    'hi',
#    'guy',
#    'novice',
#    'analysis',
#    'apc',
#    'any',
#    'insight',
#    'argument'],
#   ['ouch',
#    'started',
#    'trading',
#    'ago',
#    'shorter',
#    'return',
#    'would',
#    'around',
#    'iex',
#    'data',
#    'shortpainbot',
#    'ice'],
#   ['very',
#    'interesting',
#    'trend',
#    'month',
#    'chart',
#    'big',
#    'drop',
#    'followed',
#    'then',
#    'quick',
#    'sell',
#    'indicator',
#    'happens',
#    'before',
#    'every',
#    'run'],
#   ['come',
#    'bear',
#    'scare',
#    'them',
#    'because',
#    'want',
#    'cheaper',
#    'before',
#    'er',
#    'rip'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'sti'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['or', 'sell', 'investormint', 'investing', 'amazon'],
#   ['facebook',
#    'had',
#    'data',
#    'sharing',
#    'partnership',
#    'tech',
#    'firm',
#    'goo',
#    'gl',
#    'vhqwnh',
#    'facebook'],
#   ['bear', 'reason', 'pay', 'attention', 'dividendbot', 'jwn'],
#   ['earning',
#    'update',
#    'mccormick',
#    'company',
#    'incorporated',
#    'quarter',
#    'ending',
#    'may',
#    'revenue',
#    'rose',
#    'margin',
#    'contracted'],
#   ['aggregate', 'volume', 'reported', 'finra', 'volumebot', 'xel'],
#   ['could', 'going', 'lol', 'wc', 'le', 'vip', 'still', 'easy', 'monday'],
#   ['volume',
#    'th',
#    'percentile',
#    'term',
#    'last',
#    'trading',
#    'volumebot',
#    'intc'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['ouch',
#    'started',
#    'trading',
#    'ago',
#    'shorter',
#    'return',
#    'would',
#    'around',
#    'iex',
#    'data',
#    'shortpainbot',
#    'bmy'],
#   ['according',
#    'data',
#    'reported',
#    'finra',
#    'volume',
#    'percent',
#    'clocked',
#    'volumebot',
#    'sti'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'ice'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'ne'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['volume', 'percent', 'versus', 'volumebot', 'ne'],
#   ['gap', 'monday', 'big', 'sell', 'off', 'again'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['according',
#    'data',
#    'reported',
#    'finra',
#    'volume',
#    'percent',
#    'clocked',
#    'volumebot',
#    'cop'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['monday', 'wl'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['retailer',
#    'j',
#    'jill',
#    'ipo',
#    'd',
#    'bad',
#    'time',
#    'can',
#    'good',
#    'time',
#    'also',
#    'goo',
#    'gl',
#    'jnzntx'],
#   ['disney',
#    'never',
#    'missed',
#    'chance',
#    'push',
#    'their',
#    'liberal',
#    'unnatural',
#    'agenda',
#    'army',
#    'men',
#    'new',
#    'toy',
#    'story',
#    'land',
#    'ha',
#    'woman',
#    'absurd'],
#   ['aggregate', 'volume', 'reported', 'finra', 'volumebot', 'jwn'],
#   ['me',
#    'look',
#    'drop',
#    'off',
#    'due',
#    'wc',
#    'were',
#    'd',
#    'worry',
#    'think',
#    'hover',
#    'around',
#    'till'],
#   ['remember',
#    'drink',
#    'your',
#    'poison',
#    'water',
#    'need',
#    'get',
#    'back',
#    'over',
#    'september',
#    'lol',
#    'drink',
#    'little',
#    'bastard',
#    'drink'],
#   ['course', 'he', 'lied', 'again'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'pep'],
#   ['option',
#    'volume',
#    'x',
# ...
#    'least',
#    'he',
#    'get',
#    'low',
#    'gas',
#    'price',
#    'crucial',
#    'economy'],
#   ['said', 'about', 'year', 'ago'],
#   ['idt', 'product', 'power', 'management', 'wireless', 'power'],
#   ['great',
#    'summary',
#    'bill',
#    'ackman',
#    'letter',
#    'long',
#    'thesis',
#    'chipotle',
#    'investoralmanac',
#    'bill',
#    'ackmans',
#    'letter',
#    'utx',
#    'fnma',
#    'fmcc',
#    'cmg',
#    'adp',
#    'mdlz'],
#   ['ignore',
#    'noise',
#    'heading',
#    'higher',
#    'pullback',
#    'ha',
#    'happened',
#    'trend',
#    'higher'],
#   ['great',
#    'summary',
#    'bill',
#    'ackman',
#    'letter',
#    'long',
#    'thesis',
#    'mondelez',
#    'investoralmanac',
#    'bill',
#    'ackmans',
#    'letter',
#    'utx',
#    'fnma',
#    'fmcc',
#    'cmg',
#    'adp',
#    'mdlz'],
#   ['great',
#    'summary',
#    'bill',
#    'ackman',
#    'letter',
#    'long',
#    'thesis',
#    'adp',
#    'investoralmanac',
#    'bill',
#    'ackmans',
#    'letter',
#    'utx',
#    'fnma',
#    'fmcc',
#    'cmg',
#    'adp',
#    'mdlz'],
#   ['let', 'rip', 'next', 'week'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'presentation',
#    'long',
#    'thesis',
#    'energy',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'presentation',
#    'facebook',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['madtv', 'inlivingcolor', 'were', 'better', 'show'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['im',
#    'sorry',
#    'those',
#    'who',
#    'didnt',
#    'take',
#    'advice',
#    'good',
#    'news',
#    'should',
#    'coil',
#    'mid',
#    'then',
#    'eom'],
#   ['crypto',
#    'enth',
#    'look',
#    'lt',
#    'look',
#    'timeline',
#    'scam',
#    'info',
#    'vrs',
#    'net',
#    'neutrality',
#    'how',
#    'much',
#    'sky',
#    'would',
#    'cost',
#    'provider',
#    'bil',
#    'or',
#    'u',
#    'think'],
#   ['db',
#    'jan',
#    'attractive',
#    'discretionary',
#    'premium',
#    'doesn',
#    'look',
#    'juiced',
#    'yet',
#    'tech',
#    'too',
#    'much',
#    'bank',
#    'staple',
#    'undervalued'],
#   ['sure',
#    'felt',
#    'some',
#    'pain',
#    'shorted',
#    'first',
#    'their',
#    'ytd',
#    'return',
#    'around',
#    'shortpainbot',
#    'vrtx'],
#   ['can',
#    'whatever',
#    'open',
#    'spotify',
#    'track',
#    'ruzgdhaasjsfbemocsc',
#    'k',
#    'si',
#    'nek',
#    'zuzcstgg',
#    'uvvzs',
#    'bmg'],
#   ['tesla',
#    'hit',
#    'model',
#    'manufacturing',
#    'milestone',
#    'wk',
#    'reuters',
#    'article',
#    'u',
#    'tesla',
#    'model',
#    'exclusive',
#    'exclusive',
#    'tesla',
#    'hit',
#    'model',
#    'manufacturing',
#    'milestone',
#    'hour',
#    'after',
#    'deadline',
#    'factory',
#    'source',
#    'iduskbn',
#    'jr',
#    'wx'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'presentation',
#    'long',
#    'thesis',
#    'energy',
#    'equity',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['tesla', 'most', 'shorted', 'b', 'than', 'float'],
#   ['recent',
#    'technical',
#    'alert',
#    'expansion',
#    'pivot',
#    'setup',
#    'plus',
#    'alert',
#    'swingtradebot',
#    'equity',
#    'pld'],
#   ['polaris', 'nm', 'coming'],
#   ['fantastic',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'pres',
#    'long',
#    'thesis',
#    'energy',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['boooomski',
#    'wccftech',
#    'amd',
#    'gpu',
#    'rumor',
#    'nm',
#    'polaris',
#    'nm',
#    'navi',
#    'nm',
#    'vega',
#    'radeon',
#    'rx',
#    'gaming'],
#   ['although',
#    'doing',
#    'even',
#    'better',
#    'ha',
#    'advanced',
#    'info',
#    'peer',
#    'dividendbot',
#    'fmc'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['getting',
#    'real',
#    'tired',
#    'lazy',
#    'novice',
#    'adking',
#    'me',
#    'do',
#    'learn',
#    'stop',
#    'being',
#    'lazy'],
#   ['first', 'target'],
#   ['right', 'though', 'think', 'cheap', 'also', 'bargain', 'favorite'],
#   ['need',
#    'keep',
#    'an',
#    'eye',
#    'ntgn',
#    'interesting',
#    'entered',
#    'into',
#    'agreement',
#    'both'],
#   ['confused', 'bullish', 'or', 'bearish', 'lol'],
#   ['libya', 'export', 'kbd'],
#   ['next', 'target'],
#   ['yield',
#    'curve',
#    'flattening',
#    'crowd',
#    'selling',
#    'sector',
#    'imho',
#    'likely',
#    'too',
#    'early'],
#   ['investing',
#    'facebook',
#    'before',
#    'heard',
#    'get',
#    'point',
#    'hear',
#    'about',
#    'moviepass',
#    'no',
#    'worry'],
#   ['open', 'interest', 'maturity', 'high', 'put', 'high', 'maxpain', 'option'],
#   ['why', 'travel', 'could', 'trouble', 'vacation', 'season', 'begin'],
#   ['since',
#    'last',
#    'er',
#    'dropped',
#    'reporting',
#    'before',
#    'open',
#    'confirmed',
#    'co',
#    'zbh',
#    'jgi'],
#   ['bull', 'reason', 'pay', 'attention', 'dividendbot', 'col'],
#   ['there',
#    'reason',
#    'why',
#    'verizon',
#    'owns',
#    'company',
#    'chance',
#    'own',
#    'facebook',
#    'early',
#    'stage',
#    'own'],
#   ['downtrend', 'confirmed'],
#   ['worried',
#    'about',
#    'teriffs',
#    'going',
#    'target',
#    'eoy',
#    'usnews',
#    'opinion',
#    'economic',
#    'intelligence',
#    'article',
#    'dont',
#    'sweat',
#    'trump',
#    'steel',
#    'aluminum',
#    'tariff'],
#   ['end',
#    'quarter',
#    'win',
#    'booked',
#    'expect',
#    'announcement',
#    'early',
#    'july',
#    'somebody',
#    'know',
#    'something'],
#   ['since',
#    'price',
#    'steel',
#    'aluminum',
#    'really',
#    'undervalued',
#    'remember',
#    'isnt',
#    'sprint',
#    'marketwatch',
#    'story',
#    'new',
#    'tariff',
#    'raise',
#    'steel',
#    'aluminum',
#    'price'],
#   ['partnership', 'spike', 'incoming'],
#   ['should',
#    'would',
#    'increase',
#    'get',
#    'good',
#    'management',
#    'team',
#    'run',
#    'joint',
#    'co'],
#   ['july', 'nd', 'historically', 'most', 'bullish', 'year'],
#   ['pastor',
#    'bleeding',
#    'week',
#    'jfc',
#    'bullish',
#    'bullish',
#    'bearish',
#    'bearish',
#    'bearish',
#    'make',
#    'your',
#    'mind'],
#   ['bull', 'feeling', 'bullish', 'week', 'how', 'were', 'last', 'week'],
#   ['volume', 'percent', 'rank', 'th', 'percentile', 'volumebot', 'kmi'],
#   ['crucial', 'breakdown', 'week'],
#   ['sale', 'volume', 'interest', 'via'],
#   ['look', 'those', 'cheap', 'gpu', 'ebay', 'lol', 'gtx', 'x'],
#   ['u', 'get', 'payment', 'july', 'x', 'held'],
#   ['look', 'those', 'cheap', 'gpu', 'ebay', 'lol', 'gtx', 'x'],
#   ['going',
#    'thru',
#    'industry',
#    'sector',
#    'scan',
#    'leading',
#    'sector',
#    'ytd',
#    'retail',
#    'jewelry',
#    'ibdpartner'],
#   ['similar',
#    'er',
#    'move',
#    'when',
#    'were',
#    'acquiring',
#    'bunch',
#    'thing',
#    'lowered',
#    'profit',
#    'why',
#    'had',
#    'gaap',
#    'no',
#    'gaap'],
#   ['great', 'analysis', 'thanks', 'sharing'],
#   ['don',
#    'believe',
#    'growth',
#    'slowing',
#    'when',
#    'u',
#    'can',
#    'get',
#    'biz',
#    'loan',
#    'historically',
#    'low',
#    'rate'],
#   ['interest', 'ratio', 'float', 'via'],
#   ['think', 'bigly', 'week'],
#   ['exited',
#    'thursday',
#    'gain',
#    'mo',
#    'bad',
#    're',
#    'enter',
#    'below',
#    'rinse',
#    'repeat',
#    'woof'],
#   ['releasing',
#    'before',
#    'open',
#    'confirmed',
#    'anybody',
#    'buying',
#    'selling',
#    'co',
#    'g',
#    'odzlwhnd'],
#   ['going',
#    'wake',
#    'or',
#    'le',
#    'tomorrow',
#    'too',
#    'much',
#    'negative',
#    'sentiment'],
#   ['how',
#    'apple',
#    'inc',
#    'aapl',
#    'could',
#    'get',
#    'pulled',
#    'into',
#    'trump',
#    'war',
#    'china',
#    'stocknews',
#    'io',
#    'news',
#    'how',
#    'apple',
#    'inc',
#    'aapl',
#    'could',
#    'get',
#    'pulled',
#    'into',
#    'trump',
#    'war',
#    'china',
#    'stocknews',
#    'index',
#    'html'],
#   ['doubling'],
#   ['new', 'quarter', 'time', 'too'],
#   ['term', 'positive', 'there', 'bullish', 'indicator', 'dividendbot', 'mdlz'],
#   ['since',
#    'last',
#    'er',
#    'dropped',
#    'reporting',
#    'before',
#    'open',
#    'confirmed',
#    'co',
#    'etemxzh'],
#   ['adding', 'too', 'good', 'pas'],
#   ['tesla', 'squeezed', 'week', 'know', 'banking', 'u', 'biz'],
#   ['last',
#    'week',
#    'window',
#    'dressing',
#    'mid',
#    'year',
#    'period',
#    'monday',
#    'start',
#    'july',
#    'run',
#    'er'],
#   ['open', 'interest', 'maturity', 'high', 'put', 'high', 'maxpain', 'option'],
#   ['since',
#    'last',
#    'er',
#    'dropped',
#    'reporting',
#    'before',
#    'open',
#    'confirmed',
#    'co',
#    'ewjz',
#    'b',
#    'phq'],
#   ['can', 'feel', 'hate', 'trump', 'going', 'zero'],
#   ['quot', 'ai', 'quot', 'alone', 'company', 'reign', 'year'],
#   ['insight', 'app', 'seasonaledge', 'tool', 'fmc'],
#   ['look',
#    'folk',
#    'pulled',
#    'off',
#    'got',
#    'polish',
#    'process',
#    'work',
#    'kink'],
#   ['carnage', 'tmr'],
#   ['thesis', 'over'],
#   ['bye', 'bye', 'facebook', 'bearish'],
#   ['target',
#    'before',
#    'deal',
#    'should',
#    'yet',
#    'only',
#    'gt',
#    'our',
#    'china',
#    'play',
#    'sale'],
#   ['corning',
#    'valuation',
#    'profitability',
#    'dividend',
#    'safety',
#    'score',
#    'analysis',
#    'dividend',
#    'technology',
#    'valueinvesting'],
#   ['so',
#    'far',
#    'no',
#    'word',
#    'tariff',
#    'evil',
#    'orange',
#    'should',
#    'lead',
#    'green',
#    'tomorrow',
#    'continue',
#    'trend',
#    'upwards'],
#   ['tomorrow'],
#   ['industry', 'fack'],
#   ['own', 'buying', 'payday', 'friday'],
#   ['growth', 'wondering', 'gonna', 'again'],
#   ['produce',
#    'x',
#    'many',
#    'vehicle',
#    'tesla',
#    'ha',
#    'higher',
#    'cap',
#    'bull',
#    'want',
#    'cap',
#    'over',
#    'billion'],
#   ['end', 'month'],
#   ['anyone',
#    'wanting',
#    'practice',
#    'using',
#    'simulator',
#    'please',
#    'check',
#    'leave',
#    'review',
#    'play',
#    'google',
#    'store',
#    'apps',
#    'detail',
#    'id',
#    'target',
#    'android',
#    'bullvest'],
#   ['everything', 'need', 'know', 'morning', 'daybreak', 'audio', 'via'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'presentation',
#    'long',
#    'thesis',
#    'energy',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['option',
#    'volume',
#    'x',
#    'normal',
#    'friday',
#    'contract',
#    'volume',
#    'put',
#    'volume'],
#   ['recent',
#    'technical',
#    'alert',
#    'dma',
#    'resistance',
#    'plus',
#    'alert',
#    'swingtradebot',
#    'equity',
#    'key'],
#   ['back',
#    'order',
#    'ridiculous',
#    'tlsa',
#    'can',
#    'easily',
#    'top',
#    'ramp',
#    'production',
#    'k'],
#   ['great',
#    'summary',
#    'jeff',
#    'gundlach',
#    'sohn',
#    'conference',
#    'pres',
#    'long',
#    'thesis',
#    'energy',
#    'investoralmanac',
#    'jeffrey',
#    'gundlach',
#    'long',
#    'energy',
#    'facebook'],
#   ['term', 'negative', 'there', 'bearish', 'indicator', 'dividendbot', 'cah'],
#   ['youtu', 'j', 'numesee', 'w'],
#   ['bullish', 'or', 'bearish'],
#   ['raise', 'hand', 'bought', 'when', 'dipped', 'around', 'because', 'did'],
#   ['three', 'big', 'volume'],
#   ['dude',
#    'month',
#    'sure',
#    'could',
#    'dn',
#    'tom',
#    'future',
#    'very',
#    'bright',
#    'even',
#    'without',
#    'stevie',
#    'fuckface'],
#   ...],
#  'sentiments': [4,
#   4,
#   3,
#   3,
#   0,
#   3,
#   4,
#   0,
#   4,
#   0,
#   4,
#   4,
#   4,
#   3,
#   4,
#   2,
#   4,
#   3,
#   3,
#   3,
#   1,
#   2,
#   3,
#   3,
#   0,
#   4,
#   4,
#   0,
#   3,
#   2,
#   1,
#   2,
#   3,
#   2,
#   3,
#   4,
#   3,
#   4,
#   3,
#   3,
#   2,
#   3,
#   3,
#   3,
#   3,
#   1,
#   4,
#   3,
#   4,
#   0,
#   3,
#   0,
#   2,
#   1,
#   4,
#   1,
#   3,
#   4,
#   1,
#   0,
#   2,
#   4,
#   2,
#   2,
#   4,
#   4,
#   3,
#   4,
#   2,
#   0,
#   0,
#   0,
#   2,
#   3,
#   1,
#   1,
#   2,
#   3,
#   0,
#   0,
#   4,
#   4,
#   2,
#   3,
#   3,
#   2,
#   4,
#   0,
#   4,
#   3,
#   3,
#   4,
#   2,
#   2,
#   4,
#   1,
#   1,
#   4,
#   2,
#   2,
#   3,
#   2,
#   2,
#   4,
#   1,
#   2,
#   0,
#   3,
#   0,
#   4,
#   2,
#   4,
#   3,
#   3,
#   1,
#   2,
#   4,
#   1,
#   2,
#   3,
#   0,
#   0,
#   2,
#   0,
#   1,
#   3,
#   2,
#   3,
#   0,
#   4,
#   4,
#   4,
#   1,
#   0,
#   2,
#   1,
#   3,
#   4,
#   2,
#   1,
#   4,
#   3,
#   0,
#   3,
#   1,
#   3,
#   2,
#   2,
#   3,
#   1,
#   4,
#   1,
#   1,
#   0,
#   3,
#   2,
#   3,
#   1,
#   4,
#   3,
#   0,
#   3,
#   1,
#   3,
#   3,
#   3,
#   4,
#   2,
#   2,
#   2,
#   0,
#   1,
#   0,
#   2,
#   0,
#   0,
#   0,
#   3,
#   2,
#   0,
#   1,
#   3,
#   4,
#   3,
#   3,
#   1,
#   1,
#   4,
#   2,
#   3,
#   2,
#   3,
#   3,
#   1,
#   1,
#   2,
#   1,
#   0,
#   3,
#   4,
#   2,
#   4,
#   2,
#   0,
#   3,
#   2,
#   0,
#   4,
#   4,
#   3,
#   2,
#   3,
#   2,
#   3,
#   0,
#   2,
#   0,
#   2,
#   2,
#   0,
#   1,
#   3,
#   2,
#   1,
#   1,
#   2,
#   3,
#   3,
#   1,
#   2,
#   3,
#   0,
#   1,
#   4,
#   3,
#   0,
#   0,
#   3,
#   3,
#   4,
#   3,
#   1,
#   3,
#   4,
#   0,
#   2,
#   3,
#   4,
#   4,
#   3,
#   2,
#   2,
#   4,
#   3,
#   3,
#   1,
#   1,
#   4,
#   3,
#   3,
#   4,
#   3,
#   0,
#   3,
#   0,
#   1,
#   3,
#   1,
#   2,
#   2,
#   1,
#   3,
#   0,
#   4,
#   2,
#   2,
#   0,
#   4,
#   3,
#   0,
#   3,
#   0,
#   0,
#   1,
#   0,
#   0,
#   4,
#   0,
#   0,
#   1,
#   0,
#   3,
#   1,
#   0,
#   3,
#   3,
#   4,
#   3,
#   1,
#   3,
#   0,
#   0,
#   1,
#   3,
#   2,
#   0,
#   3,
#   0,
#   1,
#   2,
#   1,
#   2,
#   2,
#   0,
#   4,
#   4,
#   0,
#   1,
#   4,
#   2,
#   0,
#   3,
#   2,
#   4,
#   0,
#   2,
#   0,
#   4,
#   0,
#   3,
#   4,
#   2,
#   1,
#   1,
#   1,
#   2,
#   1,
#   1,
#   3,
#   0,
#   3,
#   1,
#   0,
#   0,
#   3,
#   4,
#   1,
#   3,
#   0,
#   2,
#   4,
#   0,
#   0,
#   1,
#   4,
#   0,
#   1,
#   0,
#   2,
#   1,
#   3,
#   4,
#   2,
#   4,
#   0,
#   3,
#   0,
#   2,
#   0,
#   3,
#   1,
#   0,
#   0,
#   1,
#   1,
#   1,
#   0,
#   3,
#   0,
#   3,
#   4,
#   0,
#   1,
#   2,
#   4,
#   4,
#   2,
#   1,
#   0,
#   2,
#   2,
#   0,
#   3,
#   0,
#   3,
#   0,
#   1,
#   2,
#   1,
#   2,
#   2,
#   1,
#   0,
#   0,
#   1,
#   1,
#   1,
#   3,
#   0,
#   4,
#   3,
#   0,
#   1,
#   4,
#   2,
#   1,
#   3,
#   2,
#   0,
#   3,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   0,
#   4,
#   4,
#   2,
#   4,
#   0,
#   4,
#   0,
#   0,
#   3,
#   0,
#   0,
#   3,
#   1,
#   3,
#   4,
#   3,
#   1,
#   3,
#   3,
#   3,
#   3,
#   2,
#   0,
#   2,
#   3,
#   3,
#   3,
#   0,
#   3,
#   1,
#   2,
#   4,
#   0,
#   0,
#   1,
#   2,
#   3,
#   2,
#   0,
#   1,
#   3,
#   2,
#   3,
#   4,
#   2,
#   4,
#   0,
#   2,
#   4,
#   4,
#   3,
#   0,
#   3,
#   0,
#   0,
#   0,
#   3,
#   2,
#   2,
#   4,
#   4,
#   2,
#   4,
#   0,
#   0,
#   3,
#   0,
#   2,
#   0,
#   2,
#   2,
#   0,
#   0,
#   1,
#   2,
#   4,
#   4,
#   3,
#   0,
#   1,
#   0,
#   2,
#   3,
#   4,
#   2,
#   0,
#   3,
#   3,
#   0,
#   1,
#   0,
#   2,
#   3,
#   2,
#   2,
#   0,
#   2,
#   0,
#   4,
#   4,
#   1,
#   2,
#   4,
#   3,
#   1,
#   4,
#   2,
#   2,
#   2,
#   0,
#   2,
#   0,
#   3,
#   2,
#   2,
#   4,
#   4,
#   2,
#   2,
#   2,
#   2,
#   0,
#   2,
#   2,
#   3,
#   4,
#   2,
#   4,
#   1,
#   0,
#   2,
#   2,
#   4,
#   3,
#   3,
#   2,
#   3,
#   1,
#   0,
#   2,
#   4,
#   0,
#   1,
#   0,
#   3,
#   2,
#   4,
#   0,
#   0,
#   0,
#   0,
#   2,
#   2,
#   1,
#   3,
#   2,
#   1,
#   1,
#   2,
#   0,
#   4,
#   0,
#   1,
#   2,
#   1,
#   2,
#   2,
#   3,
#   0,
#   1,
#   2,
#   3,
#   3,
#   2,
#   1,
#   2,
#   0,
#   2,
#   1,
#   1,
#   0,
#   1,
#   2,
#   1,
#   1,
#   4,
#   1,
#   0,
#   1,
#   2,
#   2,
#   2,
#   2,
#   0,
#   0,
#   2,
#   2,
#   3,
#   2,
#   1,
#   1,
#   4,
#   1,
#   3,
#   2,
#   2,
#   1,
#   2,
#   2,
#   0,
#   2,
#   2,
#   1,
#   2,
#   3,
#   2,
#   0,
#   4,
#   2,
#   2,
#   2,
#   2,
#   3,
#   4,
#   2,
#   3,
#   2,
#   2,
#   3,
#   0,
#   2,
#   2,
#   4,
#   4,
#   3,
#   3,
#   3,
#   2,
#   3,
#   2,
#   2,
#   3,
#   4,
#   2,
#   3,
#   4,
#   1,
#   2,
#   2,
#   3,
#   3,
#   4,
#   2,
#   2,
#   2,
#   0,
#   0,
#   2,
#   0,
#   4,
#   0,
#   3,
#   4,
#   0,
#   3,
#   4,
#   0,
#   4,
#   1,
#   0,
#   0,
#   2,
#   4,
#   2,
#   0,
#   0,
#   4,
#   3,
#   3,
#   2,
#   3,
#   4,
#   3,
#   3,
#   3,
#   2,
#   1,
#   3,
#   3,
#   1,
#   4,
#   4,
#   1,
#   3,
#   3,
#   3,
#   0,
#   1,
#   1,
#   1,
#   0,
#   0,
#   2,
#   1,
#   0,
#   0,
#   2,
#   4,
#   3,
#   4,
#   3,
#   2,
#   3,
#   4,
#   1,
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   3,
#   2,
#   3,
#   4,
#   3,
#   2,
#   3,
#   3,
#   4,
#   4,
#   0,
#   1,
#   2,
#   4,
#   1,
#   2,
#   3,
#   0,
#   1,
#   3,
#   4,
#   3,
#   3,
#   3,
#   3,
#   3,
#   2,
#   1,
#   4,
#   2,
#   1,
#   3,
#   3,
#   2,
#   2,
#   4,
#   4,
#   2,
#   0,
#   4,
#   1,
#   3,
#   0,
#   3,
#   2,
#   1,
#   3,
#   2,
#   3,
#   0,
#   4,
#   3,
#   4,
#   4,
#   4,
#   3,
#   0,
#   3,
#   3,
#   3,
#   4,
#   3,
#   2,
#   0,
#   4,
#   3,
#   3,
#   4,
#   0,
#   3,
#   2,
#   3,
#   0,
#   4,
#   2,
#   4,
#   1,
#   4,
#   3,
#   3,
#   2,
#   0,
#   2,
#   4,
#   1,
#   0,
#   3,
#   0,
#   4,
#   4,
#   2,
#   3,
#   4,
#   3,
#   3,
#   4,
#   3,
#   3,
#   1,
#   4,
#   3,
#   4,
#   4,
#   0,
#   3,
#   0,
#   4,
#   1,
#   1,
#   4,
#   4,
#   3,
#   4,
#   4,
#   1,
#   2,
#   2,
#   1,
#   4,
#   2,
#   3,
#   0,
#   3,
#   2,
#   1,
#   3,
#   1,
#   3,
#   3,
#   3,
#   2,
#   1,
#   4,
#   3,
#   3,
#   4,
#   3,
#   2,
#   4,
#   3,
#   3,
#   0,
#   3,
#   0,
#   3,
#   4,
#   1,
#   4,
#   2,
#   0,
#   3,
#   3,
#   4,
#   3,
#   4,
#   4,
#   4,
#   4,
#   0,
#   3,
#   1,
#   4,
#   0,
#   4,
#   0,
#   3,
#   2,
#   4,
#   0,
#   4,
#   3,
#   4,
#   2,
#   2,
#   1,
#   2,
#   4,
#   3,
#   2,
#   1,
#   1,
#   4,
#   1,
#   3,
#   2,
#   1,
#   1,
#   3,
#   3,
#   0,
#   4,
#   2,
#   4,
#   3,
#   4,
#   3,
#   0,
#   4,
#   0,
#   1,
#   1,
#   1,
#   2,
#   2,
#   2,
#   1,
#   2,
#   3,
#   0,
#   1,
#   4,
#   2,
#   0,
#   2,
#   0,
#   4,
#   3,
#   1,
#   1,
#   3,
#   3,
#   2,
#   1,
#   2,
#   2,
#   2,
#   3,
#   2,
#   3,
#   0,
#   3,
#   2,
#   4,
#   4,
#   3,
#   4,
#   1,
#   3,
#   4,
#   2,
#   2,
#   4,
#   2,
#   1,
#   2,
#   4,
#   0,
#   3,
#   1,
#   3,
#   3,
#   2,
#   ...]}

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.19675034466188257

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %%
plt.hist(sentiments)
plt.show()

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout
        
        # TODO Implement

        # Setup embedding layer
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
        # Setup additional layers
        
        self.lstm = nn.LSTM(embed_size, lstm_size, lstm_layers, 
                            dropout=dropout, batch_first=False)
        self.dropout = nn.Dropout(dropout)
        
        # linear and softmat layers
        self.fc = nn.Linear(lstm_size, output_size)
        self.Softmax = nn.LogSoftmax(dim=1)
        
        
        


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        
        # TODO Implement 
        
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        
        weight = next(self.parameters()).data
        
        
        hidden_state = (weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_(),
                      weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_())
        
        
        return hidden_state

    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        
        # TODO Implement 
        # the embeddings and the lsmt output
        embedds = self.embedding(nn_input)
        lstm_output, hidden_state = self.lstm(embedds, hidden_state)
        
        # stacking the lsmt outputs
        lstm_output = lstm_output[-1, :, :]
        
        # dropout and fully-connected layer
        out = self.dropout(self.fc(lstm_output))
        
                                  
        log_softout = F.log_softmax(out, dim=1)
        
      
          
          
        
        # return last softmax output and hidden state
        return log_softout, hidden_state

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, dropout=0.1, lstm_layers=2)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.4690, -1.9862, -1.1977, -1.8629, -1.7400],
#         [-1.4875, -1.9860, -1.1662, -1.8875, -1.7497],
#         [-1.4895, -1.9820, -1.1640, -1.8906, -1.7515],
#         [-1.4979, -1.9912, -1.1687, -1.8786, -1.7356]])

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
# With our data in nice shape, we'll split it into training and validation sets.

# %%
import numpy as np

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   

# TODO Implement 
spit_frac = 0.8
split_idx = int(len(token_ids)*0.8)

train_features = token_ids[:split_idx]
valid_features = token_ids[split_idx:]
train_labels = sentiments[:split_idx]
valid_labels = sentiments[split_idx:]

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(130566, 1024)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=512, out_features=5, bias=True)
#   (Softmax): LogSoftmax()
# )

# %%
"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""

epochs = 3
batch_size = 2048
learning_rate = 0.001
clip = 5

print_every = 100
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
model.train()

for epoch in range(epochs):
    print('Starting epoch {}'.format(epoch + 1))
    
    steps = 0
    for text_batch, labels in dataloader(
            train_features, train_labels, sequence_length=20, batch_size=batch_size, shuffle=True):
        
        steps += 1
        hidden = model.init_hidden(batch_size=labels.shape[0])
        hidden = tuple([each.data for each in hidden]) # pass
        
        
        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
        
        
        # TODO Implement: Train Model
        
        #zero accumulated gradient
        model.zero_grad()
        #get the output from the model
        output, hidden = model(text_batch, hidden)
        # calculate the loss and perform backprop
        loss = criterion(output, labels)
        loss.backward()
        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        
        
        if steps % print_every == 0:
            val_losses = []
            model.eval()
            
            # TODO Implement: Print metrics
            for val_text_batch, val_labels in dataloader(valid_features, valid_labels, 
                                                         sequence_length=20, batch_size=batch_size, shuffle=True):
                
                val_h = model.init_hidden(val_labels.shape[0])
                val_h = tuple([each.data for each in val_h])
                if(torch.cuda.is_available()):
                    val_text_batch, val_labels = val_text_batch.cuda(), val_labels.cuda()
                    val_output, val_h = model(val_text_batch, val_h)
                    val_loss = criterion(val_output, val_labels)
                    val_losses.append(val_loss.item())
                    
            model.train()
            print("Epoch: {}/{}...".format(epoch+1, epochs),
                  "Step: {}...".format(steps),
                  "Loss: {:.6f}...".format(loss.item()),
                  "Val Loss: {:.6f}".format(np.mean(val_losses)))
# Out:
# Starting epoch 1
# Epoch: 1/3... Step: 100... Loss: 1.106985... Val Loss: 1.067796
# Epoch: 1/3... Step: 200... Loss: 1.077192... Val Loss: 1.011272
# Epoch: 1/3... Step: 300... Loss: 1.004887... Val Loss: 0.983774
# Epoch: 1/3... Step: 400... Loss: 1.000410... Val Loss: 0.965169
# Starting epoch 2
# Epoch: 2/3... Step: 100... Loss: 0.947774... Val Loss: 0.947150
# Epoch: 2/3... Step: 200... Loss: 0.959927... Val Loss: 0.945473
# Epoch: 2/3... Step: 300... Loss: 0.969988... Val Loss: 0.940402
# Epoch: 2/3... Step: 400... Loss: 0.972091... Val Loss: 0.926168
# Starting epoch 3
# Epoch: 3/3... Step: 100... Loss: 0.915670... Val Loss: 0.945178
# Epoch: 3/3... Step: 200... Loss: 0.917243... Val Loss: 0.937933
# Epoch: 3/3... Step: 300... Loss: 0.910673... Val Loss: 0.931077
# Epoch: 3/3... Step: 400... Loss: 0.900268... Val Loss: 0.924010

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
def predict(text, model, vocab):
    """ 
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    
    
    # TODO Implement
    
    tokens = preprocess(text)
    
    # Filter non-vocab words
    tokens = [word for word in tokens if word in vocab]
    # Convert words to ids
    
    tokens = [vocab[word] for word in tokens]
             
        
    # Adding a batch dimension
    text_input = torch.tensor(tokens).view(-1, 1)
    # Get the NN output
    hidden = model.init_hidden(1)
    logps, _ = model(text_input, hidden)
    # Take the exponent of the NN output to get a range of 0 to 1 for each label.
    pred = torch.exp(logps)
    
    return pred

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# tensor([[ 0.0020,  0.0237,  0.0136,  0.8212,  0.1395]])

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
# ** TODO: Answer Question**
#
#
# The model predicts that text is a positive sentiment with 82% of chance.

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %%
# test
twit = test_data['data'][4]
twit
# Out:
# {'message_body': '$AMZN A lot of technical signs point to a short-term bottom in place for stocks (John Murphy)',
#  'timestamp': '2018-11-01T00:00:42Z'}

# %%
test_data['data']
# Out:
# [{'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#   'timestamp': '2018-11-01T00:00:05Z'},
#  {'message_body': '$MCD bt puts when Cramer touted going to $200 so for a profit and bt back yesterday down on up day is good $PEP looks lower too',
#   'timestamp': '2018-11-01T00:00:05Z'},
#  {'message_body': '$AAPL 190 after ER', 'timestamp': '2018-11-01T00:00:18Z'},
#  {'message_body': '$PYPL Insider &quot;Pentland Adele Louise&quot; just cashed in 8,149 Options (Tran Code - M, S)  --- Insider Forms, iOS app',
#   'timestamp': '2018-11-01T00:00:25Z'},
#  {'message_body': '$AMZN A lot of technical signs point to a short-term bottom in place for stocks (John Murphy)',
#   'timestamp': '2018-11-01T00:00:42Z'},
#  {'message_body': '$AAPL https://stockcharts.com/freecharts/pnf.php?c=aapl,PWTAWANRBO[PA][D][F1!3!!!2!20]',
#   'timestamp': '2018-11-01T00:00:55Z'},
#  {'message_body': '$NFLX Option Order Flow Sentiment is 60.9% Bullish. http://tinyurl.com/y6v6lnmz',
#   'timestamp': '2018-11-01T00:01:48Z'},
#  {'message_body': 'Long Only: $BAC, $CGC, and $EXTR.\nLong &amp; Puts: $IQ.\nShort: $MU, $AMD, and $NVDA.',
#   'timestamp': '2018-11-01T00:02:10Z'},
#  {'message_body': '$GE held while $SPY dove at close. Solid lunch bids and hold on prior low. Will look to unload my 10.5 calls either at open or run up.',
#   'timestamp': '2018-11-01T00:03:05Z'},
#  {'message_body': '$AMD interesting close.',
#   'timestamp': '2018-11-01T00:03:09Z'},
#  {'message_body': '$AMZN Like what i see here',
#   'timestamp': '2018-11-01T00:03:35Z'},
#  {'message_body': '$CELG max pain is 74 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:03:38Z'},
#  {'message_body': '@TraderLeibniz $NVDA Perhaps, no chance for $MU and $AMD till cycle &amp; trade war no longer concerns.... played these names for years. GL',
#   'timestamp': '2018-11-01T00:04:21Z'},
#  {'message_body': '$NKE maybe NKE can do a believe in something add with The Blexit Movement. 👍',
#   'timestamp': '2018-11-01T00:04:22Z'},
#  {'message_body': '$HCA \nhttps://www.google.com/amp/s/www.cnbc.com/amp/2018/10/30/hca-healthcare-jumps-after-strong-earnings-and-forward-guidance.html',
#   'timestamp': '2018-11-01T00:04:34Z'},
#  {'message_body': '@DrKillinger ya someone “downgraded“ $amzn by 6% purely because of possible interest rate hikes.',
#   'timestamp': '2018-11-01T00:05:08Z'},
#  {'message_body': 'Shorts have sure felt some pain in $MA. If shorted on the first, their YTD return is around -24.25% as of 10-31 https://www.shortpainbot.com?s=MA',
#   'timestamp': '2018-11-01T00:05:10Z'},
#  {'message_body': '$ORLY I&#39;ve seen orly green on red days . What is the reason for the fall?',
#   'timestamp': '2018-11-01T00:05:13Z'},
#  {'message_body': '$CF max pain is 44 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:05:28Z'},
#  {'message_body': '$PYPL new insider selling: 8149 shares. http://insiderbuyingselling.com/?t=PYPL',
#   'timestamp': '2018-11-01T00:05:36Z'},
#  {'message_body': '$BLK sorry, cant rotate photo',
#   'timestamp': '2018-11-01T00:05:37Z'},
#  {'message_body': 'Today&#39;s insight on $AAPL https://app.seasonaledge.com/tools/I/AAPL',
#   'timestamp': '2018-11-01T00:05:40Z'},
#  {'message_body': 'Short volume percent for $CHK was 59.5% on 10-31-18 and 20 day rank was ~60th percentile  https://volumebot.com/?s=CHK',
#   'timestamp': '2018-11-01T00:05:53Z'},
#  {'message_body': 'Today&#39;s insight on $APA https://app.seasonaledge.com/tools/I/APA',
#   'timestamp': '2018-11-01T00:06:17Z'},
#  {'message_body': '$XLP consumer staples still the strong sector right now. $PG $PEP $KO $MO $CLX $HSY',
#   'timestamp': '2018-11-01T00:06:36Z'},
#  {'message_body': '$CELG Great robbery from sucking management and manipulative hedge funds to get to this price.',
#   'timestamp': '2018-11-01T00:06:49Z'},
#  {'message_body': 'The Tides Are Turning And That Means Stocks Are About To Rise https://wp.me/p6NqCb-53G  $qqq $spy $amzn $nflx $mu $msft $amd $fxi $dxy $SMH',
#   'timestamp': '2018-11-01T00:07:06Z'},
#  {'message_body': 'Today&#39;s insight on $ESRX https://app.seasonaledge.com/tools/I/ESRX',
#   'timestamp': '2018-11-01T00:07:30Z'},
#  {'message_body': 'Bears tomorrow when $AAPL reports earnings and the rest of the market rips higher. $AMZN $SQ $IBM $IEP $AVGO $MSFT $TSLA $NFLX $GOOG $DIA',
#   'timestamp': '2018-11-01T00:07:32Z'},
#  {'message_body': '$KR Kroger Company Option Order Flow Sentiment has Shifted from Bullish to Bearish. http://tinyurl.com/y96h5cyd',
#   'timestamp': '2018-11-01T00:07:44Z'},
#  {'message_body': '$WMT Good long entry here',
#   'timestamp': '2018-11-01T00:08:28Z'},
#  {'message_body': 'Today&#39;s insight on $GM https://app.seasonaledge.com/tools/I/GM',
#   'timestamp': '2018-11-01T00:08:44Z'},
#  {'message_body': '$CHK max pain is 3.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:08:45Z'},
#  {'message_body': '$aapl $fb $twtr $spy $baba $baidu\nPretty nice strategy for apple option play tmmrw &amp; friday\n\nhttps://www.youtube.com/watch?v=3d9z7sV54i0',
#   'timestamp': '2018-11-01T00:08:49Z'},
#  {'message_body': '$FB @SMProTrades PT: $160 by Friday',
#   'timestamp': '2018-11-01T00:08:52Z'},
#  {'message_body': '$MU https://www.thestreet.com/amp/opinion/micron-and-universal-display-boost-from-samsung-earnings-14764406?__twitter_impression=true',
#   'timestamp': '2018-11-01T00:08:56Z'},
#  {'message_body': '$BMY has a bad technical rating, but it does show a decent setup pattern. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=TA&amp;utm_content=SETUP&amp;utm_campaign=social_tracking#/BMY?key=2001b027-9d63-4fea-985c-211d9bf9cff9',
#   'timestamp': '2018-11-01T00:08:58Z'},
#  {'message_body': 'Today&#39;s insight on $WMB https://app.seasonaledge.com/tools/I/WMB',
#   'timestamp': '2018-11-01T00:09:21Z'},
#  {'message_body': 'S&amp;P 500 Ends Bruising October with Back-to-Back Gain\n\n$QQQ $TMUS $BAC $EBAY $JPM $GM $K $FB $SPY $ADP  \n\nhttps://www.briefing.com/investor/markets/stock-market-update/2018/10/31/s-and-p-500-ends-bruising-october-with-backtoback-gains.htm',
#   'timestamp': '2018-11-01T00:09:31Z'},
#  {'message_body': '$CHRW max pain is 87.5 for expiry 2018-11-16 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:09:34Z'},
#  {'message_body': '$AAPL Delayed short VOL 42%, short float 0.79% inc...mini squeeze.',
#   'timestamp': '2018-11-01T00:09:35Z'},
#  {'message_body': '@Buffett15 This is why they are both buys. In 2 years I think $GE will be $20 a share and $T will hit $40 sooner than that.',
#   'timestamp': '2018-11-01T00:09:47Z'},
#  {'message_body': '$tsla $bidu $dgaz $jnug $amd\n Pretty nice strategy for apple option play tmmrw &amp; friday\nhttps://www.youtube.com/watch?v=3d9z7sV54i0',
#   'timestamp': '2018-11-01T00:09:52Z'},
#  {'message_body': '$AMD Man I really wanted to buy some , but you wouldn’t let it hit my price! Jerks!!!',
#   'timestamp': '2018-11-01T00:10:03Z'},
#  {'message_body': '#STAAnalystAlert for $HOG : Citigroup Lowers Target with a rating of Buy setting target price at USD 45.00. Our own verdict is Hold  http://www.stocktargetadvisor.com/toprating',
#   'timestamp': '2018-11-01T00:10:10Z'},
#  {'message_body': '$AAPL bad quarter means disaster. This thing has singlehandedly kept the market afloat for the last 2 months. No position, just waiting',
#   'timestamp': '2018-11-01T00:10:17Z'},
#  {'message_body': '$aapl $fb $twtr $spy $baba $SPX \nPretty nice strategy for apple option play tmmrw &amp; friday for a put\nhttps://www.youtube.com/watch?v=3d9z7sV54i0',
#   'timestamp': '2018-11-01T00:10:32Z'},
#  {'message_body': '$CI max pain is 205 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:10:33Z'},
#  {'message_body': '3 Energy Stocks to Consider Ahead of Earnings\n\n$CVX $XOM $DUK \n\nhttps://investorplace.com/2018/10/3-energy-stocks-to-buy-earnings-preview-xom-cvx-duk/',
#   'timestamp': '2018-11-01T00:10:38Z'},
#  {'message_body': '$TWTR $INTC Iowa GOP Lawmaker Vows to Win Re- Election Despite Party&amp;aposs Rebuke via http://www.hvper.com/?ref=stw',
#   'timestamp': '2018-11-01T00:11:00Z'},
#  {'message_body': 'M&amp;A rumor : $AAPL is gonna buy $MU',
#   'timestamp': '2018-11-01T00:11:02Z'},
#  {'message_body': '$AAPL what happens to Apple if Trump stops them building their phones in China',
#   'timestamp': '2018-11-01T00:11:26Z'},
#  {'message_body': '$CINF max pain is 75 for expiry 2018-11-16 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:11:33Z'},
#  {'message_body': '$AAPL  Wednesday Apple Rumors: Apple Releases First iOS 12.1.1 Beta\n\nhttps://investorplace.com/2018/10/wednesday-apple-rumors-apple-releases-first-ios-12-1-1-beta/',
#   'timestamp': '2018-11-01T00:11:40Z'},
#  {'message_body': '$AAPL $AMZN $AMD $MU $TSLA $SPY  Month Recap. HIP HOP RAP!! For fun, enjoy:  https://youtu.be/3--3iSdJ1SQ',
#   'timestamp': '2018-11-01T00:11:54Z'},
#  {'message_body': '$AMZN Looks like the algos sign inverted. I think we going up and up. What do you think?',
#   'timestamp': '2018-11-01T00:12:20Z'},
#  {'message_body': '$CL max pain is 64.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:12:43Z'},
#  {'message_body': '$GE resident bear upsell has made some amazing calls recently. Check his track record🤣🤣😊',
#   'timestamp': '2018-11-01T00:12:53Z'},
#  {'message_body': 'AH Closing Price &amp;/or Vol Leaders (a/o8pmEST): $SGYP $HK $ECR $FIT $MOH $HRTX $STAA $WTI $DCIX $MTDR $QRVO $NFX',
#   'timestamp': '2018-11-01T00:12:56Z'},
#  {'message_body': '$NE Wth happened here today? Seems like the little guy wants it to succeed, but then reality sets in',
#   'timestamp': '2018-11-01T00:13:02Z'},
#  {'message_body': '$CLF max pain is 11 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:14:02Z'},
#  {'message_body': '$GE im out but what a great company..contraian ..too many corp mang changes it will survive',
#   'timestamp': '2018-11-01T00:14:25Z'},
#  {'message_body': '$FIT On tap $W $GPRO $AAPL',
#   'timestamp': '2018-11-01T00:14:43Z'},
#  {'message_body': '$SPY $FB More volatility ahead it seems',
#   'timestamp': '2018-11-01T00:15:00Z'},
#  {'message_body': '$SPY : Chop followed by massive sell off, $AAPL ER is the excuse they have been waiting for.',
#   'timestamp': '2018-11-01T00:15:10Z'},
#  {'message_body': 'We have detected 3 negative indicators as of 10-31 for $MRO More info at https://dividendbot.com?s=MRO',
#   'timestamp': '2018-11-01T00:16:03Z'},
#  {'message_body': '$AAPL if it spikes $225, im selling my Calls. Not waiting for ER',
#   'timestamp': '2018-11-01T00:16:10Z'},
#  {'message_body': '$AMZN  Need I say more.',
#   'timestamp': '2018-11-01T00:16:15Z'},
#  {'message_body': '$CLX max pain is 150 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:16:21Z'},
#  {'message_body': '$CMCSA max pain is 37 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:17:21Z'},
#  {'message_body': 'Based on stats,75% chance,$V will close above $134.34 support by end of session. Bullish. http://tradespoon.com/s.php?t=$V',
#   'timestamp': '2018-11-01T00:17:27Z'},
#  {'message_body': 'Just to put things into perspective. $FB is back with $SPX since Nov 11, 2016',
#   'timestamp': '2018-11-01T00:17:32Z'},
#  {'message_body': '$CME max pain is 177.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:17:42Z'},
#  {'message_body': '$CMG max pain is 450 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:17:53Z'},
#  {'message_body': '$CMI max pain is 135 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:18:03Z'},
#  {'message_body': '$WMT bought a 105 call exp in January earlier in the day... think I made a big mistake...',
#   'timestamp': '2018-11-01T00:18:24Z'},
#  {'message_body': '$AAPL Swing blocking', 'timestamp': '2018-11-01T00:18:33Z'},
#  {'message_body': 'Once rockstar $ABBV has been littered with put sweepers for months. Put action again this morning, does have earnings coming ..',
#   'timestamp': '2018-11-01T00:19:01Z'},
#  {'message_body': '$WMT really bugs me we went down price and our volume was so high at end of day',
#   'timestamp': '2018-11-01T00:19:08Z'},
#  {'message_body': 'Unusual puts:\n\n$KBH $NWSA $BBD $F $MRO $NLSN $GSK',
#   'timestamp': '2018-11-01T00:19:30Z'},
#  {'message_body': '$CNC max pain is 135 for expiry 2018-11-16 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:19:32Z'},
#  {'message_body': '$AMZN  \nS&amp;P 500 Futures - Dec 18  Shorts! Futures green in Thur Asia!',
#   'timestamp': '2018-11-01T00:19:42Z'},
#  {'message_body': 'Unusual Calls:\n\n$KO $BAC $TWTR $MRK $BLDR $HIG $DVA $DXC $PFE $AOBC $CMCSA $CVE $IBM $FXI $ALB $CPE $CZR $EA $HAIN',
#   'timestamp': '2018-11-01T00:19:49Z'},
#  {'message_body': '$BMY hopefully drops to 45',
#   'timestamp': '2018-11-01T00:19:50Z'},
#  {'message_body': '$AAPL why would Apple, all of a sudden, have a bad quarter?',
#   'timestamp': '2018-11-01T00:19:51Z'},
#  {'message_body': '#STAAnalystAlert for $HOG : Citigroup Maintains with a rating of Buy setting target price at USD 45.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating',
#   'timestamp': '2018-11-01T00:20:09Z'},
#  {'message_body': 'Downgrades:\n\n$AQUA $CVLT $AMT $EGRX $CVRR $AET $BUD $ESIO $CLVS $CTSH $BHGE $EA $CEQP',
#   'timestamp': '2018-11-01T00:20:09Z'},
#  {'message_body': '$AAPL they always beat so relax bears, even if a miss buffet will buy all your shares',
#   'timestamp': '2018-11-01T00:20:23Z'},
#  {'message_body': '$AMZN Wall St. ends last day of October in the black http://www.streetinsider.com/Market+Check/Wall+St.+ends+last+day+of+haunted+October+in+the+black/14764174.html via @Street_Insider',
#   'timestamp': '2018-11-01T00:20:41Z'},
#  {'message_body': 'Upgrades:\n\n$EVTC $BE $CF $CHK $IQ $HABT $AGCO $GDI $ASML $ECL $FITB $CMA $BHGE $CMI $DENN $GE $AIG',
#   'timestamp': '2018-11-01T00:20:35Z'},
#  {'message_body': '$SIG has a poor technical rating and the quality of the setup is also not perfect at the moment. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=TA&amp;utm_content=SETUP&amp;utm_campaign=social_tracking#/SIG?key=ed62752d-6524-4a56-a9cd-245b18645d4b',
#   'timestamp': '2018-11-01T00:20:57Z'},
#  {'message_body': 'Cobalt Blue Holdings Limited (ASX:COB) Thackaringa Feasibility Study Drilling Campaign Commences $COB $CBBHF $COH… http://dlvr.it/Qq8663',
#   'timestamp': '2018-11-01T00:21:03Z'},
#  {'message_body': '$AAPL miss revenue is possible due to strong dollar but guidance will be upped for holidays',
#   'timestamp': '2018-11-01T00:21:04Z'},
#  {'message_body': '$RL reported -3.0% Comparable Store Sales last quarter. Next report is on 11/06 BMO. Jury is still out on expectations. What’s yours?\nhttp://www.estimize.com/intro/rl?chart=historical&amp;metric_name=comparable_store_sales&amp;utm_content=RL&amp;utm_medium=metric_report_date&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:21:09Z'},
#  {'message_body': '7 Massive Tech Stocks Leading the Way Higher\n\n$NFLX $MSFT $GOOG $GOOGL $AAPL $TWTR $FB $AMZN \n\n https://investorplace.com/2018/10/7-big-tech-stocks-leading-the-way-higher/',
#   'timestamp': '2018-11-01T00:21:14Z'},
#  {'message_body': '$AAPL expectations are too high. Everyone is Hoping it saves the market.',
#   'timestamp': '2018-11-01T00:21:17Z'},
#  {'message_body': 'Why Micron and Universal Display Might Be Getting a Lift from Samsung&#39;s Earnings\n\n$SSNLF $MU $OLED  \n\nhttps://www.thestreet.com/opinion/micron-and-universal-display-boost-from-samsung-earnings-14764406',
#   'timestamp': '2018-11-01T00:21:51Z'},
#  {'message_body': '$AAPL fingers crossee they miss',
#   'timestamp': '2018-11-01T00:22:04Z'},
#  {'message_body': '$AMZN bought @ 1585.42 of 40%(cash) in stock account will hold until $2,000+😂',
#   'timestamp': '2018-11-01T00:22:10Z'},
#  {'message_body': '$NWL http://www.wallstreetintellects.com/citigroup-cuts-newell-brands-inc-nysenwl-target-price-to-25-00/ Citigroup maintains buy rating today! PT $25',
#   'timestamp': '2018-11-01T00:22:13Z'},
#  {'message_body': '$AAPL 223 open, 230 close 238 ah lol tea leaves',
#   'timestamp': '2018-11-01T00:22:17Z'},
#  {'message_body': '$MU Remember, China is half of micron&#39;s business. Think about that. If micron memory is banned from China, it&#39;s EPS could be negative.',
#   'timestamp': '2018-11-01T00:22:17Z'},
#  {'message_body': '7 Dow Jones Stocks That Are Still Struggling\n\n$MSFT $CVX $IBM $CAT $DIA $GE $BA $DWDP  \n\nhttps://investorplace.com/2018/10/7-dow-jones-stocks-that-are-still-struggling/?cp=IPIE&amp;ct=20181031&amp;cc=eletter&amp;auth=nonbuyer',
#   'timestamp': '2018-11-01T00:22:20Z'},
#  {'message_body': '$ALB 16-Nov-18 ATM Implied Volatility is up +6.6% to 47.9. Straddle Implies a Move of ±8.3%. Earnings Nov 07 AMC. http://tinyurl.com/ycxbju5q',
#   'timestamp': '2018-11-01T00:22:28Z'},
#  {'message_body': '$AMZN Long &amp; Strong! BTFD',
#   'timestamp': '2018-11-01T00:22:35Z'},
#  {'message_body': '$COF max pain is 87 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:22:40Z'},
#  {'message_body': '$AAPL Final Countdown playing in the background.Apple has responsibility like MJ or Tiger Woods with 1 last shot to win 2 avoid a bear markt',
#   'timestamp': '2018-11-01T00:22:43Z'},
#  {'message_body': '$FB will we see $200 ??',
#   'timestamp': '2018-11-01T00:23:49Z'},
#  {'message_body': '$AMZN I don’t think futures are any more an indicator of the future. Lol; always manipulated. Trump tweets are more reliable. :-)',
#   'timestamp': '2018-11-01T00:24:00Z'},
#  {'message_body': '$aapl $spy $fb \nanticipating nice apple er tmmrw eod call sell friday. then switch to put. hes 6/7 right\nhttps://www.youtube.com/watch?v=3d9z7sV54i0',
#   'timestamp': '2018-11-01T00:24:01Z'},
#  {'message_body': '$COO max pain is 250 for expiry 2018-11-16 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:24:15Z'},
#  {'message_body': '$COP max pain is 69.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:24:25Z'},
#  {'message_body': '$CRM damn insiders keep selling here',
#   'timestamp': '2018-11-01T00:24:38Z'},
#  {'message_body': '$MCD has a Return On Assets of 16.67%. This is amongst the best returns in the industry. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=PROFITABILITY&amp;utm_campaign=social_tracking#/MCD?r=fa&amp;key=7388fdae-4e22-4d43-bdc1-5f0b8854d3a1',
#   'timestamp': '2018-11-01T00:24:58Z'},
#  {'message_body': '$FB $AMZN $GOOG $MSFT $NVDA $SQ A good refresher on &quot;follow through days&quot; after a possible &quot;bottom&quot;. A must read !!\n\nhttps://www.investors.com/ibd-university/market-timing/market-bottoms/',
#   'timestamp': '2018-11-01T00:25:01Z'},
#  {'message_body': '$COST max pain is 225 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:25:24Z'},
#  {'message_body': '$AMD Is ONE solid news event from resuming it&#39;s 30&#39;s trajectory, we need a Red Win! China caves-in to fair trade,Nomo drama with WH,then UP!',
#   'timestamp': '2018-11-01T00:25:28Z'},
#  {'message_body': 'The short sale volume (not short interest) for $FE on 2018-10-30 is 53%. http://shortvolumes.com/?t=FE via @shortvolumes',
#   'timestamp': '2018-11-01T00:25:36Z'},
#  {'message_body': '$AAPL  I was going to buy puts for this ER. But i dont think i will now. But im still bearish. i say it&#39;ll go down to 200',
#   'timestamp': '2018-11-01T00:25:37Z'},
#  {'message_body': '$INTC up short term', 'timestamp': '2018-11-01T00:25:37Z'},
#  {'message_body': '$AAPL \nEarnings on deck',
#   'timestamp': '2018-11-01T00:25:44Z'},
#  {'message_body': '$GE Don&#39;t forget,reason they even kept divy at .01 cent is most  mutual funds won&#39;t list stocks that don&#39;t have a divy.\n\nThe more you know=$',
#   'timestamp': '2018-11-01T00:25:46Z'},
#  {'message_body': '$GE $5 \nhttps://youtu.be/Q3EO-JnUcag',
#   'timestamp': '2018-11-01T00:25:46Z'},
#  {'message_body': '$AAPL new phones, services, awesome products... easy beat as usual.',
#   'timestamp': '2018-11-01T00:25:55Z'},
#  {'message_body': '$FB bulls and bears seemed evenly split on the street. It will move with market mostly',
#   'timestamp': '2018-11-01T00:26:08Z'},
#  {'message_body': '$GE stong buy', 'timestamp': '2018-11-01T00:26:12Z'},
#  {'message_body': 'After-Hours Movers 10/31: \n\n$UQM $HK $FIT Higher; $IO $PKI $FARO Lower more...\n\nhttps://www.streetinsider.com/dr/news.php?id=14768410',
#   'timestamp': '2018-11-01T00:26:17Z'},
#  {'message_body': '$CPB max pain is 37.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:26:44Z'},
#  {'message_body': 'Who will takeover ElDorado Gold? $EGO $ELD. Buyers can be: $KL $GG $ABX $NEM $AEM',
#   'timestamp': '2018-11-01T00:26:49Z'},
#  {'message_body': '$AAPL follow this guy he’s genius ⌛️🔪💣🔫... Moran',
#   'timestamp': '2018-11-01T00:26:53Z'},
#  {'message_body': '$MGM 🎃🎃🎃', 'timestamp': '2018-11-01T00:27:05Z'},
#  {'message_body': '$WYNN estimates distribution - here’s what 8 Estimize analysts are expecting $WYNN to report for Q3 RevPAR tomorrow 11/01 AMC.\nhttp://www.estimize.com/intro/wynn?chart=scatterplotOrHistogram&amp;metric_name=revenue_per_available_room&amp;utm_content=WYNN&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:16Z'},
#  {'message_body': 'Here’s what 4 Estimize analysts believe $REGN will report for Q3 EYLEA® U.S. Product Sales on 11/06 BMO.\nhttp://www.estimize.com/intro/regn?chart=historical&amp;metric_name=eylea_us_product_sales&amp;utm_content=REGN&amp;utm_medium=metric_update&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:16Z'},
#  {'message_body': '$SWKS reported 50.9% Gross Margins last quarter. Next report is on 11/08 AMC. Jury is still out on expectations. What’s yours?\nhttp://www.estimize.com/intro/swks?chart=historical&amp;metric_name=gross_margins&amp;utm_content=SWKS&amp;utm_medium=metric_report_date&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:16Z'},
#  {'message_body': '$SYMC analysts on Estimize expect  YoY growth in Consumer Digital Safety Revenue for Q2,  41.98% in previous year [Reporting Tomorrow 1...\nhttp://www.estimize.com/intro/symc?chart=change-over-time&amp;metric_name=consumer_digital_safety_revenue&amp;utm_content=SYMC&amp;utm_medium=metric_growth&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:17Z'},
#  {'message_body': '$SYMC&#39;s Enterprise Security Revenue is a key growth metric for their next report tomorrow 11/01 AMC. Will they beat last quarter&#39;s 556....\nhttp://www.estimize.com/intro/symc?chart=historical&amp;metric_name=enterprise_security_revenue&amp;utm_content=SYMC&amp;utm_medium=key_metric&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:17Z'},
#  {'message_body': '$KORS&#39;s Same Store Sales is a key growth metric for their next report on 11/07 BMO. Will they beat last quarter&#39;s 0.2% Same Store Sales?\nhttp://www.estimize.com/intro/kors?chart=historical&amp;metric_name=same_store_sales&amp;utm_content=KORS&amp;utm_medium=key_metric&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:17Z'},
#  {'message_body': '$TRIP reported 456.0M MAU last quarter. Next report is on 11/07 AMC. Jury is still out on expectations. What’s yours?\nhttp://www.estimize.com/intro/trip?chart=historical&amp;metric_name=monthly_active_users&amp;utm_content=TRIP&amp;utm_medium=metric_report_date&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:17Z'},
#  {'message_body': '$CVS&#39;s Same Store Sales is a key growth metric for their next report on 11/06 BMO. Will they beat last quarter&#39;s 5.9% Same Store Sales?\nhttp://www.estimize.com/intro/cvs?chart=historical&amp;metric_name=same_store_sales&amp;utm_content=CVS&amp;utm_medium=key_metric&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:27:17Z'},
#  {'message_body': '$WMT holiday spending \U0001f92d',
#   'timestamp': '2018-11-01T00:28:34Z'},
#  {'message_body': '$AMZN who owns online shopping? 📈📈',
#   'timestamp': '2018-11-01T00:28:59Z'},
#  {'message_body': '$FB (2y Daily) A classic Megaphone pattern. Bounced off bottom, should work it’s way back to ATHs. Good long setup into next year. $SPY',
#   'timestamp': '2018-11-01T00:29:00Z'},
#  {'message_body': 'Australian Potash Ltd (ASX:APC) Quarterly Activities Report $APC $SO4 $SO4 $W1D $WHELF $STBRY $SBM @OzPotash http://dlvr.it/Qq87JX',
#   'timestamp': '2018-11-01T00:29:06Z'},
#  {'message_body': '$ACRX imagine a $pfe buyout. their stock price is $43, will $acrx shareholders be worth $43 after a buyout?',
#   'timestamp': '2018-11-01T00:29:07Z'},
#  {'message_body': '$F PoS', 'timestamp': '2018-11-01T00:29:14Z'},
#  {'message_body': '$RTN: The EPS growth is accelerating: in the next 2 years the growth will be better than in the last years. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=GROWTH&amp;utm_campaign=social_tracking#/RTN?r=fa&amp;key=316f7c65-1c7b-4ea8-b174-149b2613a986',
#   'timestamp': '2018-11-01T00:29:58Z'},
#  {'message_body': 'Even with $80 oil ... the oil stocks look like death ... $slb $xom',
#   'timestamp': '2018-11-01T00:30:01Z'},
#  {'message_body': '$O how high can we expect this to go from its beat ?',
#   'timestamp': '2018-11-01T00:30:02Z'},
#  {'message_body': 'Double Bottom identified: $MS. More insights: https://stockinvest.us/technical-analysis/MS?utm_source=stocktwits&amp;utm_medium=post',
#   'timestamp': '2018-11-01T00:30:06Z'},
#  {'message_body': '$AMD I&#39;m trying to buy but it won&#39;t let me',
#   'timestamp': '2018-11-01T00:30:29Z'},
#  {'message_body': '$ORLY break 280 then free fall from there',
#   'timestamp': '2018-11-01T00:30:48Z'},
#  {'message_body': '@MapTechnicalForecasting But what will S&amp;P500 be at Fri lunchtime after $AAPL reports Thurs afternoon? That is the more relevant question',
#   'timestamp': '2018-11-01T00:30:55Z'},
#  {'message_body': '$EBAY earnings move  5.9% vs an expected ±9.7% move  http://tinyurl.com/y7rldku9',
#   'timestamp': '2018-11-01T00:30:59Z'},
#  {'message_body': '$CRM max pain is 139 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:31:11Z'},
#  {'message_body': '$GE Firm market cap about $88B.  Need to time 25-1 reverse split when she hits $8.75 this Q.',
#   'timestamp': '2018-11-01T00:31:15Z'},
#  {'message_body': '$ABMD I’m afraid to hold during earning so sold both call and put today: will buy back after earning look at $isrg as a study case after war',
#   'timestamp': '2018-11-01T00:31:33Z'},
#  {'message_body': '$BAC Banking sector is about to soar. Banks spends so much money trying to comply with the rules that were placed after the financial crisis',
#   'timestamp': '2018-11-01T00:32:17Z'},
#  {'message_body': '$BAC back in for like no ride now...',
#   'timestamp': '2018-11-01T00:32:31Z'},
#  {'message_body': '$AMD $DJIA  Happy Halloween From THE STAGGERRRRR......\n https://www.youtube.com/watch?v=2x-4BAqk4wc',
#   'timestamp': '2018-11-01T00:32:32Z'},
#  {'message_body': '$ORLY plunge to 220 to fill gap',
#   'timestamp': '2018-11-01T00:32:51Z'},
#  {'message_body': '$YUM reported -33.33% YoY growth in Same Store Sales for Q3.\nhttp://www.estimize.com/intro/yum?chart=historical&amp;metric_name=same_store_sales&amp;utm_content=YUM&amp;utm_medium=metric_growth&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:33:09Z'},
#  {'message_body': '$CSCO max pain is 45.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:33:30Z'},
#  {'message_body': '$AGN is cheaper than 92% of the companies listed in the same industry. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=VALUATION&amp;utm_campaign=social_tracking#/AGN?r=fa&amp;key=a0ee423d-0ce9-41af-9088-9c0720c7ccd9',
#   'timestamp': '2018-11-01T00:33:59Z'},
#  {'message_body': 'Huntington Bancshares Director Richard Neu Buys $93,690.00 in $HBAN https://www.marketbeat.com/i/303249',
#   'timestamp': '2018-11-01T00:34:16Z'},
#  {'message_body': '$AAPL devil&#39;s advocate. Why would this go down?',
#   'timestamp': '2018-11-01T00:34:55Z'},
#  {'message_body': '$AMZN happy Halloween',
#   'timestamp': '2018-11-01T00:35:10Z'},
#  {'message_body': '$AAPL china tariff issue will impact their earnings negatively. News will be significant enough to thrash the entire stock mkt',
#   'timestamp': '2018-11-01T00:35:11Z'},
#  {'message_body': '@w97 ssshhhhh.  Bulls never acknowledge the possibility they might be wrong.  The $MU cult is quite disturbing',
#   'timestamp': '2018-11-01T00:35:19Z'},
#  {'message_body': '$CSX max pain is 67.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:35:20Z'},
#  {'message_body': '$CTAS max pain is 190 for expiry 2018-11-16 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:35:30Z'},
#  {'message_body': '$SIG Bearish earnings reversal should drop to it&#39;s 5 EMA  two points lower.',
#   'timestamp': '2018-11-01T00:35:31Z'},
#  {'message_body': 'Big Trade Blocks for $ANTM (Largest Trade: 0.59% of Volume) https://icebergbot.com?s=ANTM',
#   'timestamp': '2018-11-01T00:35:35Z'},
#  {'message_body': 'Today&#39;s insight on $NE https://app.seasonaledge.com/tools/I/NE',
#   'timestamp': '2018-11-01T00:35:40Z'},
#  {'message_body': '$DWDP I had thought this co could out compete rest of the world by making high qual things from plastic made by cheap natural  gas ?',
#   'timestamp': '2018-11-01T00:35:45Z'},
#  {'message_body': '$UNH GOOGLE :OPTUM, ATTORNEY MARK CUKER PHARMACY FRAUD PENSYLVANNIA',
#   'timestamp': '2018-11-01T00:35:47Z'},
#  {'message_body': '$GS Yuan Will Hit 7 as China Avoids Heavy Intervention, Goldman Says via http://www.hvper.com/?ref=stw',
#   'timestamp': '2018-11-01T00:36:01Z'},
#  {'message_body': '$BB another car comes off the line w QNX every .7 sec! QNX growing at 30% YoY QoQ. All players hard code onto their chips! Yum yum!! $NVDA',
#   'timestamp': '2018-11-01T00:36:01Z'},
#  {'message_body': '$MCD bulls have 5 reasons on 10-31 to pay more attention https://dividendbot.com?s=MCD',
#   'timestamp': '2018-11-01T00:36:05Z'},
#  {'message_body': '$AMZN boom', 'timestamp': '2018-11-01T00:36:09Z'},
#  {'message_body': '$CTL max pain is 20.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:36:10Z'},
#  {'message_body': 'Today&#39;s insight on $K https://app.seasonaledge.com/tools/I/K',
#   'timestamp': '2018-11-01T00:36:53Z'},
#  {'message_body': 'The industry average ROA is -1.59%. $MSFT outperforms 81% of its industry peers. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=PROFITABILITY&amp;utm_campaign=social_tracking#/MSFT?r=fa&amp;key=92318c9b-cb66-4932-8e30-5564fa1dd6a6',
#   'timestamp': '2018-11-01T00:36:58Z'},
#  {'message_body': '$CLF What a night in New York.  Perfect weather.  Happy Halloween.  Hope my car doesn’t get egged.',
#   'timestamp': '2018-11-01T00:37:05Z'},
#  {'message_body': '@shortvolume $WM is a utility like $RSG',
#   'timestamp': '2018-11-01T00:37:16Z'},
#  {'message_body': '$GE Shows a possibility of hitting $8.75 at 35 year trend using quarterly candles:',
#   'timestamp': '2018-11-01T00:37:16Z'},
#  {'message_body': '$CTSH max pain is 72.5 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:37:19Z'},
#  {'message_body': '@GoldenWhale @dt100 Tim Cook just posted it on Twitter. It’s official, $AAPL will buy $mu. IT WILL SKYROCKET TOMORROW !!!!',
#   'timestamp': '2018-11-01T00:37:20Z'},
#  {'message_body': '$PKI Of course...', 'timestamp': '2018-11-01T00:37:24Z'},
#  {'message_body': '$WATT I&#39;m thinking diversified  $AMD $TNDM $NIO $JWN and of course wattup for the long',
#   'timestamp': '2018-11-01T00:37:30Z'},
#  {'message_body': 'Today&#39;s insight on $CLX https://app.seasonaledge.com/tools/I/CLX',
#   'timestamp': '2018-11-01T00:38:06Z'},
#  {'message_body': '$AMZN I don’t give a fukc I bought my shares back today and gonna roll on with Amazon \nAlso bought some apple',
#   'timestamp': '2018-11-01T00:38:23Z'},
#  {'message_body': '$INTC fair price 38 heard it here first',
#   'timestamp': '2018-11-01T00:38:25Z'},
#  {'message_body': '$FCX charts are telling me upwards tomorrow.',
#   'timestamp': '2018-11-01T00:38:29Z'},
#  {'message_body': '$AMZN even after ours was green today I’m not sure what to think up or down\n\nThat they have in store for us',
#   'timestamp': '2018-11-01T00:38:29Z'},
#  {'message_body': '$AAPL estimates distribution - here’s what 42 Estimize analysts are expecting $AAPL to report for Q4 Gross Margins tomorrow 11/01 AMC.\nhttp://www.estimize.com/intro/aapl?chart=scatterplotOrHistogram&amp;metric_name=gross_margins&amp;utm_content=AAPL&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:11Z'},
#  {'message_body': '$AAPL estimates distribution - here’s what 30 Estimize analysts are expecting $AAPL to report for Q4 Mac Sales tomorrow 11/01 AMC.\nhttp://www.estimize.com/intro/aapl?chart=scatterplotOrHistogram&amp;metric_name=mac_unit_sales&amp;utm_content=AAPL&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:11Z'},
#  {'message_body': 'Here’s what 6 Estimize analysts believe $QCOM will report for Q4 Gross Margins on 11/07 AMC.\nhttp://www.estimize.com/intro/qcom?chart=historical&amp;metric_name=gross_margins&amp;utm_content=QCOM&amp;utm_medium=metric_update&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:11Z'},
#  {'message_body': '$AAPL estimates distribution - here’s what 64 Estimize analysts are expecting $AAPL to report for Q4 iPhone Sales tomorrow 11/01 AMC.\nhttp://www.estimize.com/intro/aapl?chart=scatterplotOrHistogram&amp;metric_name=iphone_unit_sales&amp;utm_content=AAPL&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:11Z'},
#  {'message_body': '$AAPL estimates distribution - here’s what 31 Estimize analysts are expecting $AAPL to report for Q4 iPad Sales tomorrow 11/01 AMC.\nhttp://www.estimize.com/intro/aapl?chart=scatterplotOrHistogram&amp;metric_name=ipad_unit_sales&amp;utm_content=AAPL&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:11Z'},
#  {'message_body': 'Here’s what 11 Estimize analysts believe $SBUX will report for Q4 Same Store Sales tomorrow 11/01 AMC.\nhttp://www.estimize.com/intro/sbux?chart=historical&amp;metric_name=same_store_sales&amp;utm_content=SBUX&amp;utm_medium=metric_update&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:12Z'},
#  {'message_body': '$ATVI estimates distribution - here’s what 10 Estimize analysts are expecting $ATVI to report for Q3 MAU on 11/08 AMC.\nhttp://www.estimize.com/intro/atvi?chart=scatterplotOrHistogram&amp;metric_name=monthly_active_users&amp;utm_content=ATVI&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:12Z'},
#  {'message_body': '$BKNG estimates distribution - here’s what 8 Estimize analysts are expecting $BKNG to report for Q3 Room Nights Growth on 11/05 AMC.\nhttp://www.estimize.com/intro/bkng?chart=scatterplotOrHistogram&amp;metric_name=room_nights_growth&amp;utm_content=BKNG&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:13Z'},
#  {'message_body': '$BKNG estimates distribution - here’s what 8 Estimize analysts are expecting $BKNG to report for Q3 Total Bookings on 11/05 AMC.\nhttp://www.estimize.com/intro/bkng?chart=scatterplotOrHistogram&amp;metric_name=total_bookings&amp;utm_content=BKNG&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:13Z'},
#  {'message_body': 'Here’s what 48 Estimize analysts believe $QCOM will report for Q4 2018 EPS [Reporting 11/07 AMC]\nhttp://www.estimize.com/intro/qcom?chart=historical&amp;metric_name=eps&amp;utm_content=QCOM&amp;utm_medium=eps_update&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:19Z'},
#  {'message_body': 'Estimize EPS expectations are 13.74% higher than that of Wall Street for $ATVI Q3 [Reporting 11/08 AMC]\nhttp://www.estimize.com/intro/atvi?chart=change-over-time&amp;metric_name=eps&amp;utm_content=ATVI&amp;utm_medium=eps_difference&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:20Z'},
#  {'message_body': 'Estimize EPS expectations are 1.78% higher than that of Wall Street for $AAPL Q4 [Reporting Tomorrow 11/01 AMC]\nhttp://www.estimize.com/intro/aapl?chart=change-over-time&amp;metric_name=eps&amp;utm_content=AAPL&amp;utm_medium=eps_difference&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:24Z'},
#  {'message_body': '$BKNG analysts on Estimize are expecting 10.07% YoY revenue growth for Q3, down from 16.93% in Q2 [Reporting 11/05 AMC]\nhttp://www.estimize.com/intro/bkng?chart=historical&amp;metric_name=revenue&amp;utm_content=BKNG&amp;utm_medium=revenue_growth&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:25Z'},
#  {'message_body': 'Here’s what 119 Estimize analysts believe $SBUX will report for Q4 2018 revenue [Reporting Tomorrow 11/01 AMC]\nhttp://www.estimize.com/intro/sbux?chart=historical&amp;metric_name=revenue&amp;utm_content=SBUX&amp;utm_medium=revenue_update&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:39:26Z'},
#  {'message_body': '$WDC Large Trades (Largest Trade: 0.37% of Volume)  https://icebergbot.com?s=WDC',
#   'timestamp': '2018-11-01T00:39:34Z'},
#  {'message_body': '$CHK Swinging for the fences tomorrow',
#   'timestamp': '2018-11-01T00:40:07Z'},
#  {'message_body': '#STAAnalystAlert for $HSY : Credit Suisse Upgrades with a rating of Neutral. Our own verdict is Under-perform http://www.stocktargetadvisor.com/toprating',
#   'timestamp': '2018-11-01T00:40:10Z'},
#  {'message_body': 'Holy grail pump into Friday $SPY and this bad baby $NKE is sitting on a split open gap ready to explode to $76.83 77.08 cash out',
#   'timestamp': '2018-11-01T00:40:25Z'},
#  {'message_body': 'Based on stats,74% chance,$NWSA will close above $12.82 support by end of session. Bullish. http://tradespoon.com/s.php?t=$NWSA',
#   'timestamp': '2018-11-01T00:40:37Z'},
#  {'message_body': '$CVS max pain is 73 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:40:44Z'},
#  {'message_body': '$MU just noticed that analysts estimates for AAPL for next qtr, not tomorrow, are for almost $5.00/share...terrific news for MU IMO..',
#   'timestamp': '2018-11-01T00:40:45Z'},
#  {'message_body': '$AMZN Core of Amzn sales come from 3rd party sellers .Amzn holds funds for 2 weeks. Billions in funds. Amazon 2 wks away from BR everyday',
#   'timestamp': '2018-11-01T00:40:51Z'},
#  {'message_body': '$CVX max pain is 116 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:40:54Z'},
#  {'message_body': '$GE Peter at CNBC will buy Puts@around Range $7.00-$7.50 and he will buy the stock @$5.00 https://www.youtube.com/watch?v=Q3EO-JnUcag&amp;feature=youtu.be',
#   'timestamp': '2018-11-01T00:41:02Z'},
#  {'message_body': '@Zingerman $MA was first to introduce cards without raised numbers.  $V did the same.  The old cards with chips kept on failing at kiosks.',
#   'timestamp': '2018-11-01T00:41:30Z'},
#  {'message_body': '$FB 159, 162, 186-168 are the next resistance levels. If the market is good with us it should reach there and then will take off to 172-176.',
#   'timestamp': '2018-11-01T00:41:32Z'},
#  {'message_body': '$AAPL more buyers long term',
#   'timestamp': '2018-11-01T00:41:55Z'},
#  {'message_body': '$SPY tomorrow mostly likely sidewides till afternoon(2pm-4pm) then all eyes on $AAPL',
#   'timestamp': '2018-11-01T00:42:08Z'},
#  {'message_body': '$ESRX reported 334.6M Total Adjusted Claims for Q3.\nhttp://www.estimize.com/intro/esrx?chart=historical&amp;metric_name=total_adjusted_claims&amp;utm_content=ESRX&amp;utm_medium=metric_actuals&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:42:10Z'},
#  {'message_body': '$QRVO reported 47.7% Gross Margins for Q2.\nhttp://www.estimize.com/intro/qrvo?chart=historical&amp;metric_name=gross_margins&amp;utm_content=QRVO&amp;utm_medium=metric_actuals&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:42:11Z'},
#  {'message_body': '$DIS estimates distribution - here’s what 7 Estimize analysts are expecting $DIS to report for Q4 Media Networks Revenue on 11/08 AMC.\nhttp://www.estimize.com/intro/dis?chart=scatterplotOrHistogram&amp;metric_name=media_networks_revenue&amp;utm_content=DIS&amp;utm_medium=metric_distribution&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:42:11Z'},
#  {'message_body': '$DIS analysts on Estimize are expecting 25.82% YoY EPS growth for Q4, up from 18.35% in Q3 [Reporting 11/08 AMC]\nhttp://www.estimize.com/intro/dis?chart=historical&amp;metric_name=eps&amp;utm_content=DIS&amp;utm_medium=eps_growth&amp;utm_source=stocktwits',
#   'timestamp': '2018-11-01T00:42:17Z'},
#  {'message_body': '$FB  159, 162, 166-168 are the next resistance levels. If the market is good with us it should reach there and then will take off to 172-176',
#   'timestamp': '2018-11-01T00:42:31Z'},
#  {'message_body': '$NKE reload at 73.65', 'timestamp': '2018-11-01T00:42:51Z'},
#  {'message_body': '$CXO max pain is 145 for expiry 2018-11-16 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:43:03Z'},
#  {'message_body': '$AAPL Institutional investors aren&#39;t playing this for &quot;this ER&quot;, they&#39;re starting positions for SaaS sales in future.',
#   'timestamp': '2018-11-01T00:43:04Z'},
#  {'message_body': '$NFX how high can we go tomorrow? Let’s see if we can “explore” our way back up close to $30!',
#   'timestamp': '2018-11-01T00:43:06Z'},
#  {'message_body': '10-31-2018 Potential Whale Trades for $AMD (Largest Trade: 0.12% of Volume) https://icebergbot.com?s=AMD',
#   'timestamp': '2018-11-01T00:43:35Z'},
#  {'message_body': '$FB  Cramer: FANG went up because the sellers disappeared, not because Facebook (FB) wasn&#39;t horrendous',
#   'timestamp': '2018-11-01T00:43:53Z'},
#  {'message_body': '@MaxAlpha41 I&#39;m involved in $NVDA &#39;s service and while they&#39;ve gone a LOOONG way since inception it&#39;s still not on par with local gaming.',
#   'timestamp': '2018-11-01T00:44:04Z'},
#  {'message_body': '$AAPL  indicating sell here',
#   'timestamp': '2018-11-01T00:44:31Z'},
#  {'message_body': '$FB any one with reason of why December out of the money calls were down so much even on an up day like this?',
#   'timestamp': '2018-11-01T00:44:33Z'},
#  {'message_body': 'PivotPoint bottom identified: $ICE. More insights: https://stockinvest.us/technical-analysis/ICE?utm_source=stocktwits&amp;utm_medium=post',
#   'timestamp': '2018-11-01T00:44:37Z'},
#  {'message_body': '$GOOGL is expected to show a strong growth in EPS. In the coming 2 years, the EPS will grow by 22.86% yearly. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=GROWTH&amp;utm_campaign=social_tracking#/GOOGL?r=fa&amp;key=b499dbfa-898a-47fd-b995-82dbbc8d1753',
#   'timestamp': '2018-11-01T00:44:58Z'},
#  {'message_body': '$SQ $PYPL we need HK HSI and Shanghai index going green for tonight!! lol',
#   'timestamp': '2018-11-01T00:45:01Z'},
#  {'message_body': '$AAPL this should run up into earnings tomorrow. Will trim a bit as a hedge tomorrow. Still long but makes sense for me to balance tax loss',
#   'timestamp': '2018-11-01T00:45:06Z'},
#  {'message_body': '$AAPL indicating sell the mkt',
#   'timestamp': '2018-11-01T00:45:20Z'},
#  {'message_body': '$D max pain is 72.5 for expiry 2018-11-16 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:45:26Z'},
#  {'message_body': '$FB 41 Billion in their war chess. Would be interested who they buy next.',
#   'timestamp': '2018-11-01T00:45:42Z'},
#  {'message_body': '$AMZN Trump advisor Larry Kudlow: &#39;Nothing is set in stone right now&#39; on new China tariffs CNBC https://cnb.cx/2Sz7hr9',
#   'timestamp': '2018-11-01T00:45:44Z'},
#  {'message_body': '$AMZN  \nS&amp;P 500 Futures - Dec 18 Green in Thur Asia Investing com',
#   'timestamp': '2018-11-01T00:46:43Z'},
#  {'message_body': '$AMD I&#39;m just going to sit this here...',
#   'timestamp': '2018-11-01T00:47:52Z'},
#  {'message_body': '$F has a good Piotroski-$F score of 7.00. This indicates a good health and profitability. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=PROFITABILITY&amp;utm_campaign=social_tracking#/F?r=fa&amp;key=4062c916-f2e2-4f46-837b-7cad76f0bb6d',
#   'timestamp': '2018-11-01T00:47:59Z'},
#  {'message_body': '$SPY Top analyst thinks $AAPL is going to have good numbers tomorrow.  https://www.google.com/amp/s/www.smarteranalyst.com/analyst-insights/technology-stocks/will-apple-aapl-meet-expectations-tomorrows-earning-report-top-analyst-weighs-stock/amp/ CV',
#   'timestamp': '2018-11-01T00:48:15Z'},
#  {'message_body': '$JCP Beartooth, GrimReaper, Carlo17, BalancedBull, MattyAndy, HighLimit, StockGod12, RocketQueen. Who am I missing on the Shorts list?',
#   'timestamp': '2018-11-01T00:48:36Z'},
#  {'message_body': '@judge1 $FB should reward shareholders with a buy-back',
#   'timestamp': '2018-11-01T00:48:48Z'},
#  {'message_body': 'Possible low risk trading setup on $BSX, buy stop entry @37.1.. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=TA&amp;utm_content=TRADINGSETUP&amp;utm_campaign=social_tracking#/BSX?key=1b8fdb95-7305-48f4-9f43-59d621c261f2',
#   'timestamp': '2018-11-01T00:48:53Z'},
#  {'message_body': '@MaxAlpha41 As an external partner, I mean, not a $NVDA employee or speaking as one. Their tech is light-years ahead of $SNE &amp; $MSFT...',
#   'timestamp': '2018-11-01T00:48:53Z'},
#  {'message_body': '$SPY $AMZN $AAPL this is good right? https://www.cnbc.com/2018/10/31/kudlow-nothing-is-set-in-stone-right-now-on-trump-talks-with-xi.html',
#   'timestamp': '2018-11-01T00:48:59Z'},
#  {'message_body': '$DTEA $TAP Molson Coors 🌿🍺 Expects To Launch Cannabis Beverage In 2019\n$NEPT $DTEA $NBEV $IGCC $CGC $STZ $DEO 🌿🍺🍺https://www.stocknewswires.com/tap-molson-coors-expects-to-launch-cannabis-beverage-in-2019/',
#   'timestamp': '2018-11-01T00:49:16Z'},
#  {'message_body': 'Top Gainers: $SBBP $PXS $ARAY $JONE $GLBS $RRD $SSW $RBBN $MOBL $MITK $AKTS\n\nDTN&#39;s Two Week Free Trial: www.daytradingnation.com',
#   'timestamp': '2018-11-01T00:49:28Z'},
#  {'message_body': '$AMZN $NIO clown', 'timestamp': '2018-11-01T00:49:32Z'},
#  {'message_body': '$DE max pain is 144 for expiry 2018-11-02 Source: http://sweep.ly/maxpain.html',
#   'timestamp': '2018-11-01T00:49:47Z'},
#  {'message_body': 'The industry average Profit Margin is -1.80%. $INTU outperforms 90% of its industry peers. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=PROFITABILITY&amp;utm_campaign=social_tracking#/INTU?r=fa&amp;key=d61f6162-8dfa-40fb-8b5d-d2449152ca35',
#   'timestamp': '2018-11-01T00:49:58Z'},
#  {'message_body': '$NE ER was good, well see what happens next. Lots of lost ground to make up',
#   'timestamp': '2018-11-01T00:50:08Z'},
#  {'message_body': '$MU Price: $38 Equity Per Share: $29. Upcoming annual EPS prediction: $10.5... Within a year this stock will be sub 1 PtB... just saying.',
#   'timestamp': '2018-11-01T00:50:47Z'},
#  {'message_body': '@MaxAlpha41 Nothing to suggest $EA is going to change that short of having a server within 1 mile of every gamer + 10 gig connection.',
#   'timestamp': '2018-11-01T00:50:49Z'},
#  {'message_body': 'The Current Ratio of $A is much better than the industry average of 3.15. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=HEALTH&amp;utm_campaign=social_tracking#/A?r=fa&amp;key=94343187-c937-44e5-bcc2-ab18a48e7785',
#   'timestamp': '2018-11-01T00:50:59Z'},
#  {'message_body': '$ISRG 573 is price target for Friday. 551 for tomorrow.',
#   'timestamp': '2018-11-01T00:51:11Z'},
# ...
#   'timestamp': '2018-11-01T03:29:54Z'},
#  {'message_body': '$ATVI black ops black market shop started on ps4 today. Seems to have the right idea, but it’s a little bit too much on the greed side',
#   'timestamp': '2018-11-01T03:29:57Z'},
#  {'message_body': '$AAPL BACK TO 235 AFTER EARNINGS',
#   'timestamp': '2018-11-01T03:31:02Z'},
#  {'message_body': '$CELG Someone could buy CELG at a 30% premium right now and make a profit off of future Revlimid gains alone -gigantic pipeline valued at $0',
#   'timestamp': '2018-11-01T03:31:36Z'},
#  {'message_body': '@jonboy22 ER tomorrow after market closes, its a gamble, non of the FANGS have produced great results, if $AAPL goes, so does the market.',
#   'timestamp': '2018-11-01T03:32:41Z'},
#  {'message_body': '$AAPL Red apple tomorrow.',
#   'timestamp': '2018-11-01T03:32:44Z'},
#  {'message_body': '$FDX has a bad technical rating, but it does show a decent setup pattern. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=TA&amp;utm_content=SETUP&amp;utm_campaign=social_tracking#/FDX?key=39f7149a-f480-40c4-b016-a36185a1eb98',
#   'timestamp': '2018-11-01T03:32:57Z'},
#  {'message_body': '@smrt7 $BB ls like our partners, especially $AMZN $NVDA we will grow into it organically. Growth Growth. Revenue Revenue $F &amp; $BIDU too',
#   'timestamp': '2018-11-01T03:33:16Z'},
#  {'message_body': '$AAPL if this misses things should get ugly',
#   'timestamp': '2018-11-01T03:34:55Z'},
#  {'message_body': '$GE = Good Endeavor .... to lose money on ... lol ... stop smoking hopium and see reality... this is a deadbeat stock... charts dont lie',
#   'timestamp': '2018-11-01T03:36:01Z'},
#  {'message_body': '$NFLX   \nWhere Will Netflix Inc. Be in 5 Years? https://www.nasdaq.com/article/where-will-netflix-inc-be-in-5-years-cm1047635',
#   'timestamp': '2018-11-01T03:36:16Z'},
#  {'message_body': '$NFLX $292 tomorrow', 'timestamp': '2018-11-01T03:36:49Z'},
#  {'message_body': '$AMZN IS IT GOOD Ohttp://archive.fast-edgar.com//20181031/AMZZ622CJ22282Z2222V2CZFOV5OZ22H28A2/R BAD  ?',
#   'timestamp': '2018-11-01T03:36:51Z'},
#  {'message_body': '$EA 21-Dec-18 ATM Implied Vol Retreats -19.1% to 36.7. Straddle Implies a Move of ±11.0% http://tinyurl.com/ya95ekzj',
#   'timestamp': '2018-11-01T03:37:36Z'},
#  {'message_body': 'Double Bottom identified: $CAG. More insights: https://stockinvest.us/technical-analysis/CAG?utm_source=stocktwits&amp;utm_medium=post',
#   'timestamp': '2018-11-01T03:37:50Z'},
#  {'message_body': '$AAPL what is all this news I hear about helium gas messing up iPhones. Sounds totally weird. Any truth to these claims?',
#   'timestamp': '2018-11-01T03:38:07Z'},
#  {'message_body': '$MSFT 110 TOMORROW', 'timestamp': '2018-11-01T03:38:48Z'},
#  {'message_body': 'Well this may be time for $NFLX \n\nhttps://www.tradingview.com/chart/NFLX/SWJD6hP2-Bull-case-coming-for-NFLX-Needs-306/',
#   'timestamp': '2018-11-01T03:39:11Z'},
#  {'message_body': 'AutoZone Director William Andrew Mckenna Sells $2,241,450.00 in $AZO https://www.marketbeat.com/i/303311',
#   'timestamp': '2018-11-01T03:39:37Z'},
#  {'message_body': '$NXTD I think this is going to explode soon $MA $GRMN news 👀',
#   'timestamp': '2018-11-01T03:40:58Z'},
#  {'message_body': '$AAPL wow this is gonna make me cum',
#   'timestamp': '2018-11-01T03:41:06Z'},
#  {'message_body': '$FB 140 tomorrow', 'timestamp': '2018-11-01T03:42:45Z'},
#  {'message_body': '$JNUG $JPM $AG $GLD $SIVR $SI_F $SLV $GC_F $BTC.X Shamelessly plugging my kids jiujitsu video https://www.youtube.com/watch?v=e_vkaFtduVA Gold &amp; silver or bust!!',
#   'timestamp': '2018-11-01T03:44:05Z'},
#  {'message_body': 'Simon Property Group Insider John Rulli Sells $1,119,120.00 in $SPG https://www.marketbeat.com/i/303312',
#   'timestamp': '2018-11-01T03:44:21Z'},
#  {'message_body': '$AMZN IS IT BAD ? \nForm  4   For: Oct 29  Filed by: BEZOS JEFFREY P 9:00 PM ET 10/31/18 Form  4    AMAZON COM INC    For: Oct 29   JEFFREY P',
#   'timestamp': '2018-11-01T03:44:44Z'},
#  {'message_body': '$EOG short ratio on 2018-10-15 is 3.41 and short % to float is 1.73% http://sunshineavenue.com/stock/EOG/ via @sunshineave',
#   'timestamp': '2018-11-01T03:45:36Z'},
#  {'message_body': '$MOSY $MU I don’t see this happening. There would be me reason for new directors.',
#   'timestamp': '2018-11-01T03:45:42Z'},
#  {'message_body': 'What Facebook, Twitter and Snap&#39;s Earnings Say About Social Media Usage $FB http://dlvr.it/Qq8j5X',
#   'timestamp': '2018-11-01T03:45:44Z'},
#  {'message_body': '$AMZN $fb $googl $nflx more good news from India in world Bank ease of doing business report',
#   'timestamp': '2018-11-01T03:45:45Z'},
#  {'message_body': '$HES earnings move  0.6% vs an expected ±5.2% move  http://tinyurl.com/y7vevglb',
#   'timestamp': '2018-11-01T03:46:06Z'},
#  {'message_body': '$AMZN 5D 1Hr \n{L:$1598}{B:$1605}{A:$1606}\nSupport/Resistance\n#BullishAF #Stocks',
#   'timestamp': '2018-11-01T03:46:32Z'},
#  {'message_body': 'Trade signal, 87% chance,$HCP will close above $27.17 support by end of session. Bullish. http://tradespoon.com/s.php?t=$HCP',
#   'timestamp': '2018-11-01T03:46:34Z'},
#  {'message_body': '$CHK $5.50 pre market',
#   'timestamp': '2018-11-01T03:46:40Z'},
#  {'message_body': '$XLNX  \nvery high PE 39, 22B MktCap, has Run up a lot 27% in 5 days. Needs to pull back likely around 75-78. slowing chip sales is a issue.',
#   'timestamp': '2018-11-01T03:47:15Z'},
#  {'message_body': '$URI premarket looks good for tomorrow, it’s going up much higher tomorrow 125+ easily.',
#   'timestamp': '2018-11-01T03:48:03Z'},
#  {'message_body': '$AMZN Price tomorrow?',
#   'timestamp': '2018-11-01T03:48:25Z'},
#  {'message_body': '$K Stupid selloff', 'timestamp': '2018-11-01T03:48:55Z'},
#  {'message_body': '$SHLD https://www.google.com/amp/amp.usatoday.com/story/1836559002',
#   'timestamp': '2018-11-01T03:49:33Z'},
#  {'message_body': '$AAPL will be good tomorrow-- no worries--',
#   'timestamp': '2018-11-01T03:49:42Z'},
#  {'message_body': 'Kroger Director Clyde Moore Sells $377,780.00 in $KR https://www.marketbeat.com/i/303315',
#   'timestamp': '2018-11-01T03:49:43Z'},
#  {'message_body': 'Essex Property Trust Insider John Burkart Sells $213,595.74 in $ESS https://www.marketbeat.com/i/303314',
#   'timestamp': '2018-11-01T03:49:44Z'},
#  {'message_body': '$SHLD just wait till trips on otc won&#39;t take long, load and set sell for Idk maybe .09¢ the name won&#39;t die it will be bought and used',
#   'timestamp': '2018-11-01T03:49:48Z'},
#  {'message_body': '#STAAnalystAlert for $KLAC : B. Riley Raises Target with a rating of Buy setting target price at USD 123.00. Our own verdict is Strong Buy http://www.stocktargetadvisor.com/toprating',
#   'timestamp': '2018-11-01T03:50:09Z'},
#  {'message_body': '$FB Happy Halloween Zuck 🎃 ur FB is like cancer i don&#39;t ever use it anymore, that said, i bet this rallies along with fang 👋',
#   'timestamp': '2018-11-01T03:50:17Z'},
#  {'message_body': '$CHK Hope you guys are all ready for the wild ride ahead!!! 🐂',
#   'timestamp': '2018-11-01T03:51:10Z'},
#  {'message_body': '$AMD annoying how I’m just as nervous about $AAPL ER as I was this ER. Gonna have to hedge a bit 😕',
#   'timestamp': '2018-11-01T03:51:48Z'},
#  {'message_body': 'There have been 1 acquisition and 0 dispositions for $EQT over the last 7 days http://dividendbot.com/?s=EQT',
#   'timestamp': '2018-11-01T03:51:57Z'},
#  {'message_body': '$AAPL I believe a miss because new phones not special at all. But higher prices may Off set that. It’s a crap shoot but I bet a miss',
#   'timestamp': '2018-11-01T03:52:22Z'},
#  {'message_body': '$ROST Guess the gains will never end:)',
#   'timestamp': '2018-11-01T03:53:57Z'},
#  {'message_body': '$CMS - Sale by Brian Rich of 4000 shares of CMS Energy - CMS Energy https://www.macroaxis.com/invest/story/CMS--14379293--Sale-by-Brian-Rich-of-4000-shares-of-CMS-Energy #insidertrading #stocks #fintechnews',
#   'timestamp': '2018-11-01T03:54:04Z'},
#  {'message_body': 'Northrop Grumman Is Headed For a Real Rough Patch in the Months Ahead $NOC http://dlvr.it/Qq8kM7',
#   'timestamp': '2018-11-01T03:54:05Z'},
#  {'message_body': 'Salesforce Stock: Despite Positive News, the Charts Have Weakened $CRM http://dlvr.it/Qq8kQh',
#   'timestamp': '2018-11-01T03:54:05Z'},
#  {'message_body': 'Facebook&#39;s Advertising Power Buoys Wall Street Confidence Into Earnings $FB http://dlvr.it/Qq8kRC',
#   'timestamp': '2018-11-01T03:54:06Z'},
#  {'message_body': 'Expectations for Facebook&#39;s Earnings Tonight Are Quite Low $FB http://dlvr.it/Qq8kRZ',
#   'timestamp': '2018-11-01T03:54:06Z'},
#  {'message_body': 'Facebook Investors Might Need to Brace for User Slowdown $FB http://dlvr.it/Qq8kS7',
#   'timestamp': '2018-11-01T03:54:07Z'},
#  {'message_body': '$LMT midterms', 'timestamp': '2018-11-01T03:54:29Z'},
#  {'message_body': 'Jim Cramer: Here&#39;s What I Saw That Justified Today&#39;s Rally $NVDA http://dlvr.it/Qq8kTp',
#   'timestamp': '2018-11-01T03:54:32Z'},
#  {'message_body': 'Jim Cramer: Why We Need Definitively Mixed Data Like We Are Getting $PAYX http://dlvr.it/Qq8kV7',
#   'timestamp': '2018-11-01T03:54:32Z'},
#  {'message_body': 'Stay Disciplined When Trading Nvidia: Market Recon $NVDA http://dlvr.it/Qq8kVS',
#   'timestamp': '2018-11-01T03:54:33Z'},
#  {'message_body': 'Starbucks Earnings Preview: Coffee Giant Looks to Wake Up Shares Thursday $SBUX http://dlvr.it/Qq8kVl',
#   'timestamp': '2018-11-01T03:54:36Z'},
#  {'message_body': 'Is FOMO (Fear of Missing Out) Back In Play? $FB http://dlvr.it/Qq8kVx',
#   'timestamp': '2018-11-01T03:55:04Z'},
#  {'message_body': 'eBay Shares Jump Despite Caution on Wall Street $EBAY http://dlvr.it/Qq8kW0',
#   'timestamp': '2018-11-01T03:55:05Z'},
#  {'message_body': 'Deals, Potential Deals and Dividend Cuts $GE http://dlvr.it/Qq8kW6',
#   'timestamp': '2018-11-01T03:55:05Z'},
#  {'message_body': 'Is Starbucks Turning Lukewarm? $SBUX http://dlvr.it/Qq8kWN',
#   'timestamp': '2018-11-01T03:55:06Z'},
#  {'message_body': 'Why General Motors&#39; Disastrous Unit Sales Didn&#39;t Matter -- For Now $GM http://dlvr.it/Qq8kWS',
#   'timestamp': '2018-11-01T03:55:07Z'},
#  {'message_body': 'Masco&#39;s Bad News Bounce Is Not Built to Last $MAS http://dlvr.it/Qq8kWX',
#   'timestamp': '2018-11-01T03:55:07Z'},
#  {'message_body': 'Valero Energy Looks Like It Has the Energy to Stage a Rebound Rally $VLO http://dlvr.it/Qq8kWd',
#   'timestamp': '2018-11-01T03:55:09Z'},
#  {'message_body': '$IBM How Does IBM&#39;s Red Hat Acquisition Impact its 5% Dividend Yield? https://finance.yahoo.com/news/does-ibm-apos-red-hat-112700925.html',
#   'timestamp': '2018-11-01T03:55:28Z'},
#  {'message_body': 'Short sale volume (not short interest) for $NEE on 2018-10-31 is 73%. http://shortvolumes.com/?t=NEE via @shortvolumes',
#   'timestamp': '2018-11-01T03:55:36Z'},
#  {'message_body': 'A Buying Opportunity in Nucor $NUE http://dlvr.it/Qq8kbG',
#   'timestamp': '2018-11-01T03:56:02Z'},
#  {'message_body': 'Newell Brands Unable to Mount an Advance - Bears Remain in Control $NWL http://dlvr.it/Qq8kdV',
#   'timestamp': '2018-11-01T03:56:03Z'},
#  {'message_body': 'Chart of the Day: Starbucks&#39; Chinese Growth Engine Might Stall on Earnings $SBUX http://dlvr.it/Qq8kdn',
#   'timestamp': '2018-11-01T03:56:04Z'},
#  {'message_body': '$AMZN $AAPL Earnings key to determine the short term fate for Amazon',
#   'timestamp': '2018-11-01T03:56:32Z'},
#  {'message_body': '$CHK kaboom', 'timestamp': '2018-11-01T03:57:09Z'},
#  {'message_body': '$CHK A big move is coming.  And it&#39;s not down again',
#   'timestamp': '2018-11-01T03:57:23Z'},
#  {'message_body': '$FB This will probably see red tomorrow',
#   'timestamp': '2018-11-01T03:58:27Z'},
#  {'message_body': 'Facebook VP David B. Fischer Sells $392,936.72 in $FB https://www.marketbeat.com/i/303317',
#   'timestamp': '2018-11-01T03:59:09Z'},
#  {'message_body': '$SHW new insider buying: 675 shares. http://insiderbuyingselling.com/?t=SHW',
#   'timestamp': '2018-11-01T03:59:37Z'},
#  {'message_body': '@20day With the gap up in $HLT today, that most likely eliminates it as a possible short.',
#   'timestamp': '2018-11-01T04:00:15Z'},
#  {'message_body': '$UPS Today&#39;s trading opportunity: https://app.seasonaledge.com/tools/DB/7230?from=11-1&amp;to=11-29&amp;sl=5.5&amp;dp=18',
#   'timestamp': '2018-11-01T04:00:30Z'},
#  {'message_body': 'CH Robinson (CHRW) announces earnings. $1.25 EPS. Beats estimates. 162.33M earnings. $CHRW https://www.tipranks.com/stocks/CHRW/earnings-calendar?ref=TREarnings',
#   'timestamp': '2018-11-01T04:00:59Z'},
#  {'message_body': '$FB $GE $BAC $AAPL $AMD $AMZN $NFLX $MSFT $BABA $GM $TWTR $MU $TEVA $INTC $NVDA $TSLA $F $KO $T $PBR $CHK $NWSA $CZR $SQ $JPM $JD $CAT $IBM',
#   'timestamp': '2018-11-01T04:00:59Z'},
#  {'message_body': '$NVDA $TSLA $AMD $AMZA $FB $CGC  looking good for tomorrow so far, fingers crossed',
#   'timestamp': '2018-11-01T04:01:25Z'},
#  {'message_body': 'Short sale volume (not short interest) for $UAL on 2018-10-31 is 55%. http://shortvolumes.com/?t=UAL via @shortvolumes',
#   'timestamp': '2018-11-01T04:01:36Z'},
#  {'message_body': '$AAPL lol.  He who controls the market, can and will control the market.  Precisely y it didn’t take a beaten like the other FANGS.',
#   'timestamp': '2018-11-01T04:02:17Z'},
#  {'message_body': '$IQ $NFLX of China can come back hard here $IQ.  Bullishmatt.com . Been beaten down for a couple months now, for sure w',
#   'timestamp': '2018-11-01T04:03:39Z'},
#  {'message_body': '$CELG https://www.facebook.com/FastMoney/videos/2205768369698064/',
#   'timestamp': '2018-11-01T04:03:45Z'},
#  {'message_body': '$SVU is valued rather cheaply when comparing the Enterprise Value to EBITDA ratio to the industry average of 16.04. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=VALUATION&amp;utm_campaign=social_tracking#/SVU?r=fa&amp;key=3cd9fe26-26bb-480f-99db-6bf47ccc44d1',
#   'timestamp': '2018-11-01T04:03:58Z'},
#  {'message_body': '$CMI shows a strong growth in EPS: 29.04%. https://www.chartmill.com/analyze.php?utm_source=stocktwits&amp;utm_medium=FA&amp;utm_content=GROWTH&amp;utm_campaign=social_tracking#/CMI?r=fa&amp;key=0a0cc9ed-8051-453d-b1ca-afe0c2963e44',
#   'timestamp': '2018-11-01T04:04:57Z'},
#  {'message_body': '$IBM Where do we go from here ?',
#   'timestamp': '2018-11-01T04:05:50Z'},
#  {'message_body': '$AAPL ...I’d roll them out to 01/19...need some breathing room..G.L.',
#   'timestamp': '2018-11-01T04:06:35Z'},
#  {'message_body': '$AMD it,s interesting that when the news is about more than the wh antics ...the market goes up? Maybe even China see,s balance in congress?',
#   'timestamp': '2018-11-01T04:06:36Z'},
#  {'message_body': '$NWL They have lowered earnings 4 times in last 1 year, If they do it again, we will see $8. It is falling entirely due to poor management.',
#   'timestamp': '2018-11-01T04:06:53Z'},
#  {'message_body': '$NWL Icahn destroyed this company. CEO and his buddy are both part of Trump council.',
#   'timestamp': '2018-11-01T04:07:28Z'},
#  {'message_body': '$DISH 7.4m ago: First HBO Blackout Ever; Harms Competition and Consumers; ATandT Unfairly Targets Rural Americans on DISH https://www.prnewswire.com:443/news-releases/first-hbo-blackout-ever-harms-competition-and-consumers-att-unfairly-targets-rural-americans-on-dish-300741882.html',
#   'timestamp': '2018-11-01T04:08:22Z'},
#  {'message_body': '$ABBV 6.4m ago: AbbVie Receives European Commission Approval of VENCLYXTO® (venetoclax) Plus Rituximab for the Treatment o... https://www.prnewswire.com:443/news-releases/abbvie-receives-european-commission-approval-of-venclyxto-venetoclax-plus-rituximab-for-the-treatment-of-patients-with-chronic-lymphocytic-leukemia-who-have-received-at-least-one-prior-therapy-300741883.html',
#   'timestamp': '2018-11-01T04:08:23Z'},
#  {'message_body': '$CELG unanimous BUY\nhttps://twitter.com/CNBCFastMoney/status/1057752108475314176',
#   'timestamp': '2018-11-01T04:09:00Z'},
#  {'message_body': '$ARNC 15-Feb-19 ATM Implied Vol Decreases -6.9%. Straddle Implies a Move of ±17.0% http://tinyurl.com/yczagfcx',
#   'timestamp': '2018-11-01T04:09:18Z'},
#  ...]

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())
# Out:
# {'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#  'timestamp': '2018-11-01T00:00:05Z'}

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)
# Out:
# {'symbol': '$AAPL',
#  'score': tensor([[ 0.1471,  0.2509,  0.1437,  0.1927,  0.2655]]),
#  'timestamp': '2018-11-01T00:00:18Z'}

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
